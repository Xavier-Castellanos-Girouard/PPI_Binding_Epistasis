# %% [markdown]
# Xavier Castellanos-Girouard <br>
# Date First Created: Oct 22 2023 <br>
# Date Last Modified: Jun 26 2024 <br>

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx
import math
from timeit import default_timer as timer
import pickle
import multiprocessing as mp
from itertools import repeat
from functools import reduce
from itertools import combinations
from itertools import product
from itertools import chain
import random
from tqdm import tqdm
import scipy
import sys
import statistics
import time

# %%
from platform import python_version
print(python_version())
# Out:
# 3.9.19

# %% [markdown]
# # Define Functions

# %%
# Calculate Jaccard index for two sets of elements
def Jaccard(a, b):
    set_a = set(a)
    set_b = set(b)
    intersect_ab = set_a.intersection(set_b)
    union_ab = set_a.union(set_b)
    
    try:
        Jaccard_index = len(intersect_ab)/len(union_ab)
    
    except:
        Jaccard_index = np.nan
    
    return(Jaccard_index)

# %% [markdown]
# # Import and Format Data

# %%
### PPI Network Dataframes
# Import PPI network
Modular_PPI_Network_DF = pd.read_csv("../results/Yeast_PPI_Network_CPX.csv", index_col = 0)

# Convert PPI Complex strings to list
Modular_PPI_Network_DF['source_Complex'] = Modular_PPI_Network_DF['source_Complex'].str.split("|")
Modular_PPI_Network_DF['target_Complex'] = Modular_PPI_Network_DF['target_Complex'].str.split("|")

# Reset index
Modular_PPI_Network_DF = Modular_PPI_Network_DF.reset_index(drop = True)

### GI Network Dataframes
GI_Epsi_network_DF = pd.read_csv("../../Python_GI_Network_Formatting/data/Costanzo_GI_processed/costanzo_2016_longer_withoutReps.csv")


print(Modular_PPI_Network_DF.head(5))
print(GI_Epsi_network_DF.head(5))
# Out:
#   source_locus target_locus source_Complex target_Complex Interaction_Type
# 0      YNR010W      YPR070W     [CPX-3226]     [CPX-3226]      IntraModule
# 1      YNR010W      YPR168W     [CPX-3226]     [CPX-3226]      IntraModule
# 2      YNR010W      YOL135C     [CPX-3226]     [CPX-3226]      IntraModule
# 3      YNR010W      YOR174W     [CPX-3226]     [CPX-3226]      IntraModule
# 4      YNR010W      YOL051W     [CPX-3226]     [CPX-3226]      IntraModule
#    pval  scores  ORF_query strain_query ORF_array strain_array
# 0   0.0 -0.0783  YNL138W-A       sn4590   YER061C      dma1363
# 1   0.0 -0.0126    YDR142C        sn312   YDL222C       dma813
# 2   0.0 -0.0598    YDL143W       tsq729   YIL036W      dma2279
# 3   0.0  0.0319    YIL076W        sn202   YBR269C       dma421
# 4   0.0 -0.6502    YPL233W       tsq450   YGL093W       tsa446

# %%
## Import other network attributes
GI_Modules = pd.read_excel("../data/Costanzo2016_DataFileS6.xlsx")

# Assign proper names to columns
GI_Modules.columns = list(GI_Modules.iloc[0].values)

# Remove row containing column names. Reset index
GI_Modules = GI_Modules.drop(index = 0, axis = 0, inplace = False).reset_index(drop = True)

# Remove duplicates
GI_Modules = GI_Modules[~GI_Modules.duplicated(['Systematic array ORF  name', 'Pathway/complex level (PCC > 0.4)'])]
GI_Modules = GI_Modules[~GI_Modules.duplicated(['Systematic array ORF  name'])].reset_index(drop = True)

GI_Modules.head()
# Out:
#   Systematic array ORF  name Standard array gene/allele Array strain ID  \
# 0                    YJL115W                       ASF1         dma2518
# 1                    YLR320W                      MMS22         dma3369
# 2                    YER095W                      RAD51         dma1402
# 3                    YML032C                      RAD52         dma3531
# 4                    YDR076W                      RAD55          dma885
#
#   Cell compartment level ( PCC <0.05) Bioprocess level (PCC > 0.2)  \
# 0                                   6                           33
# 1                                   6                           33
# 2                                   6                           33
# 3                                   6                           33
# 4                                   6                           33
#
#   Pathway/complex level (PCC > 0.4) Cell compartment enriched term  \
# 0                                27      nucleus-enriched cluster
# 1                                27      nucleus-enriched cluster
# 2                                27      nucleus-enriched cluster
# 3                                27      nucleus-enriched cluster
# 4                                27      nucleus-enriched cluster
#
#                  Select GO bioprocess enriched terms  \
# 0  DNA repair (GO:0006281); DNA metabolic process...
# 1  DNA repair (GO:0006281); DNA metabolic process...
# 2  DNA repair (GO:0006281); DNA metabolic process...
# 3  DNA repair (GO:0006281); DNA metabolic process...
# 4  DNA repair (GO:0006281); DNA metabolic process...
#
#   Select Pathway/protein complex enriched terms
# 0                  DNA homologous recombination
# 1                  DNA homologous recombination
# 2                  DNA homologous recombination
# 3                  DNA homologous recombination
# 4                  DNA homologous recombination

# %% [markdown]
# ## Sort PPI ORFs into modules

# %%
## Get list of PPI modules

# Initiate list:
PPI_module_list = []

# Flatten list from interactorA complexes, and add to list
PPI_module_list.extend([CPX for sublist in Modular_PPI_Network_DF["source_Complex"] for CPX in sublist])

# Flatten list from interactorB complexes, and add to list
PPI_module_list.extend([CPX for sublist in Modular_PPI_Network_DF["target_Complex"] for CPX in sublist])

# Get unique list
PPI_module_list = list(np.unique(PPI_module_list))

# Make dictionary keys from list items
PPI_module_dict = {key: [] for key in PPI_module_list}

PPI_module_dict

# * Note: 'None' value is purpousfully kept in dict, it serves as a list of connectors
# Out:
# {'CPX-1015': [],
#  'CPX-1016': [],
#  'CPX-1018': [],
#  'CPX-1021': [],
#  'CPX-1022': [],
#  'CPX-1026': [],
#  'CPX-1028': [],
#  'CPX-1036': [],
#  'CPX-1037': [],
#  'CPX-1039': [],
#  'CPX-1040': [],
#  'CPX-1041': [],
#  'CPX-1042': [],
#  'CPX-1043': [],
#  'CPX-1044': [],
#  'CPX-1045': [],
#  'CPX-1047': [],
#  'CPX-1052': [],
#  'CPX-1053': [],
#  'CPX-1068': [],
#  'CPX-1071': [],
#  'CPX-1101': [],
#  'CPX-1102': [],
#  'CPX-1103': [],
#  'CPX-112': [],
#  'CPX-1125': [],
#  'CPX-1140': [],
#  'CPX-1141': [],
#  'CPX-1142': [],
#  'CPX-1143': [],
#  'CPX-1149': [],
#  'CPX-1150': [],
#  'CPX-1151': [],
#  'CPX-1152': [],
#  'CPX-1153': [],
#  'CPX-1155': [],
#  'CPX-1156': [],
#  'CPX-1157': [],
#  'CPX-1162': [],
#  'CPX-1165': [],
#  'CPX-1166': [],
#  'CPX-1167': [],
#  'CPX-1178': [],
#  'CPX-1179': [],
#  'CPX-1185': [],
#  'CPX-1186': [],
#  'CPX-1187': [],
#  'CPX-1188': [],
#  'CPX-1189': [],
#  'CPX-1190': [],
#  'CPX-1191': [],
#  'CPX-1192': [],
#  'CPX-1193': [],
#  'CPX-1197': [],
#  'CPX-1198': [],
#  'CPX-1200': [],
#  'CPX-1229': [],
#  'CPX-1230': [],
#  'CPX-1231': [],
#  'CPX-124': [],
#  'CPX-1249': [],
#  'CPX-1260': [],
#  'CPX-1266': [],
#  'CPX-1267': [],
#  'CPX-1268': [],
#  'CPX-1270': [],
#  'CPX-1274': [],
#  'CPX-1275': [],
#  'CPX-1276': [],
#  'CPX-1278': [],
#  'CPX-1279': [],
#  'CPX-1280': [],
#  'CPX-1283': [],
#  'CPX-1287': [],
#  'CPX-1293': [],
#  'CPX-1294': [],
#  'CPX-1295': [],
#  'CPX-1302': [],
#  'CPX-1304': [],
#  'CPX-1306': [],
#  'CPX-1307': [],
#  'CPX-1314': [],
#  'CPX-1315': [],
#  'CPX-1316': [],
#  'CPX-1317': [],
#  'CPX-1318': [],
#  'CPX-1319': [],
#  'CPX-1320': [],
#  'CPX-1322': [],
#  'CPX-1323': [],
#  'CPX-1332': [],
#  'CPX-1333': [],
#  'CPX-1335': [],
#  'CPX-1341': [],
#  'CPX-1342': [],
#  'CPX-1344': [],
#  'CPX-1355': [],
#  'CPX-1362': [],
#  'CPX-1363': [],
#  'CPX-1364': [],
#  'CPX-1365': [],
#  'CPX-1369': [],
#  'CPX-1372': [],
#  'CPX-1377': [],
#  'CPX-1378': [],
#  'CPX-1379': [],
#  'CPX-1380': [],
#  'CPX-1381': [],
#  'CPX-1382': [],
#  'CPX-1383': [],
#  'CPX-1384': [],
#  'CPX-1386': [],
#  'CPX-140': [],
#  'CPX-1408': [],
#  'CPX-1409': [],
#  'CPX-1410': [],
#  'CPX-1412': [],
#  'CPX-1413': [],
#  'CPX-1415': [],
#  'CPX-1417': [],
#  'CPX-1418': [],
#  'CPX-1419': [],
#  'CPX-1420': [],
#  'CPX-1421': [],
#  'CPX-1422': [],
#  'CPX-1423': [],
#  'CPX-1424': [],
#  'CPX-1425': [],
#  'CPX-1426': [],
#  'CPX-1470': [],
#  'CPX-1500': [],
#  'CPX-1501': [],
#  'CPX-154': [],
#  'CPX-1556': [],
#  'CPX-1599': [],
#  'CPX-1601': [],
#  'CPX-1602': [],
#  'CPX-1603': [],
#  'CPX-1604': [],
#  'CPX-1606': [],
#  'CPX-1607': [],
#  'CPX-1608': [],
#  'CPX-161': [],
#  'CPX-1610': [],
#  'CPX-1611': [],
#  'CPX-1612': [],
#  'CPX-1613': [],
#  'CPX-1614': [],
#  'CPX-1616': [],
#  'CPX-162': [],
#  'CPX-1622': [],
#  'CPX-1623': [],
#  'CPX-1624': [],
#  'CPX-1625': [],
#  'CPX-1626': [],
#  'CPX-1627': [],
#  'CPX-1628': [],
#  'CPX-1629': [],
#  'CPX-1630': [],
#  'CPX-1631': [],
#  'CPX-1632': [],
#  'CPX-1633': [],
#  'CPX-1634': [],
#  'CPX-1635': [],
#  'CPX-1636': [],
#  'CPX-1637': [],
#  'CPX-1638': [],
#  'CPX-1639': [],
#  'CPX-1640': [],
#  'CPX-1641': [],
#  'CPX-1642': [],
#  'CPX-1643': [],
#  'CPX-1645': [],
#  'CPX-1646': [],
#  'CPX-1647': [],
#  'CPX-1648': [],
#  'CPX-1649': [],
#  'CPX-1651': [],
#  'CPX-1652': [],
#  'CPX-1653': [],
#  'CPX-1654': [],
#  'CPX-1655': [],
#  'CPX-1656': [],
#  'CPX-1657': [],
#  'CPX-1658': [],
#  'CPX-1659': [],
#  'CPX-166': [],
#  'CPX-1660': [],
#  'CPX-1661': [],
#  'CPX-1662': [],
#  'CPX-1663': [],
#  'CPX-1664': [],
#  'CPX-1665': [],
#  'CPX-1666': [],
#  'CPX-1667': [],
#  'CPX-1668': [],
#  'CPX-1669': [],
#  'CPX-1671': [],
#  'CPX-1672': [],
#  'CPX-1673': [],
#  'CPX-1674': [],
#  'CPX-1675': [],
#  'CPX-1676': [],
#  'CPX-1677': [],
#  'CPX-1678': [],
#  'CPX-1679': [],
#  'CPX-1680': [],
#  'CPX-1681': [],
#  'CPX-1682': [],
#  'CPX-1683': [],
#  'CPX-1684': [],
#  'CPX-1685': [],
#  'CPX-1686': [],
#  'CPX-1687': [],
#  'CPX-1688': [],
#  'CPX-1689': [],
#  'CPX-1690': [],
#  'CPX-1691': [],
#  'CPX-1692': [],
#  'CPX-1693': [],
#  'CPX-1694': [],
#  'CPX-1695': [],
#  'CPX-1696': [],
#  'CPX-1697': [],
#  'CPX-1698': [],
#  'CPX-1699': [],
#  'CPX-1700': [],
#  'CPX-1701': [],
#  'CPX-1702': [],
#  'CPX-1703': [],
#  'CPX-1705': [],
#  'CPX-1706': [],
#  'CPX-1707': [],
#  'CPX-1708': [],
#  'CPX-1709': [],
#  'CPX-1710': [],
#  'CPX-1711': [],
#  'CPX-1712': [],
#  'CPX-1715': [],
#  'CPX-1716': [],
#  'CPX-1717': [],
#  'CPX-1718': [],
#  'CPX-1719': [],
#  'CPX-1720': [],
#  'CPX-1721': [],
#  'CPX-1722': [],
#  'CPX-1726': [],
#  'CPX-1731': [],
#  'CPX-1732': [],
#  'CPX-1733': [],
#  'CPX-1734': [],
#  'CPX-1735': [],
#  'CPX-1738': [],
#  'CPX-1739': [],
#  'CPX-1740': [],
#  'CPX-1741': [],
#  'CPX-1742': [],
#  'CPX-1743': [],
#  'CPX-1744': [],
#  'CPX-1786': [],
#  'CPX-1792': [],
#  'CPX-1793': [],
#  'CPX-1800': [],
#  'CPX-1805': [],
#  'CPX-1807': [],
#  'CPX-1808': [],
#  'CPX-1810': [],
#  'CPX-1811': [],
#  'CPX-1812': [],
#  'CPX-1813': [],
#  'CPX-1814': [],
#  'CPX-1830': [],
#  'CPX-1831': [],
#  'CPX-1832': [],
#  'CPX-1833': [],
#  'CPX-1834': [],
#  'CPX-1835': [],
#  'CPX-1836': [],
#  'CPX-1837': [],
#  'CPX-1838': [],
#  'CPX-1839': [],
#  'CPX-1840': [],
#  'CPX-1846': [],
#  'CPX-1848': [],
#  'CPX-1849': [],
#  'CPX-1850': [],
#  'CPX-1851': [],
#  'CPX-1852': [],
#  'CPX-1853': [],
#  'CPX-1854': [],
#  'CPX-1855': [],
#  'CPX-1856': [],
#  'CPX-1857': [],
#  'CPX-1858': [],
#  'CPX-1859': [],
#  'CPX-1861': [],
#  'CPX-1862': [],
#  'CPX-1863': [],
#  'CPX-1864': [],
#  'CPX-1865': [],
#  'CPX-1866': [],
#  'CPX-1867': [],
#  'CPX-1868': [],
#  'CPX-1869': [],
#  'CPX-1872': [],
#  'CPX-1873': [],
#  'CPX-1881': [],
#  'CPX-1882': [],
#  'CPX-1883': [],
#  'CPX-1884': [],
#  'CPX-1885': [],
#  'CPX-1886': [],
#  'CPX-1887': [],
#  'CPX-1888': [],
#  'CPX-1889': [],
#  'CPX-1890': [],
#  'CPX-1891': [],
#  'CPX-1893': [],
#  'CPX-1894': [],
#  'CPX-1895': [],
#  'CPX-1896': [],
#  'CPX-1898': [],
#  'CPX-1899': [],
#  'CPX-1900': [],
#  'CPX-1901': [],
#  'CPX-1903': [],
#  'CPX-1904': [],
#  'CPX-1906': [],
#  'CPX-1939': [],
#  'CPX-1940': [],
#  'CPX-1947': [],
#  'CPX-2091': [],
#  'CPX-21': [],
#  'CPX-2101': [],
#  'CPX-2110': [],
#  'CPX-2112': [],
#  'CPX-2122': [],
#  'CPX-2146': [],
#  'CPX-2147': [],
#  'CPX-2148': [],
#  'CPX-2156': [],
#  'CPX-2225': [],
#  'CPX-2262': [],
#  'CPX-2267': [],
#  'CPX-23': [],
#  'CPX-231': [],
#  'CPX-232': [],
#  'CPX-24': [],
#  'CPX-242': [],
#  'CPX-25': [],
#  'CPX-2523': [],
#  'CPX-2541': [],
#  'CPX-2566': [],
#  'CPX-26': [],
#  'CPX-2660': [],
#  'CPX-2662': [],
#  'CPX-2678': [],
#  'CPX-2680': [],
#  'CPX-2723': [],
#  'CPX-2800': [],
#  'CPX-2841': [],
#  'CPX-2854': [],
#  'CPX-2894': [],
#  'CPX-2895': [],
#  'CPX-2896': [],
#  'CPX-29': [],
#  'CPX-2902': [],
#  'CPX-2910': [],
#  'CPX-2911': [],
#  'CPX-2918': [],
#  'CPX-2921': [],
#  'CPX-2923': [],
#  'CPX-2935': [],
#  'CPX-2937': [],
#  'CPX-2944': [],
#  'CPX-2946': [],
#  'CPX-2948': [],
#  'CPX-297': [],
#  'CPX-30': [],
#  'CPX-301': [],
#  'CPX-3028': [],
#  'CPX-3034': [],
#  'CPX-3036': [],
#  'CPX-3037': [],
#  'CPX-3038': [],
#  'CPX-3039': [],
#  'CPX-3055': [],
#  'CPX-3056': [],
#  'CPX-3069': [],
#  'CPX-307': [],
#  'CPX-3070': [],
#  'CPX-3074': [],
#  'CPX-3078': [],
#  'CPX-3087': [],
#  'CPX-3088': [],
#  'CPX-31': [],
#  'CPX-3139': [],
#  'CPX-3146': [],
#  'CPX-3155': [],
#  'CPX-3158': [],
#  'CPX-3159': [],
#  'CPX-3163': [],
#  'CPX-3172': [],
#  'CPX-3179': [],
#  'CPX-3180': [],
#  'CPX-3184': [],
#  'CPX-3185': [],
#  'CPX-3188': [],
#  'CPX-3196': [],
#  'CPX-32': [],
#  'CPX-3211': [],
#  'CPX-3212': [],
#  'CPX-3215': [],
#  'CPX-3226': [],
#  'CPX-3231': [],
#  'CPX-3233': [],
#  'CPX-3234': [],
#  'CPX-3238': [],
#  'CPX-3241': [],
#  'CPX-3242': [],
#  'CPX-3243': [],
#  'CPX-3244': [],
#  'CPX-3248': [],
#  'CPX-3249': [],
#  'CPX-325': [],
#  'CPX-3250': [],
#  'CPX-3253': [],
#  'CPX-3254': [],
#  'CPX-3255': [],
#  'CPX-3265': [],
#  'CPX-3281': [],
#  'CPX-3284': [],
#  'CPX-3294': [],
#  'CPX-3297': [],
#  'CPX-334': [],
#  'CPX-3342': [],
#  'CPX-335': [],
#  'CPX-336': [],
#  'CPX-337': [],
#  'CPX-3384': [],
#  'CPX-339': [],
#  'CPX-342': [],
#  'CPX-3462': [],
#  'CPX-3503': [],
#  'CPX-3541': [],
#  'CPX-36': [],
#  'CPX-361': [],
#  'CPX-3621': [],
#  'CPX-3681': [],
#  'CPX-384': [],
#  'CPX-385': [],
#  'CPX-386': [],
#  'CPX-392': [],
#  'CPX-393': [],
#  'CPX-396': [],
#  'CPX-416': [],
#  'CPX-417': [],
#  'CPX-418': [],
#  'CPX-422': [],
#  'CPX-425': [],
#  'CPX-426': [],
#  'CPX-427': [],
#  'CPX-429': [],
#  'CPX-43': [],
#  'CPX-430': [],
#  'CPX-431': [],
#  'CPX-435': [],
#  'CPX-44': [],
#  'CPX-45': [],
#  'CPX-46': [],
#  'CPX-465': [],
#  'CPX-473': [],
#  'CPX-474': [],
#  'CPX-5304': [],
#  'CPX-532': [],
#  'CPX-5321': [],
#  'CPX-5322': [],
#  'CPX-533': [],
#  'CPX-534': [],
#  'CPX-5341': [],
#  'CPX-535': [],
#  'CPX-536': [],
#  'CPX-537': [],
#  'CPX-539': [],
#  'CPX-5401': [],
#  'CPX-5421': [],
#  'CPX-5422': [],
#  'CPX-5423': [],
#  'CPX-5424': [],
#  'CPX-544': [],
#  'CPX-5441': [],
#  'CPX-5442': [],
#  'CPX-545': [],
#  'CPX-5461': [],
#  'CPX-5462': [],
#  'CPX-5463': [],
#  'CPX-5464': [],
#  'CPX-5465': [],
#  'CPX-5466': [],
#  'CPX-548': [],
#  'CPX-5521': [],
#  'CPX-554': [],
#  'CPX-558': [],
#  'CPX-565': [],
#  'CPX-567': [],
#  'CPX-568': [],
#  'CPX-571': [],
#  'CPX-572': [],
#  'CPX-573': [],
#  'CPX-574': [],
#  'CPX-575': [],
#  'CPX-576': [],
#  'CPX-579': [],
#  'CPX-580': [],
#  'CPX-581': [],
#  'CPX-582': [],
#  'CPX-583': [],
#  'CPX-588': [],
#  'CPX-590': [],
#  'CPX-599': [],
#  'CPX-603': [],
#  'CPX-607': [],
#  'CPX-608': [],
#  'CPX-609': [],
#  'CPX-6127': [],
#  'CPX-636': [],
#  'CPX-637': [],
#  'CPX-656': [],
#  'CPX-6643': [],
#  'CPX-675': [],
#  'CPX-6864': [],
#  'CPX-6865': [],
#  'CPX-692': [],
#  'CPX-6921': [],
#  'CPX-6924': [],
#  'CPX-6928': [],
#  'CPX-693': [],
#  'CPX-6930': [],
#  'CPX-6937': [],
#  'CPX-695': [],
#  'CPX-6957': [],
#  'CPX-728': [],
#  'CPX-729': [],
#  'CPX-734': [],
#  'CPX-737': [],
#  'CPX-756': [],
#  'CPX-760': [],
#  'CPX-761': [],
#  'CPX-762': [],
#  'CPX-768': [],
#  'CPX-769': [],
#  'CPX-770': [],
#  'CPX-771': [],
#  'CPX-772': [],
#  'CPX-773': [],
#  'CPX-774': [],
#  'CPX-775': [],
#  'CPX-776': [],
#  'CPX-777': [],
#  'CPX-778': [],
#  'CPX-779': [],
#  'CPX-780': [],
#  'CPX-781': [],
#  'CPX-782': [],
#  'CPX-783': [],
#  'CPX-784': [],
#  'CPX-824': [],
#  'CPX-828': [],
#  'CPX-863': [],
#  'CPX-867': [],
#  'CPX-868': [],
#  'CPX-869': [],
#  'CPX-940': [],
#  'CPX-946': [],
#  'CPX-950': [],
#  'CPX-956': [],
#  'CPX-961': [],
#  'CPX-962': [],
#  'CPX-963': [],
#  'CPX-964': [],
#  'CPX-977': [],
#  'CPX-995': [],
#  'CPX-999': [],
#  'None': []}

# %%
## Sort ORFs from interactorA column

# Pair ORF to list of complexes it is part of:
InteractorA_assign = zip(Modular_PPI_Network_DF["source_locus"], Modular_PPI_Network_DF["source_Complex"])

for ORF, CPX_ls in InteractorA_assign: # For every ORF and list of complexes
    for CPX in CPX_ls: # For every complex in list of complexes
        if (ORF not in PPI_module_dict[CPX]): # If the Complexes exists (i.e. ORF is in a complex)
            PPI_module_dict[CPX].append(ORF) # Assign ORF to complex in dictionnary

## Sort ORFs from interactorB column

# Pair ORF to list of complexes it is part of:
InteractorB_assign = zip(Modular_PPI_Network_DF["target_locus"], Modular_PPI_Network_DF["target_Complex"])

for ORF, CPX_ls in InteractorB_assign: # For every ORF and list of complexes
    for CPX in CPX_ls: # For every complex in list of complexes
        if (ORF not in PPI_module_dict[CPX]): # If the Complexes exists (i.e. ORF is in a complex) and ORF is not in dict
            PPI_module_dict[CPX].append(ORF) # Assign ORF to complex in dictionnary
            
PPI_module_dict
# Out:
# {'CPX-1015': ['YNL103W'],
#  'CPX-1016': ['YNL103W'],
#  'CPX-1018': ['YAL026C', 'YCR094W'],
#  'CPX-1021': ['YER166W', 'YNL323W'],
#  'CPX-1022': ['YDR093W', 'YNL323W'],
#  'CPX-1026': ['YMR162C', 'YNR048W'],
#  'CPX-1028': ['YDR141C', 'YBR164C', 'YNL297C'],
#  'CPX-1036': ['YCR092C', 'YOL090W'],
#  'CPX-1037': ['YDR097C', 'YOL090W'],
#  'CPX-1039': ['YPL138C',
#   'YHR119W',
#   'YLR015W',
#   'YBR258C',
#   'YDR469W',
#   'YAR003W',
#   'YBR175W',
#   'YKL018W'],
#  'CPX-1040': ['YGL213C', 'YLR398C', 'YPR189W'],
#  'CPX-1041': ['YDR016C',
#   'YKR083C',
#   'YKR037C',
#   'YGL061C',
#   'YKL052C',
#   'YBR233W-A',
#   'YDR320C-A',
#   'YGR113W',
#   'YDR201W',
#   'YKL138C-A'],
#  'CPX-1042': ['YML051W'],
#  'CPX-1043': ['YML051W'],
#  'CPX-1044': ['YML051W'],
#  'CPX-1045': ['YML067C', 'YAL042W'],
#  'CPX-1047': ['YNR046W', 'YCR047C'],
#  'CPX-1052': ['YML014W', 'YNR046W'],
#  'CPX-1053': ['YNL317W',
#   'YPR107C',
#   'YLR277C',
#   'YKR002W',
#   'YLR115W',
#   'YKL018W',
#   'YKL059C',
#   'YGR156W',
#   'YJR093C',
#   'YDR301W',
#   'YAL043C',
#   'YDR195W',
#   'YOR179C',
#   'YER133W',
#   'YNL222W'],
#  'CPX-1068': ['YLR347C', 'YNL189W'],
#  'CPX-1071': ['YPL024W', 'YLR234W', 'YMR190C'],
#  'CPX-1101': ['YBL025W',
#   'YNL031C',
#   'YNL030W',
#   'YBR009C',
#   'YBR010W',
#   'YOR295W',
#   'YLR141W',
#   'YMR270C'],
#  'CPX-1102': ['YER070W', 'YGR180C', 'YJL026W'],
#  'CPX-1103': ['YER070W', 'YGR180C', 'YJL026W', 'YIL066C'],
#  'CPX-112': ['YNL147W',
#   'YJL124C',
#   'YER112W',
#   'YDR378C',
#   'YCR077C',
#   'YBL026W',
#   'YLR438C-A',
#   'YER146W'],
#  'CPX-1125': ['YDL099W', 'YDR517W'],
#  'CPX-1140': ['YMR032W', 'YDL117W'],
#  'CPX-1141': ['YER148W', 'YPL082C'],
#  'CPX-1142': ['YKL186C', 'YPL169C'],
#  'CPX-1143': ['YER148W', 'YGR246C', 'YNL039W'],
#  'CPX-1149': ['YPL129W', 'YGR186W', 'YGR005C'],
#  'CPX-1150': ['YPR034W',
#   'YPL129W',
#   'YGR275W',
#   'YOR290C',
#   'YPL016W',
#   'YNR023W',
#   'YHL025W',
#   'YJL176C',
#   'YFL049W',
#   'YBR289W',
#   'YMR033W'],
#  'CPX-1151': ['YJL071W'],
#  'CPX-1152': ['YMR043W', 'YMR042W', 'YDR173C', 'YML099C'],
#  'CPX-1153': ['YNL086W',
#   'YLR408C',
#   'YKL061W',
#   'YGL079W',
#   'YEL005C',
#   'YDR357C'],
#  'CPX-1155': ['YGR255C',
#   'YLR201C',
#   'YDR204W',
#   'YML110C',
#   'YOL096C',
#   'YOR125C'],
#  'CPX-1156': ['YAL034W-A',
#   'YLR315W',
#   'YLR381W',
#   'YJR135C',
#   'YDR254W',
#   'YGR179C',
#   'YDR318W',
#   'YPL018W',
#   'YBR107C',
#   'YBR211C',
#   'YDR383C',
#   'YPR046W'],
#  'CPX-1157': ['YJL047C', 'YHR154W', 'YPR164W'],
#  'CPX-1162': ['YKL182W', 'YPL231W'],
#  'CPX-1165': ['YJL047C', 'YPR135W', 'YPR164W'],
#  'CPX-1166': ['YJL047C', 'YPR164W'],
#  'CPX-1167': ['YNL261W', 'YJL047C', 'YPR164W'],
#  'CPX-1178': ['YMR299C', 'YKR054C', 'YDR424C'],
#  'CPX-1179': ['YLR270W'],
#  'CPX-1185': ['YLR270W', 'YOR173W'],
#  'CPX-1186': ['YJR112W', 'YIR010W', 'YAL034W-A', 'YPL233W'],
#  'CPX-1187': ['YGR179C', 'YDR318W', 'YPL018W', 'YBR211C'],
#  'CPX-1188': ['YGL113W'],
#  'CPX-1189': ['YJR035W', 'YKL054C'],
#  'CPX-1190': ['YDL091C', 'YKL034W'],
#  'CPX-1191': ['YJR052W', 'YGR003W', 'YBR114W', 'YPL046C'],
#  'CPX-1192': ['YHR026W',
#   'YGR106C',
#   'YLR447C',
#   'YPR036W',
#   'YOR332W',
#   'YKL080W',
#   'YHR039C-A',
#   'YGR020C',
#   'YEL051W',
#   'YBR127C',
#   'YDL185W',
#   'YMR054W',
#   'YEL027W',
#   'YPL234C'],
#  'CPX-1193': ['YHR026W',
#   'YGR106C',
#   'YLR447C',
#   'YPR036W',
#   'YOR270C',
#   'YOR332W',
#   'YKL080W',
#   'YHR039C-A',
#   'YGR020C',
#   'YEL051W',
#   'YBR127C',
#   'YDL185W',
#   'YEL027W',
#   'YPL234C'],
#  'CPX-1197': ['YNL127W',
#   'YMR029C',
#   'YMR052W',
#   'YFR008W',
#   'YDR200C',
#   'YLR238W'],
#  'CPX-1198': ['YHR172W', 'YLR212C', 'YNL126W'],
#  'CPX-1200': ['YPL075W', 'YNL216W'],
#  'CPX-1229': ['YPL075W', 'YNL216W', 'YNL199C'],
#  'CPX-1230': ['YER133W', 'YNL233W'],
#  'CPX-1231': ['YER133W', 'YOR178C'],
#  'CPX-124': ['YJR140C', 'YBR215W', 'YBL008W', 'YOR038C'],
#  'CPX-1249': ['YER133W', 'YKL193C'],
#  'CPX-1260': ['YER133W', 'YKL193C'],
#  'CPX-1266': ['YER133W', 'YDR028C'],
#  'CPX-1267': ['YER133W'],
#  'CPX-1268': ['YAL044C', 'YFL018C', 'YMR189W', 'YDR019C'],
#  'CPX-1270': ['YJR013W', 'YCL052C'],
#  'CPX-1274': ['YPL076W', 'YDR437W', 'YPL175W', 'YGR216C'],
#  'CPX-1275': ['YLR088W', 'YDR331W', 'YDR434W', 'YHR188C'],
#  'CPX-1276': ['YMR186W',
#   'YLL024C',
#   'YAL005C',
#   'YPL240C',
#   'YNL064C',
#   'YCL037C'],
#  'CPX-1278': ['YLR043C', 'YNL015W'],
#  'CPX-1279': ['YGR209C', 'YNL015W'],
#  'CPX-1280': ['YDR057W', 'YJL034W', 'YLR207W'],
#  'CPX-1283': ['YCL043C'],
#  'CPX-1287': ['YPL255W', 'YGL075C'],
#  'CPX-1293': ['YFR049W', 'YFL018C', 'YDR148C', 'YIL125W'],
#  'CPX-1294': ['YML091C'],
#  'CPX-1295': ['YGR178C', 'YNL085W'],
#  'CPX-1302': ['YPR075C'],
#  'CPX-1304': ['YOR326W', 'YEL013W', 'YCL063W'],
#  'CPX-1306': ['YHR193C', 'YPL037C'],
#  'CPX-1307': ['YHR193C', 'YDR252W'],
#  'CPX-1314': ['YLR382C'],
#  'CPX-1315': ['YGR072W', 'YMR080C', 'YHR077C'],
#  'CPX-1316': ['YNL251C', 'YLR430W', 'YPL190C'],
#  'CPX-1317': ['YLL010C', 'YOR043W'],
#  'CPX-1318': ['YOR043W'],
#  'CPX-1319': ['YNL264C', 'YGR170W'],
#  'CPX-1320': ['YEL037C', 'YPL096W'],
#  'CPX-1322': ['YJL115W', 'YPL153C'],
#  'CPX-1323': ['YEL037C', 'YDL126C', 'YDL190C'],
#  'CPX-1332': ['YGL246C', 'YOR048C'],
#  'CPX-1333': ['YLL002W', 'YNL246W'],
#  'CPX-1335': ['YCR009C', 'YDR388W'],
#  'CPX-1341': ['YHR098C', 'YPR181C'],
#  'CPX-1342': ['YDR155C',
#   'YOL068C',
#   'YIL112W',
#   'YCR033W',
#   'YGL194C',
#   'YBR103W',
#   'YKR029C'],
#  'CPX-1344': ['YBL007C', 'YOR181W'],
#  'CPX-1355': ['YHR154W', 'YLR135W'],
#  'CPX-1362': ['YML095C', 'YLR135W', 'YPL022W'],
#  'CPX-1363': ['YML095C', 'YAL027W', 'YPL022W'],
#  'CPX-1364': ['YER038C',
#   'YLR383W',
#   'YOL034W',
#   'YEL019C',
#   'YDL105W',
#   'YDR288W',
#   'YLR007W',
#   'YML023C'],
#  'CPX-1365': ['YPL232W', 'YGR009C', 'YAL030W'],
#  'CPX-1369': ['YMR183C', 'YGR009C', 'YAL030W'],
#  'CPX-1372': ['YGL131C', 'YNL330C', 'YMR176W'],
#  'CPX-1377': ['YDL113C', 'YJL036W'],
#  'CPX-1378': ['YDR425W', 'YJL036W'],
#  'CPX-1379': ['YGR244C', 'YOR142W'],
#  'CPX-1380': ['YDL134C', 'YMR028W'],
#  'CPX-1381': ['YHR195W', 'YEL013W'],
#  'CPX-1382': ['YDL188C', 'YMR028W'],
#  'CPX-1383': ['YOR115C',
#   'YKR068C',
#   'YDR246W',
#   'YDR472W',
#   'YBR254C',
#   'YDR108W',
#   'YML077W'],
#  'CPX-1384': ['YDR310C', 'YOL068C', 'YOR279C'],
#  'CPX-1386': ['YGL249W'],
#  'CPX-140': ['YNL100W', 'YFR011C', 'YKR016W', 'YGR235C', 'YCL057C-A'],
#  'CPX-1408': ['YIL026C', 'YFL008W', 'YJL074C'],
#  'CPX-1409': ['YPL126W',
#   'YMR093W',
#   'YJL109C',
#   'YHR196W',
#   'YGR128C',
#   'YDR398W',
#   'YDR324C'],
#  'CPX-1410': ['YLR409C',
#   'YLR222C',
#   'YLR129W',
#   'YJL069C',
#   'YDR449C',
#   'YCR057C'],
#  'CPX-1412': ['YER151C', 'YNR051C'],
#  'CPX-1413': ['YOL129W', 'YJR044C'],
#  'CPX-1415': ['YDR207C'],
#  'CPX-1417': ['YKL074C', 'YLR116W'],
#  'CPX-1418': ['YLR147C',
#   'YGR074W',
#   'YPR182W',
#   'YLR275W',
#   'YER029C',
#   'YKL074C',
#   'YFL017W-A',
#   'YML046W',
#   'YIL061C',
#   'YLR298C',
#   'YDR240C',
#   'YGR013W',
#   'YDL087C',
#   'YDR235W',
#   'YBR119W',
#   'YOR159C',
#   'YHR086W',
#   'YKL012W',
#   'YLR116W'],
#  'CPX-1419': ['YKL042W', 'YDR356W', 'YBR109C', 'YPL124W'],
#  'CPX-1420': ['YKL042W', 'YNL225C'],
#  'CPX-1421': ['YKL014C', 'YJR041C', 'YNR038W', 'YLR221C', 'YOL144W'],
#  'CPX-1422': ['YJR136C', 'YKL033W', 'YGR099W'],
#  'CPX-1423': ['YLR203C', 'YJR045C', 'YJL062W-A'],
#  'CPX-1424': ['YML085C', 'YFL037W'],
#  'CPX-1425': ['YML124C', 'YFL037W'],
#  'CPX-1426': ['YHR023W', 'YGL106W', 'YPR188C'],
#  'CPX-1470': ['YMR109W', 'YBR109C'],
#  'CPX-1500': ['YKL129C', 'YBR109C'],
#  'CPX-1501': ['YAL029C', 'YBR109C', 'YGL106W'],
#  'CPX-154': ['YOR026W', 'YGR188C'],
#  'CPX-1556': ['YPR019W',
#   'YLR274W',
#   'YDR013W',
#   'YBL023C',
#   'YBR202W',
#   'YLR103C',
#   'YGL201C',
#   'YEL032W',
#   'YDR489W',
#   'YDR121W',
#   'YNL262W',
#   'YBR278W',
#   'YOL146W',
#   'YJL072C',
#   'YPR175W'],
#  'CPX-1599': ['YNL096C',
#   'YGR027C',
#   'YBR189W',
#   'YPL090C',
#   'YOR182C',
#   'YOR167C',
#   'YMR230W',
#   'YMR143W',
#   'YML026C',
#   'YML024W',
#   'YLR367W',
#   'YLR333C',
#   'YLR287C-A',
#   'YKL156W',
#   'YJR145C',
#   'YJL190C',
#   'YIL069C',
#   'YHR203C',
#   'YHR021C',
#   'YER102W',
#   'YER074W',
#   'YDR447C',
#   'YGL189C',
#   'YER131W',
#   'YBR181C',
#   'YPL081W',
#   'YLR264W',
#   'YDL061C',
#   'YOR369C',
#   'YOL121C',
#   'YOR096W',
#   'YNL302C',
#   'YOL040C',
#   'YNL178W',
#   'YMR116C',
#   'YML063W',
#   'YLR441C',
#   'YLR388W',
#   'YKR057W',
#   'YLR048W',
#   'YJR123W',
#   'YJL136C',
#   'YHL015W',
#   'YGL123W',
#   'YGR214W',
#   'YDR064W',
#   'YCR031C',
#   'YBL072C',
#   'YPR132W',
#   'YOR293W',
#   'YBR048W',
#   'YDL083C',
#   'YGR118W',
#   'YDR450W',
#   'YDR025W',
#   'YJL191W',
#   'YLR167W'],
#  'CPX-1601': ['YOL039W',
#   'YHL001W',
#   'YBL027W',
#   'YPL249C-A',
#   'YPL079W',
#   'YNL067W',
#   'YMR142C',
#   'YML073C',
#   'YLR406C',
#   'YLR448W',
#   'YLR325C',
#   'YLR344W',
#   'YLR185W',
#   'YLL045C',
#   'YLR075W',
#   'YHL033C',
#   'YGR148C',
#   'YGL031C',
#   'YFL034C-A',
#   'YDL081C',
#   'YDL130W',
#   'YDL075W',
#   'YBL092W',
#   'YPL131W',
#   'YPL143W',
#   'YOR063W',
#   'YNL069C',
#   'YLR340W',
#   'YLR061W',
#   'YKL180W',
#   'YLR029C',
#   'YJL189W',
#   'YKL006W',
#   'YIL133C',
#   'YJL177W',
#   'YGR034W',
#   'YIL052C',
#   'YGL147C',
#   'YGL030W',
#   'YGL076C',
#   'YER056C-A',
#   'YDR382W',
#   'YBR191W',
#   'YBR031W',
#   'YPR102C',
#   'YPR043W',
#   'YPL220W',
#   'YPL198W',
#   'YOR312C',
#   'YOR234C',
#   'YNL301C',
#   'YMR242C',
#   'YMR194W',
#   'YJR094W-A',
#   'YGR085C',
#   'YFR031C-A',
#   'YFR032C-A',
#   'YDR500C',
#   'YDR471W',
#   'YDR418W',
#   'YDL191W',
#   'YDL184C',
#   'YDL136W',
#   'YDL133C-A',
#   'YDL082W',
#   'YDR012W',
#   'YBR084C-A',
#   'YGL103W',
#   'YKR094C',
#   'YHR141C',
#   'YHR010W',
#   'YGL135W',
#   'YIL018W',
#   'YOL120C',
#   'YNL162W',
#   'YIL148W',
#   'YMR121C',
#   'YER117W',
#   'YEL054C',
#   'YBL087C'],
#  'CPX-1602': ['YNL185C',
#   'YNL284C',
#   'YMR193W',
#   'YNL122C',
#   'YML025C',
#   'YKL167C',
#   'YLR439W',
#   'YGR076C',
#   'YHR147C',
#   'YGL068W',
#   'YDR237W',
#   'YEL050C',
#   'YDL202W',
#   'YDR115W',
#   'YBR268W',
#   'YCR003W',
#   'YBL038W',
#   'YPR100W',
#   'YNR022C',
#   'YOR150W',
#   'YNL177C',
#   'YNL252C',
#   'YNL005C',
#   'YMR024W',
#   'YMR286W',
#   'YLR312W-A',
#   'YML009C',
#   'YKR006C',
#   'YKR085C',
#   'YKL138C',
#   'YKL170W',
#   'YJL063C',
#   'YJL096W',
#   'YGR220C',
#   'YDR405W',
#   'YDR462W',
#   'YDR322W',
#   'YDR116C',
#   'YDR296W',
#   'YCR046C',
#   'YCR071C',
#   'YBR122C',
#   'YBR282W',
#   'YPL183W-A',
#   'YPL173W',
#   'YMR225C'],
#  'CPX-1603': ['YDR036C',
#   'YPL013C',
#   'YPL118W',
#   'YNR037C',
#   'YOR158W',
#   'YNL306W',
#   'YNR036C',
#   'YNL081C',
#   'YMR158W',
#   'YMR188C',
#   'YKL003C',
#   'YJR101W',
#   'YJR113C',
#   'YIL093C',
#   'YHL004W',
#   'YHR059W',
#   'YGR165W',
#   'YGR215W',
#   'YGL129C',
#   'YGR084C',
#   'YDR494W',
#   'YER050C',
#   'YDR337W',
#   'YDR347W',
#   'YDR041W',
#   'YDR175C',
#   'YBR251W',
#   'YDL045W-A',
#   'Q0140',
#   'YBR146W',
#   'YBL090W',
#   'YNL137C',
#   'YPR166C'],
#  'CPX-1604': ['YKL009W',
#   'YGR081C',
#   'YPR137W',
#   'YPR144C',
#   'YPL126W',
#   'YPL217C',
#   'YOR310C',
#   'YOR078W',
#   'YNR054C',
#   'YOL010W',
#   'YNL075W',
#   'YNL132W',
#   'YMR128W',
#   'YMR229C',
#   'YLR409C',
#   'YMR093W',
#   'YLR197W',
#   'YLR222C',
#   'YLR129W',
#   'YKR060W',
#   'YLL011W',
#   'YJR002W',
#   'YKL099C',
#   'YJL069C',
#   'YJL109C',
#   'YIL091C',
#   'YHR196W',
#   'YGR128C',
#   'YGR090W',
#   'YER127W',
#   'YGL171W',
#   'YER082C',
#   'YDR398W',
#   'YDR449C',
#   'YDR324C',
#   'YDR339C',
#   'YDL148C',
#   'YDL153C',
#   'YCR057C',
#   'YCL059C',
#   'YBR247C',
#   'YCL031C',
#   'YML093W',
#   'YBL004W',
#   'YLR186W',
#   'YJL010C',
#   'YGR280C',
#   'YGL120C',
#   'YHR169W',
#   'YDL014W',
#   'YGR159C',
#   'YOR039W',
#   'YGL019W',
#   'YJL033W',
#   'YDR365C',
#   'YLR336C',
#   'YIL035C',
#   'YOR004W',
#   'YDL213C',
#   'YLR430W',
#   'YKL143W',
#   'YOR061W',
#   'YMR290C',
#   'YOR287C',
#   'YHR148W',
#   'YKL078W',
#   'YEL026W',
#   'YEL055C',
#   'YPR112C'],
#  'CPX-1606': ['YPL217C', 'YOL010W'],
#  'CPX-1607': ['YKL009W',
#   'YGR081C',
#   'YPR137W',
#   'YPR144C',
#   'YPL126W',
#   'YPL217C',
#   'YOR310C',
#   'YOR078W',
#   'YNR054C',
#   'YOL010W',
#   'YNL075W',
#   'YNL132W',
#   'YMR128W',
#   'YMR229C',
#   'YLR409C',
#   'YMR093W',
#   'YLR197W',
#   'YLR222C',
#   'YLR129W',
#   'YKR060W',
#   'YLL011W',
#   'YJR002W',
#   'YKL099C',
#   'YJL069C',
#   'YJL109C',
#   'YIL091C',
#   'YHR196W',
#   'YGR128C',
#   'YGR090W',
#   'YER127W',
#   'YGL171W',
#   'YER082C',
#   'YDR398W',
#   'YDR449C',
#   'YDR324C',
#   'YDR339C',
#   'YDL148C',
#   'YDL153C',
#   'YCR057C',
#   'YCL059C',
#   'YBR247C',
#   'YCL031C',
#   'YML093W',
#   'YBL004W',
#   'YLR186W',
#   'YJL010C',
#   'YGR280C',
#   'YGL120C',
#   'YHR169W',
#   'YDL014W',
#   'YGR159C',
#   'YOR039W',
#   'YGL019W',
#   'YJL033W',
#   'YDR365C',
#   'YLR336C',
#   'YIL035C',
#   'YOR004W',
#   'YDL213C',
#   'YLR430W',
#   'YKL143W',
#   'YMR290C',
#   'YOR287C',
#   'YHR148W',
#   'YKL078W',
#   'YEL026W',
#   'YEL055C',
#   'YPR112C'],
#  'CPX-1608': ['YKL009W',
#   'YGR081C',
#   'YPR137W',
#   'YPR144C',
#   'YPL126W',
#   'YPL217C',
#   'YOR310C',
#   'YOR078W',
#   'YNR054C',
#   'YOL010W',
#   'YNL075W',
#   'YNL132W',
#   'YMR128W',
#   'YMR229C',
#   'YLR409C',
#   'YMR093W',
#   'YLR197W',
#   'YLR222C',
#   'YLR129W',
#   'YKR060W',
#   'YLL011W',
#   'YJR002W',
#   'YKL099C',
#   'YJL069C',
#   'YJL109C',
#   'YIL091C',
#   'YHR196W',
#   'YGR128C',
#   'YGR090W',
#   'YER127W',
#   'YGL171W',
#   'YER082C',
#   'YDR398W',
#   'YDR449C',
#   'YDR324C',
#   'YDR339C',
#   'YDL148C',
#   'YDL153C',
#   'YCR057C',
#   'YCL059C',
#   'YBR247C',
#   'YCL031C',
#   'YML093W',
#   'YBL004W',
#   'YLR186W',
#   'YJL010C',
#   'YGR280C',
#   'YGL120C',
#   'YHR169W',
#   'YDL014W',
#   'YGR159C',
#   'YOR039W',
#   'YGL019W',
#   'YJL033W',
#   'YDR365C',
#   'YLR336C',
#   'YOR004W',
#   'YDL213C',
#   'YLR430W',
#   'YKL143W',
#   'YOR061W',
#   'YMR290C',
#   'YOR287C',
#   'YHR148W',
#   'YKL078W',
#   'YEL026W',
#   'YEL055C',
#   'YPR112C'],
#  'CPX-161': ['YBR179C'],
#  'CPX-1610': ['YBL003C',
#   'YNL031C',
#   'YNL030W',
#   'YBR009C',
#   'YBR010W',
#   'YBL002W'],
#  'CPX-1611': ['YBL003C',
#   'YNL031C',
#   'YNL030W',
#   'YBR009C',
#   'YBR010W',
#   'YDR224C'],
#  'CPX-1612': ['YNL031C',
#   'YNL030W',
#   'YBR009C',
#   'YBR010W',
#   'YDR224C',
#   'YDR225W'],
#  'CPX-1613': ['YNL031C',
#   'YNL030W',
#   'YBR009C',
#   'YBR010W',
#   'YDR224C',
#   'YOL012C'],
#  'CPX-1614': ['YNL031C',
#   'YNL030W',
#   'YBR009C',
#   'YBR010W',
#   'YBL002W',
#   'YOL012C'],
#  'CPX-1616': ['YGL206C', 'YGR167W'],
#  'CPX-162': ['YBR002C', 'YDL193W'],
#  'CPX-1622': ['YHL002W', 'YNR006W'],
#  'CPX-1623': ['YPL002C', 'YLR417W', 'YJR102C'],
#  'CPX-1624': ['YKL002W', 'YKL041W', 'YLR025W', 'YMR077C'],
#  'CPX-1625': ['YDR080W',
#   'YDL077C',
#   'YLR396C',
#   'YMR231W',
#   'YLR148W',
#   'YPL045W'],
#  'CPX-1626': ['YLR396C',
#   'YMR231W',
#   'YDR495C',
#   'YLR148W',
#   'YAL002W',
#   'YPL045W'],
#  'CPX-1627': ['YDR328C', 'YDR202C', 'YJR033C'],
#  'CPX-1628': ['YNL118C', 'YOL149W'],
#  'CPX-1629': ['YOR297C', 'YJL054W'],
#  'CPX-1630': ['YHR024C', 'YLR163C'],
#  'CPX-1631': ['YJL125C', 'YNL062C'],
#  'CPX-1632': ['YDL201W', 'YDR165W'],
#  'CPX-1633': ['YKL058W', 'YOR194C'],
#  'CPX-1634': ['YDL090C', 'YKL019W'],
#  'CPX-1635': ['YGL155W', 'YKL019W'],
#  'CPX-1636': ['YOR370C'],
#  'CPX-1637': ['YIL034C', 'YKL007W'],
#  'CPX-1638': ['YMR149W',
#   'YJL002C',
#   'YGL022W',
#   'YEL002C',
#   'YGL226C-A',
#   'YDL232W',
#   'YOR103C',
#   'YML019W'],
#  'CPX-1639': ['YMR149W',
#   'YJL002C',
#   'YGL022W',
#   'YEL002C',
#   'YGL226C-A',
#   'YDL232W',
#   'YOR103C',
#   'YOR085W'],
#  'CPX-1640': ['YEL037C', 'YER162C'],
#  'CPX-1641': ['YDR013W', 'YDR489W', 'YOL146W', 'YJL072C'],
#  'CPX-1642': ['YPL129W',
#   'YER148W',
#   'YPL011C',
#   'YMR227C',
#   'YML015C',
#   'YML114C',
#   'YCR042C',
#   'YGR274C',
#   'YDR167W',
#   'YML098W',
#   'YMR236W',
#   'YGL112C',
#   'YDR145W',
#   'YBR198C',
#   'YMR005W'],
#  'CPX-1643': ['YBR070C'],
#  'CPX-1645': ['YJR086W', 'YOR212W'],
#  'CPX-1646': ['YHR005C', 'YJR086W', 'YOR212W'],
#  'CPX-1647': ['YMR288W', 'YOR319W', 'YMR240C', 'YML049C', 'YPR094W'],
#  'CPX-1648': ['YDL043C', 'YJL203W', 'YDL030W'],
#  'CPX-1649': ['YIR005W', 'YGL174W', 'YLR016C'],
#  'CPX-1651': ['YNL245C',
#   'YLR147C',
#   'YGR074W',
#   'YIR005W',
#   'YPR182W',
#   'YDL043C',
#   'YPR101W',
#   'YPL151C',
#   'YPL213W',
#   'YMR288W',
#   'YMR213W',
#   'YMR240C',
#   'YLR275W',
#   'YML049C',
#   'YLL036C',
#   'YLR117C',
#   'YKL095W',
#   'YKL173W',
#   'YJL203W',
#   'YJR050W',
#   'YGR278W',
#   'YHR165C',
#   'YGR129W',
#   'YER172C',
#   'YGL174W',
#   'YDR482C',
#   'YER029C',
#   'YDR364C',
#   'YDR416W',
#   'YDR088C',
#   'YDR163W',
#   'YDL030W',
#   'YDL209C',
#   'YBR188C',
#   'YCR063W',
#   'YAL032C',
#   'YBR065C',
#   'YLR323C',
#   'YGL128C',
#   'YIR009W',
#   'YPL064C',
#   'YOR148C',
#   'YER013W'],
#  'CPX-1652': ['YNL287W',
#   'YGL137W',
#   'YIL076W',
#   'YFR051C',
#   'YDR238C',
#   'YDL145C',
#   'YPL010W'],
#  'CPX-1653': ['YOR069W', 'YHR012W', 'YJL154C', 'YJL053W', 'YOR132W'],
#  'CPX-1654': ['YER017C', 'YMR089C'],
#  'CPX-1655': ['YMR115W', 'YPR024W', 'YCL044C'],
#  'CPX-1656': ['YGR047C',
#   'YOR110W',
#   'YDR362C',
#   'YAL001C',
#   'YBR123C',
#   'YPL007C'],
#  'CPX-1657': ['YMR125W', 'YPL178W'],
#  'CPX-1658': ['YKL028W', 'YKR062W'],
#  'CPX-1659': ['YDR079C-A',
#   'YLR005W',
#   'YPL122C',
#   'YIL143C',
#   'YOR352W',
#   'YDR460W',
#   'YER171W',
#   'YDL108W',
#   'YDR311W',
#   'YPR056W',
#   'YPR025C'],
#  'CPX-166': ['YDL193W'],
#  'CPX-1660': ['YDR460W', 'YDL108W', 'YPR025C'],
#  'CPX-1661': ['YGR063C', 'YML010W'],
#  'CPX-1662': ['YDR397C', 'YER159C'],
#  'CPX-1663': ['YBR112C', 'YCR084C'],
#  'CPX-1664': ['YOR340C',
#   'YOR341W',
#   'YJL148W',
#   'YNL248C',
#   'YDR156W',
#   'YPR110C',
#   'YPR187W',
#   'YPR010C',
#   'YOR210W',
#   'YOR224C',
#   'YNL113W',
#   'YJR063W',
#   'YHR143W-A',
#   'YBR154C'],
#  'CPX-1665': ['YGL090W'],
#  'CPX-1666': ['YNL082W', 'YMR167W'],
#  'CPX-1667': ['YMR167W', 'YLR035C'],
#  'CPX-1668': ['YMR167W'],
#  'CPX-1669': ['YJL076W', 'YFR028C', 'YDL042C'],
#  'CPX-1671': ['YJL179W',
#   'YML094W',
#   'YGR078C',
#   'YLR200W',
#   'YEL003W',
#   'YNL153C'],
#  'CPX-1672': ['YML115C', 'YPL050C'],
#  'CPX-1673': ['YMR048W', 'YNL273W'],
#  'CPX-1674': ['YBR131W', 'YGL124C'],
#  'CPX-1675': ['YJR076C', 'YHR107C', 'YCR002C', 'YDL225W', 'YLR314C'],
#  'CPX-1676': ['YGL180W', 'YPR185W'],
#  'CPX-1677': ['YBR097W', 'YLR240W', 'YLR360W', 'YPL120W'],
#  'CPX-1678': ['YJL050W', 'YIL079C', 'YOL115W'],
#  'CPX-1679': ['YJL050W', 'YDL175C', 'YOL115W'],
#  'CPX-1680': ['YJL050W', 'YIL079C', 'YNL299W'],
#  'CPX-1681': ['YDR439W', 'YPL204W'],
#  'CPX-1682': ['YEL056W', 'YLL022C', 'YPL001W'],
#  'CPX-1683': ['YIL106W', 'YGR092W'],
#  'CPX-1684': ['YFL034C-B', 'YNL161W'],
#  'CPX-1685': ['YLR226W', 'YPR161C'],
#  'CPX-1686': ['YOL072W', 'YDR363W-A', 'YBR111W-A', 'YOR257W', 'YDR159W'],
#  'CPX-1687': ['YOL072W', 'YDR159W'],
#  'CPX-1688': ['YOL001W', 'YPL031C'],
#  'CPX-1689': ['YPL031C', 'YER059W'],
#  'CPX-1690': ['YIL050W', 'YPL031C'],
#  'CPX-1691': ['YPL031C', 'YPL219W'],
#  'CPX-1692': ['YGL134W', 'YPL031C'],
#  'CPX-1693': ['YPL031C'],
#  'CPX-1694': ['YPL031C'],
#  'CPX-1695': ['YPL031C'],
#  'CPX-1696': ['YPL031C'],
#  'CPX-1697': ['YPL031C'],
#  'CPX-1698': ['YGL200C', 'YAR002C-A', 'YAL007C', 'YML012W'],
#  'CPX-1699': ['YBR135W', 'YBR160W', 'YMR199W'],
#  'CPX-1700': ['YBR135W', 'YBR160W'],
#  'CPX-1701': ['YBR160W', 'YPR119W'],
#  'CPX-1702': ['YBR160W', 'YPR120C'],
#  'CPX-1703': ['YGR132C', 'YGR231C'],
#  'CPX-1705': ['YER133W', 'YAR014C'],
#  'CPX-1706': ['YKL008C', 'YHL003C', 'YMR298W'],
#  'CPX-1707': ['YPL111W'],
#  'CPX-1708': ['YML095C', 'YPL022W'],
#  'CPX-1709': ['YJR052W', 'YBR114W', 'YKL112W'],
#  'CPX-1710': ['YKL139W', 'YJL006C', 'YML112W'],
#  'CPX-1711': ['YHR085W', 'YHR197W', 'YNL182C'],
#  'CPX-1712': ['YKR048C',
#   'YNL166C',
#   'YJR076C',
#   'YDR507C',
#   'YHR107C',
#   'YCR002C',
#   'YDL225W',
#   'YLR314C'],
#  'CPX-1715': ['YHR186C', 'YNL006W', 'YPL180W', 'YJR066W'],
#  'CPX-1716': ['YHR186C', 'YNL006W', 'YPL180W', 'YKL203C'],
#  'CPX-1717': ['YNL006W', 'YOL078W', 'YKL203C'],
#  'CPX-1718': ['YDR484W', 'YJL029C', 'YDR027C', 'YKR020W'],
#  'CPX-1719': ['YLR330W', 'YOR299W', 'YKR027W', 'YJL099W', 'YMR237W'],
#  'CPX-1720': ['YDR279W', 'YLR154C', 'YNL072W'],
#  'CPX-1721': ['YLR038C', 'YMR256C', 'Q0045'],
#  'CPX-1722': ['YLR038C', 'YMR256C', 'Q0045'],
#  'CPX-1726': ['YOL145C', 'YGL244W', 'YLR418C', 'YBR279W', 'YOR123C'],
#  'CPX-1731': ['YOL094C',
#   'YNL290W',
#   'YJR068W',
#   'YBR087W',
#   'YMR078C',
#   'YCL016C',
#   'YHR191C'],
#  'CPX-1732': ['YMR106C', 'YMR284W'],
#  'CPX-1733': ['YDR060W', 'YOR206W'],
#  'CPX-1734': ['YLR002C', 'YOR206W'],
#  'CPX-1735': ['YPR144C', 'YDL148C'],
#  'CPX-1738': ['YLR060W', 'YFL022C'],
#  'CPX-1739': ['YBR036C', 'YPL057C'],
#  'CPX-1740': ['YBR036C'],
#  'CPX-1741': ['YJR045C'],
#  'CPX-1742': ['YJL035C', 'YLR316C'],
#  'CPX-1743': ['YGR285C', 'YHR064C'],
#  'CPX-1744': ['YHR083W', 'YNL026W', 'YMR060C'],
#  'CPX-1786': ['YLR440C', 'YGL145W', 'YNL258C'],
#  'CPX-1792': ['YNL139C', 'YML062C', 'YDR138W', 'YHR167W', 'YNL253W'],
#  'CPX-1793': ['YNL139C',
#   'YML062C',
#   'YDR138W',
#   'YHR167W',
#   'YDR381W',
#   'YDL084W',
#   'YNL253W'],
#  'CPX-1800': ['YNR052C',
#   'YNL288W',
#   'YER068W',
#   'YGR134W',
#   'YDL165W',
#   'YAL021C',
#   'YCR093W',
#   'YIL038C',
#   'YPR072W'],
#  'CPX-1805': ['YHR129C', 'YPL174C', 'YMR294W'],
#  'CPX-1807': ['YOL094C', 'YNL290W', 'YJR068W', 'YBR087W', 'YER173W'],
#  'CPX-1808': ['YFR009W', 'YGL195W'],
#  'CPX-1810': ['YPL129W', 'YBL052C', 'YJR082C', 'YPR031W', 'YOR064C'],
#  'CPX-1811': ['YDL042C', 'YLR442C', 'YDR227W'],
#  'CPX-1812': ['YLR342W', 'YPR165W'],
#  'CPX-1813': ['YPR165W', 'YGR032W'],
#  'CPX-1814': ['YHR034C', 'YDR190C', 'YCR060W', 'YPL235W'],
#  'CPX-1830': ['YOR358W'],
#  'CPX-1831': ['YOR361C', 'YDR429C', 'YBR079C', 'YMR309C', 'YMR146C'],
#  'CPX-1832': ['YMR059W', 'YPL083C', 'YLR105C', 'YAR008W'],
#  'CPX-1833': ['YLR378C'],
#  'CPX-1834': ['YBR283C', 'YER019C-A'],
#  'CPX-1835': ['YLR066W', 'YJR010C-A', 'YIR022W', 'YML055W'],
#  'CPX-1836': ['YJL025W', 'YBL014C', 'YML043C'],
#  'CPX-1837': ['YGR003W', 'YNL230C', 'YPL046C'],
#  'CPX-1838': ['YNR044W'],
#  'CPX-1839': ['YEL036C', 'YJR075W', 'YJL183W', 'YDR245W', 'YPL050C'],
#  'CPX-1840': ['YGR120C',
#   'YNL041C',
#   'YNL051W',
#   'YGL223C',
#   'YML071C',
#   'YER157W',
#   'YGL005C',
#   'YPR105C'],
#  'CPX-1846': ['YBL046W', 'YDR075W', 'YNL201C'],
#  'CPX-1848': ['YPL149W'],
#  'CPX-1849': ['YMR159C', 'YPL149W'],
#  'CPX-1850': ['YER090W', 'YKL211C'],
#  'CPX-1851': ['YPR023C', 'YMR075W', 'YOL004W', 'YPL139C', 'YNL330C'],
#  'CPX-1852': ['YPL181W',
#   'YOL004W',
#   'YPL139C',
#   'YNL097C',
#   'YNL330C',
#   'YMR263W',
#   'YDL076C',
#   'YIL084C',
#   'YBR095C',
#   'YAL013W'],
#  'CPX-1853': ['YNL025C', 'YDR443C', 'YCR081W', 'YPL042C'],
#  'CPX-1854': ['YLR268W', 'YIL004C', 'YLR078C', 'YLR026C'],
#  'CPX-1855': ['YKL006C-A', 'YKL196C', 'YHL031C', 'YLR026C'],
#  'CPX-1856': ['YAL016W', 'YDL134C', 'YGL190C'],
#  'CPX-1857': ['YAL016W', 'YDL134C', 'YOR014W'],
#  'CPX-1858': ['YDL188C', 'YAL016W', 'YOR014W'],
#  'CPX-1859': ['YDL188C', 'YAL016W', 'YGL190C'],
#  'CPX-1861': ['YOL111C', 'YOR007C', 'YBR137W', 'YLL026W', 'YOR164C'],
#  'CPX-1862': ['YMR049C', 'YGR103W', 'YOR272W'],
#  'CPX-1863': ['YDL047W', 'YIL153W', 'YMR028W'],
#  'CPX-1864': ['YDL047W', 'YFR040W'],
#  'CPX-1865': ['YDL047W', 'YJL098W'],
#  'CPX-1866': ['YDL047W', 'YKR028W'],
#  'CPX-1867': ['YIL026C', 'YDL003W', 'YFL008W', 'YJL074C'],
#  'CPX-1868': ['YDR180W', 'YER147C'],
#  'CPX-1869': ['YFR031C', 'YLR086W', 'YBL097W', 'YDR325W', 'YLR272C'],
#  'CPX-1872': ['YDR369C', 'YNL250W', 'YMR224C'],
#  'CPX-1873': ['YNL221C',
#   'YGR030C',
#   'YHR062C',
#   'YBL018C',
#   'YBR167C',
#   'YAL033W',
#   'YNL282W',
#   'YIR015W',
#   'YBR257W'],
#  'CPX-1881': ['YBR097W', 'YLR240W', 'YLR211C', 'YPL120W'],
#  'CPX-1882': ['YAL005C', 'YNL064C', 'YCL037C'],
#  'CPX-1883': ['YLL024C', 'YNL064C', 'YCL037C'],
#  'CPX-1884': ['YDR295C', 'YNL021W', 'YPR179C'],
#  'CPX-1885': ['YPR101W',
#   'YMR213W',
#   'YLL036C',
#   'YLR117C',
#   'YJR050W',
#   'YGR129W',
#   'YDR416W',
#   'YBR188C'],
#  'CPX-1886': ['YKR022C', 'YGL120C', 'YLR424W'],
#  'CPX-1887': ['YGL212W', 'YKL196C', 'YOR106W'],
#  'CPX-1888': ['YPR034W',
#   'YMR091C',
#   'YML127W',
#   'YLR357W',
#   'YLR321C',
#   'YLR033W',
#   'YKR008W',
#   'YIL126W',
#   'YGR275W',
#   'YHR056C',
#   'YFR037C',
#   'YDR303C',
#   'YCR052W',
#   'YBL006C',
#   'YCR020W-B',
#   'YMR033W'],
#  'CPX-1889': ['YPR034W',
#   'YMR091C',
#   'YML127W',
#   'YLR321C',
#   'YLR033W',
#   'YKR008W',
#   'YIL126W',
#   'YGR275W',
#   'YHR056C',
#   'YGR056W',
#   'YFR037C',
#   'YDR303C',
#   'YCR052W',
#   'YBL006C',
#   'YCR020W-B',
#   'YMR033W'],
#  'CPX-1890': ['YLR166C',
#   'YIL068C',
#   'YJL085W',
#   'YER008C',
#   'YGL233W',
#   'YBR102C',
#   'YDR166C',
#   'YPR055W'],
#  'CPX-1891': ['YJL140W', 'YDR404C'],
#  'CPX-1893': ['YNL075W', 'YJR002W', 'YHR148W'],
#  'CPX-1894': ['YIL071C',
#   'YDL216C',
#   'YDR179C',
#   'YOL117W',
#   'YJR084W',
#   'YMR025W'],
#  'CPX-1895': ['YDR228C', 'YMR061W', 'YOR250C', 'YGL044C'],
#  'CPX-1896': ['YDR228C', 'YOL123W', 'YMR061W', 'YOR250C', 'YGL044C'],
#  'CPX-1898': ['YMR168C', 'YDR328C', 'YGR140W', 'YMR094W'],
#  'CPX-1899': ['YDR532C', 'YGL093W'],
#  'CPX-1900': ['YBR156C'],
#  'CPX-1901': ['YKL197C', 'YNL329C'],
#  'CPX-1903': ['YJL210W', 'YDR265W', 'YMR026C'],
#  'CPX-1904': ['YNL214W', 'YGL153W', 'YLR191W'],
#  'CPX-1906': ['YGR239C'],
#  'CPX-1939': ['YEL048C',
#   'YOR115C',
#   'YMR218C',
#   'YGR166W',
#   'YKR068C',
#   'YDR246W',
#   'YDR472W',
#   'YBR254C',
#   'YDR407C',
#   'YML077W'],
#  'CPX-1940': ['YOR115C',
#   'YKR068C',
#   'YDR246W',
#   'YDR472W',
#   'YBR254C',
#   'YML077W'],
#  'CPX-1947': ['YGL245W', 'YGL105W', 'YGR264C'],
#  'CPX-2091': ['YNL102W', 'YBL035C', 'YKL045W', 'YIR008C'],
#  'CPX-21': ['YJL173C', 'YAR007C', 'YNL312W'],
#  'CPX-2101': ['YJR006W', 'YDL102W', 'YJR043C'],
#  'CPX-2110': ['YDR121W', 'YNL262W', 'YBR278W', 'YPR175W'],
#  'CPX-2112': ['YBR275C', 'YNL216W'],
#  'CPX-2122': ['YLR399C',
#   'YGR002C',
#   'YJL081C',
#   'YNL107W',
#   'YML041C',
#   'YLR085C',
#   'YLR385C',
#   'YDR334W',
#   'YDR485C',
#   'YBR231C',
#   'YDR190C',
#   'YAL011W',
#   'YFL039C',
#   'YPL235W'],
#  'CPX-2146': ['YCR030C'],
#  'CPX-2147': ['YHR079C'],
#  'CPX-2148': ['YNL231C'],
#  'CPX-2156': ['YJL008C',
#   'YJL111W',
#   'YIL142W',
#   'YJL014W',
#   'YDR188W',
#   'YDR212W',
#   'YDL143W',
#   'YJR064W'],
#  'CPX-2225': ['YOR326W', 'YBR109C', 'YGL106W'],
#  'CPX-2262': ['YOR157C',
#   'YPR108W',
#   'YOR259C',
#   'YOR261C',
#   'YFR052W',
#   'YHR200W',
#   'YFR004W',
#   'YER021W',
#   'YDR394W',
#   'YDR427W',
#   'YDL147W',
#   'YDR363W-A',
#   'YDL097C',
#   'YLR421C',
#   'YOR117W',
#   'YIL075C',
#   'YKL145W',
#   'YHR027C',
#   'YGL048C',
#   'YDL007W',
#   'YOR362C',
#   'YPR103W',
#   'YMR314W',
#   'YOL038W',
#   'YJL001W',
#   'YGL011C',
#   'YGR135W',
#   'YFR050C',
#   'YER012W',
#   'YBL041W',
#   'YGR253C',
#   'YML092C',
#   'YER094C'],
#  'CPX-2267': ['YJR104C', 'YMR038C'],
#  'CPX-23': ['YLR147C',
#   'YGR074W',
#   'YPR182W',
#   'YLR275W',
#   'YER029C',
#   'YFL017W-A',
#   'YML046W',
#   'YIL061C',
#   'YLR298C',
#   'YDR240C',
#   'YGR013W',
#   'YDL087C',
#   'YDR235W',
#   'YBR119W',
#   'YOR159C',
#   'YHR086W',
#   'YKL012W'],
#  'CPX-231': ['YGL115W', 'YER027C', 'YDR477W'],
#  'CPX-232': ['YGL115W', 'YDR422C', 'YDR477W'],
#  'CPX-24': ['YNL147W',
#   'YJR022W',
#   'YER112W',
#   'YDR378C',
#   'YBL026W',
#   'YLR438C-A',
#   'YER146W'],
#  'CPX-242': ['YLR336C'],
#  'CPX-25': ['YPR178W',
#   'YOR308C',
#   'YNL147W',
#   'YJR022W',
#   'YGR091W',
#   'YGR075C',
#   'YDR473C',
#   'YER112W',
#   'YDR378C',
#   'YBL026W',
#   'YBR055C',
#   'YLR147C',
#   'YGR074W',
#   'YPR182W',
#   'YLR275W',
#   'YKL173W',
#   'YHR165C',
#   'YER172C',
#   'YER029C',
#   'YLR438C-A',
#   'YFL017W-A',
#   'YDL098C',
#   'YOR159C',
#   'YBR152W',
#   'YER146W',
#   'YDR243C',
#   'YFR005C',
#   'YEL026W',
#   'YPR082C'],
#  'CPX-2523': ['YIL109C', 'YDL195W', 'YLR208W', 'YPL218W', 'YPR181C'],
#  'CPX-2541': ['YGL087C'],
#  'CPX-2566': ['YNL031C',
#   'YNL030W',
#   'YBR009C',
#   'YBR010W',
#   'YBL002W',
#   'YDR225W'],
#  'CPX-26': ['YLR147C',
#   'YGR074W',
#   'YIR005W',
#   'YPR182W',
#   'YDL043C',
#   'YPL213W',
#   'YMR288W',
#   'YOR319W',
#   'YMR240C',
#   'YLR275W',
#   'YML049C',
#   'YJL203W',
#   'YGL174W',
#   'YER029C',
#   'YDL030W',
#   'YLR016C',
#   'YFL017W-A',
#   'YIR009W',
#   'YOR159C',
#   'YPR094W'],
#  'CPX-2660': ['YDL150W',
#   'YPR190C',
#   'YOR207C',
#   'YPR110C',
#   'YOR116C',
#   'YKL144C',
#   'YNL151C',
#   'YJL011C',
#   'YDR045C',
#   'YPR187W',
#   'YOR210W',
#   'YOR224C',
#   'YNL113W',
#   'YHR143W-A',
#   'YBR154C',
#   'YKR025W',
#   'YNR003C'],
#  'CPX-2662': ['YJL140W',
#   'YIL021W',
#   'YDR404C',
#   'YDL140C',
#   'YPR187W',
#   'YOR210W',
#   'YOR224C',
#   'YOR151C',
#   'YHR143W-A',
#   'YGL070C',
#   'YOL005C',
#   'YBR154C'],
#  'CPX-2678': ['YDR302W', 'YJL062W'],
#  'CPX-2680': ['YDR302W', 'YLL031C'],
#  'CPX-2723': ['YPR067W', 'YLL027W', 'YJR122W'],
#  'CPX-2800': ['YGL115W', 'YDR477W', 'YGL208W'],
#  'CPX-2841': ['YDL010W'],
#  'CPX-2854': ['YPL048W', 'YBR118W', 'YPR080W', 'YAL003W'],
#  'CPX-2894': ['YDR367W', 'YKL004W'],
#  'CPX-2895': ['YMR038C'],
#  'CPX-2896': ['YJR104C'],
#  'CPX-29': ['YBR055C',
#   'YLR147C',
#   'YGR074W',
#   'YPR182W',
#   'YLR275W',
#   'YKL173W',
#   'YHR165C',
#   'YER172C',
#   'YER029C',
#   'YFL017W-A',
#   'YOR159C',
#   'YDR243C',
#   'YPR082C',
#   'YHR156C'],
#  'CPX-2902': ['YGL058W', 'YCR066W'],
#  'CPX-2910': ['YGL058W', 'YDL074C'],
#  'CPX-2911': ['YDL074C'],
#  'CPX-2918': ['YGL058W', 'YGR184C'],
#  'CPX-2921': ['YMR275C'],
#  'CPX-2923': ['YML111W'],
#  'CPX-2935': ['YGL058W', 'YLR024C'],
#  'CPX-2937': ['YGL058W', 'YLR024C', 'YMR100W'],
#  'CPX-2944': ['YPR019W',
#   'YLR274W',
#   'YBL023C',
#   'YBR202W',
#   'YGL201C',
#   'YEL032W'],
#  'CPX-2946': ['YBR170C', 'YDL126C', 'YGR048W'],
#  'CPX-2948': ['YMR022W', 'YMR264W'],
#  'CPX-297': ['YPR019W',
#   'YLR274W',
#   'YDR013W',
#   'YBL023C',
#   'YBR202W',
#   'YLR103C',
#   'YGL201C',
#   'YEL032W',
#   'YDR489W',
#   'YOL146W',
#   'YJL072C'],
#  'CPX-30': ['YLR147C',
#   'YGR074W',
#   'YPR182W',
#   'YLR275W',
#   'YKL173W',
#   'YHR165C',
#   'YER029C',
#   'YFL017W-A',
#   'YOR159C',
#   'YBL074C'],
#  'CPX-301': ['YMR135C',
#   'YIL017C',
#   'YIL097W',
#   'YGL227W',
#   'YCL039W',
#   'YDR255C',
#   'YBR105C'],
#  'CPX-3028': ['YPR165W', 'YMR306W'],
#  'CPX-3034': ['YCL009C', 'YMR108W'],
#  'CPX-3036': ['YAL023C', 'YDL095W'],
#  'CPX-3037': ['YDL095W'],
#  'CPX-3038': ['YAL023C'],
#  'CPX-3039': ['YJR143C'],
#  'CPX-3055': ['YOR254C', 'YLR378C', 'YBR171W', 'YLR292C', 'YPL094C'],
#  'CPX-3056': ['YOR254C', 'YBR171W', 'YLR292C', 'YPL094C'],
#  'CPX-3069': ['YBR170C', 'YDL126C', 'YDR049W'],
#  'CPX-307': ['YJR088C', 'YCL045C', 'YGL231C', 'YIL027C', 'YLL014W', 'YKL207W'],
#  'CPX-3070': ['YOL013C', 'YML029W', 'YDR057W', 'YML013W', 'YLR207W'],
#  'CPX-3074': ['YML013W', 'YIL030C'],
#  'CPX-3078': ['YDR137W', 'YLR039C'],
#  'CPX-3087': ['YLR376C'],
#  'CPX-3088': ['YFR021W', 'YFR019W', 'YLR386W', 'YNL325C', 'YNL054W'],
#  'CPX-31': ['YPR178W',
#   'YDR473C',
#   'YLR147C',
#   'YGR074W',
#   'YPR182W',
#   'YLR275W',
#   'YER029C',
#   'YFL017W-A',
#   'YOR159C',
#   'YEL026W'],
#  'CPX-3139': ['YDR004W', 'YDR076W'],
#  'CPX-3146': ['YFL036W'],
#  'CPX-3155': ['YPR023C',
#   'YGR002C',
#   'YJL081C',
#   'YNL107W',
#   'YNL136W',
#   'YHR090C',
#   'YJR082C',
#   'YOR244W',
#   'YFL024C',
#   'YEL018W',
#   'YDR359C',
#   'YFL039C',
#   'YHR099W'],
#  'CPX-3158': ['YDR062W', 'YKL212W', 'YBR058C-A', 'YMR296C'],
#  'CPX-3159': ['YLR135W'],
#  'CPX-3163': ['YFR030W', 'YJR137C'],
#  'CPX-3172': ['YML121W', 'YGR163W', 'YKR007W', 'YBR077C', 'YCR075W-A'],
#  'CPX-3179': ['YER116C', 'YDL013W'],
#  'CPX-3180': ['YMR287C', 'YPL029W'],
#  'CPX-3184': ['YPR023C', 'YNL136W', 'YEL018W'],
#  'CPX-3185': ['YHR090C', 'YOR244W', 'YFL024C'],
#  'CPX-3188': ['YER149C', 'YLR319C', 'YNL271C', 'YLL021W'],
#  'CPX-3196': ['YGL219C', 'YLL006W', 'YAL010C', 'YAL048C'],
#  'CPX-32': ['YPR178W',
#   'YNL147W',
#   'YJR022W',
#   'YGR091W',
#   'YDR473C',
#   'YER112W',
#   'YDR378C',
#   'YBL026W',
#   'YLR147C',
#   'YGR074W',
#   'YPR182W',
#   'YLR275W',
#   'YER029C',
#   'YLR438C-A',
#   'YFL017W-A',
#   'YOR159C',
#   'YER146W',
#   'YEL026W'],
#  'CPX-3211': ['YBR057C'],
#  'CPX-3212': ['YOR026W', 'YGL086W', 'YGR188C', 'YJL030W'],
#  'CPX-3215': ['YGL207W', 'YML069W'],
#  'CPX-3226': ['YNR010W',
#   'YGL127C',
#   'YPR070W',
#   'YOR174W',
#   'YOL051W',
#   'YOL135C',
#   'YNL236W',
#   'YLR071C',
#   'YHR041C',
#   'YHR058C',
#   'YGL151W',
#   'YGR104C',
#   'YER022W',
#   'YGL025C',
#   'YDR308C',
#   'YDL005C',
#   'YBR193C',
#   'YBR253W',
#   'YBL093C',
#   'YPR168W'],
#  'CPX-3231': ['YLR208W',
#   'YJR138W',
#   'YOL138C',
#   'YGL100W',
#   'YDR128W',
#   'YEL062W',
#   'YBL104C',
#   'YHL023C'],
#  'CPX-3233': ['YML121W', 'YGR163W', 'YKR007W', 'YBR077C', 'YKL143W'],
#  'CPX-3234': ['YDR054C', 'YDR328C', 'YDL132W', 'YFL009W'],
#  'CPX-3238': ['YDR390C', 'YPR180W'],
#  'CPX-3241': ['YDR054C', 'YDR328C', 'YDL132W', 'YJR090C'],
#  'CPX-3242': ['YDR054C', 'YDR328C', 'YDL132W'],
#  'CPX-3243': ['YDR054C', 'YDR328C', 'YDL132W', 'YML088W'],
#  'CPX-3244': ['YDR054C', 'YDR328C', 'YDL132W', 'YJL149W'],
#  'CPX-3248': ['YMR119W', 'YNL008C'],
#  'CPX-3249': ['YIL046W', 'YDR054C', 'YDR328C', 'YDL132W'],
#  'CPX-325': ['YBR281C', 'YNL191W'],
#  'CPX-3250': ['YDR054C', 'YDR328C', 'YDL132W'],
#  'CPX-3253': ['YDR054C', 'YDR328C', 'YDL132W', 'YLR352W'],
#  'CPX-3254': ['YDR054C', 'YDR328C', 'YDL132W', 'YBR280C'],
#  'CPX-3255': ['YDR054C', 'YDR328C', 'YDL132W', 'YLR097C'],
#  'CPX-3265': ['YPL009C', 'YBR170C', 'YDL126C', 'YGR048W', 'YDR333C'],
#  'CPX-3281': ['YBL099W',
#   'YDR377W',
#   'YOL077W-A',
#   'YDR322C-A',
#   'Q0085',
#   'YPL271W',
#   'YPR020W',
#   'YLR295C',
#   'YML081C-A',
#   'YPL078C',
#   'YJR121W',
#   'YKL016C',
#   'YDR298C',
#   'YBR039W',
#   'YDL004W'],
#  'CPX-3284': ['YLR145W',
#   'YNL221C',
#   'YGR030C',
#   'YHR062C',
#   'YDR478W',
#   'YBL018C',
#   'YBR167C',
#   'YAL033W',
#   'YNL282W',
#   'YBR257W'],
#  'CPX-3294': ['YKL025C', 'YGL094C'],
#  'CPX-3297': ['YAL019W'],
#  'CPX-334': ['YPR173C'],
#  'CPX-3342': ['YCL005W', 'YLR404W'],
#  'CPX-335': ['YBR160W', 'YGR108W'],
#  'CPX-336': ['YBR160W', 'YDL155W'],
#  'CPX-337': ['YBR160W', 'YLR210W'],
#  'CPX-3384': ['YKR063C', 'YGL246C', 'YOR048C', 'YLL035W'],
#  'CPX-339': ['YBR160W'],
#  'CPX-342': ['YBR135W', 'YBR160W'],
#  'CPX-3462': ['YAL041W', 'YNL298W', 'YBR200W'],
#  'CPX-3503': ['YPL242C', 'YMR032W', 'YGL106W'],
#  'CPX-3541': ['YER071C', 'YIR003W'],
#  'CPX-36': ['YGR238C', 'YAR014C', 'YHR158C'],
#  'CPX-361': ['YFR021W', 'YNL242W'],
#  'CPX-3621': ['YDR499W', 'YBR136W'],
#  'CPX-3681': ['YDR054C', 'YDR328C', 'YDL132W'],
#  'CPX-384': ['YBR120C', 'YPL215W'],
#  'CPX-385': ['YGL091C', 'YIL003W'],
#  'CPX-386': ['YKR071C', 'YPR048W'],
#  'CPX-392': ['YCL017C', 'YER048W-A', 'YKL192C', 'YPL135W'],
#  'CPX-393': ['YKL088W', 'YKR072C', 'YOR054C'],
#  'CPX-396': ['YKL088W', 'YIL083C', 'YGR277C', 'YDR196C'],
#  'CPX-416': ['YGR102C', 'YBL080C', 'YMR293C'],
#  'CPX-417': ['YDR221W', 'YBR229C'],
#  'CPX-418': ['YDR140W', 'YNR046W'],
#  'CPX-422': ['YOL094C', 'YNL290W', 'YJR068W', 'YBR087W', 'YOR144C'],
#  'CPX-425': ['YBR118W', 'YPR080W', 'YKL081W', 'YAL003W'],
#  'CPX-426': ['YIR006C', 'YBL007C', 'YNL084C'],
#  'CPX-427': ['YJR007W', 'YER025W', 'YPL237W'],
#  'CPX-429': ['YKR026C', 'YGR083C', 'YDR211W', 'YLR291C', 'YOR260W'],
#  'CPX-43': ['YLR147C',
#   'YGR074W',
#   'YPR182W',
#   'YLR275W',
#   'YER029C',
#   'YFL017W-A',
#   'YOR159C'],
#  'CPX-430': ['YGR162W', 'YKR059W', 'YJL138C', 'YOL139C'],
#  'CPX-431': ['YGL049C', 'YKR059W', 'YJL138C', 'YOL139C'],
#  'CPX-435': ['YBR143C', 'YDR172W'],
#  'CPX-44': ['YNL147W',
#   'YJR022W',
#   'YER112W',
#   'YDR378C',
#   'YBL026W',
#   'YLR438C-A',
#   'YER146W'],
#  'CPX-45': ['YNL147W',
#   'YJL124C',
#   'YER112W',
#   'YDR378C',
#   'YBL026W',
#   'YLR438C-A',
#   'YER146W'],
#  'CPX-46': ['YNL147W',
#   'YER112W',
#   'YDR378C',
#   'YBL026W',
#   'YLR438C-A',
#   'YER146W'],
#  'CPX-465': ['YNL001W', 'YKR084C'],
#  'CPX-473': ['YNL131W', 'YOR045W', 'YMR203W'],
#  'CPX-474': ['YGR082W', 'YNL131W', 'YOR045W', 'YNL121C', 'YMR203W'],
#  'CPX-5304': ['YLR268W', 'YGL098W', 'YDR498C', 'YOR075W'],
#  'CPX-532': ['YPL259C', 'YKL135C', 'YPR029C', 'YLR170C'],
#  'CPX-5321': ['YOR327C', 'YDR468C', 'YOL018C'],
#  'CPX-5322': ['YDR468C', 'YOL018C', 'YAL030W'],
#  'CPX-533': ['YKL135C', 'YHL019C', 'YPR029C', 'YLR170C'],
#  'CPX-534': ['YJR058C', 'YJR005W', 'YBL037W', 'YOL062C'],
#  'CPX-5341': ['YIL106W', 'YPR111W'],
#  'CPX-535': ['YGR261C', 'YJL024C', 'YBR288C', 'YPL195W'],
#  'CPX-536': ['YJL164C', 'YIL033C'],
#  'CPX-537': ['YIL033C', 'YPL203W'],
#  'CPX-539': ['YJL104W',
#   'YIL022W',
#   'YPL063W',
#   'YOR232W',
#   'YJR045C',
#   'YKR065C',
#   'YNR017W',
#   'YLR008C'],
#  'CPX-5401': ['YGL212W', 'YLR093C', 'YOR106W'],
#  'CPX-5421': ['YKL196C'],
#  'CPX-5422': ['YKL196C', 'YDR468C'],
#  'CPX-5423': ['YDR468C', 'YAL030W'],
#  'CPX-5424': ['YAL030W'],
#  'CPX-544': ['YBR088C'],
#  'CPX-5441': ['YGL249W'],
#  'CPX-5442': ['YGL249W'],
#  'CPX-545': ['YOL094C', 'YNL290W', 'YJR068W', 'YBR087W', 'YOR217W'],
#  'CPX-5461': ['YOR327C'],
#  'CPX-5462': ['YOR327C', 'YDR468C'],
#  'CPX-5463': ['YOR327C', 'YPL232W', 'YGR009C'],
#  'CPX-5464': ['YPL232W', 'YAL030W'],
#  'CPX-5465': ['YOR327C', 'YMR183C', 'YGR009C'],
#  'CPX-5466': ['YOR327C', 'YPL232W'],
#  'CPX-548': ['YER018C', 'YMR117C', 'YIL144W', 'YOL069W'],
#  'CPX-5521': ['YLR093C', 'YPL232W', 'YGR009C'],
#  'CPX-554': ['YGR240C', 'YMR205C'],
#  'CPX-558': ['YNL037C', 'YOR136W'],
#  'CPX-565': ['YLL041C', 'YDR178W', 'YKL148C'],
#  'CPX-567': ['YEL024W',
#   'YBL045C',
#   'YGR183C',
#   'YHR001W-A',
#   'YOR065W',
#   'YJL166W',
#   'YDR529C',
#   'YFR033C',
#   'YPR191W'],
#  'CPX-568': ['YML102W', 'YBR195C', 'YPR018W'],
#  'CPX-571': ['YKL166C', 'YIL033C'],
#  'CPX-572': ['YJL164C', 'YIL033C', 'YPL203W'],
#  'CPX-573': ['YJL164C', 'YKL166C', 'YIL033C'],
#  'CPX-574': ['YKL166C', 'YIL033C', 'YPL203W'],
#  'CPX-575': ['YPL049C', 'YDR480W', 'YHR084W'],
#  'CPX-576': ['YPL049C', 'YHR084W', 'YBR083W'],
#  'CPX-579': ['YJR109C', 'YOR303W'],
#  'CPX-580': ['YGL130W', 'YPL228W'],
#  'CPX-581': ['YOR039W', 'YGL019W', 'YIL035C', 'YOR061W'],
#  'CPX-582': ['YDR074W', 'YBR126C', 'YMR261C'],
#  'CPX-583': ['YDR074W', 'YBR126C', 'YML100W'],
#  'CPX-588': ['YKL190W', 'YLR433C'],
#  'CPX-590': ['YKL190W', 'YML057W'],
#  'CPX-599': ['YOL021C',
#   'YOL142W',
#   'YNL232W',
#   'YHR069C',
#   'YGR158C',
#   'YGR195W',
#   'YGR095C',
#   'YDR280W',
#   'YDL111C',
#   'YCR035C',
#   'YOR001W'],
#  'CPX-603': ['YOL021C',
#   'YOL142W',
#   'YNL232W',
#   'YHR069C',
#   'YGR158C',
#   'YGR195W',
#   'YGR095C',
#   'YDR280W',
#   'YDL111C',
#   'YCR035C'],
#  'CPX-607': ['YNR035C',
#   'YLR370C',
#   'YKL013C',
#   'YIL062C',
#   'YDL029W',
#   'YBR234C',
#   'YJR065C'],
#  'CPX-608': ['YCR082W', 'YGR252W', 'YDR448W', 'YDR176W', 'YCL010C', 'YOR023C'],
#  'CPX-609': ['YKL122C', 'YPL210C', 'YML105C', 'YPL243W', 'YDL092W', 'YPR088C'],
#  'CPX-6127': ['YPL063W', 'YNR017W'],
#  'CPX-636': ['YLR095C', 'YBR245C', 'YMR044W'],
#  'CPX-637': ['YBR245C', 'YFR013W'],
#  'CPX-656': ['YPL047W',
#   'YDR167W',
#   'YOL148C',
#   'YPL254W',
#   'YMR223W',
#   'YMR236W',
#   'YLR055C',
#   'YGR252W',
#   'YGL066W',
#   'YGL112C',
#   'YDR392W',
#   'YDR448W',
#   'YDR145W',
#   'YDR176W',
#   'YBR198C',
#   'YCL010C',
#   'YBR081C',
#   'YBR111W-A',
#   'YER164W',
#   'YHR099W'],
#  'CPX-6643': ['YGL110C', 'YGR271W', 'YKR023W'],
#  'CPX-675': ['YPL047W',
#   'YDR167W',
#   'YOL148C',
#   'YPL254W',
#   'YMR223W',
#   'YMR236W',
#   'YGR252W',
#   'YGL066W',
#   'YGL112C',
#   'YDR392W',
#   'YDR448W',
#   'YDR145W',
#   'YDR176W',
#   'YBR198C',
#   'YCL010C',
#   'YBR081C',
#   'YBR111W-A',
#   'YER164W',
#   'YHR099W'],
#  'CPX-6864': ['YGL220W', 'YDR098C'],
#  'CPX-6865': ['YGL220W', 'YER174C'],
#  'CPX-692': ['YMR043W'],
#  'CPX-6921': ['YER174C'],
#  'CPX-6924': ['YDR098C'],
#  'CPX-6928': ['YPL059W', 'YAL044W-A'],
#  'CPX-693': ['YMR043W'],
#  'CPX-6930': ['YPL059W', 'YAL046C'],
#  'CPX-6937': ['YBR014C'],
#  'CPX-695': ['YJL005W', 'YNL138W'],
#  'CPX-6957': ['YPL059W'],
#  'CPX-728': ['YGL133W', 'YJL065C', 'YDR121W', 'YOR304W'],
#  'CPX-729': ['YOR310C', 'YLR197W', 'YDL014W', 'YEL026W'],
#  'CPX-734': ['YGL133W', 'YOR304W'],
#  'CPX-737': ['YHR089C', 'YHR072W-A', 'YDL208W', 'YLR175W'],
#  'CPX-756': ['YOR249C',
#   'YDL008W',
#   'YLR127C',
#   'YNL172W',
#   'YKL022C',
#   'YLR102C',
#   'YHR166C',
#   'YFR036W',
#   'YGL240W',
#   'YDR118W',
#   'YDR260C',
#   'YBL084C',
#   'YIR025W'],
#  'CPX-760': ['YOR249C',
#   'YDL008W',
#   'YLR127C',
#   'YNL172W',
#   'YKL022C',
#   'YLR102C',
#   'YHR166C',
#   'YFR036W',
#   'YGL240W',
#   'YDR118W',
#   'YDR260C',
#   'YBL084C',
#   'YIR025W'],
#  'CPX-761': ['YOR249C',
#   'YDL008W',
#   'YLR127C',
#   'YNL172W',
#   'YKL022C',
#   'YLR102C',
#   'YHR166C',
#   'YFR036W',
#   'YGL240W',
#   'YDR118W',
#   'YDR260C',
#   'YBL084C',
#   'YIR025W',
#   'YGL003C'],
#  'CPX-762': ['YOR249C',
#   'YDL008W',
#   'YLR127C',
#   'YNL172W',
#   'YKL022C',
#   'YLR102C',
#   'YHR166C',
#   'YFR036W',
#   'YGL240W',
#   'YDR118W',
#   'YDR260C',
#   'YBL084C',
#   'YIR025W'],
#  'CPX-768': ['YNL261W', 'YML065W', 'YLL004W', 'YHR118C', 'YBR060C', 'YPR162C'],
#  'CPX-769': ['YOR039W', 'YGL019W', 'YIL035C'],
#  'CPX-770': ['YOR039W', 'YGL019W', 'YOR061W'],
#  'CPX-771': ['YGR090W', 'YCL031C', 'YOR039W', 'YGL019W', 'YIL035C'],
#  'CPX-772': ['YGR090W', 'YCL031C', 'YOR039W', 'YGL019W', 'YIL035C', 'YOR061W'],
#  'CPX-773': ['YGR090W', 'YCL031C', 'YOR039W', 'YGL019W', 'YOR061W'],
#  'CPX-774': ['YGR090W',
#   'YCL031C',
#   'YOR039W',
#   'YLR223C',
#   'YGL019W',
#   'YIL035C',
#   'YOR061W'],
#  'CPX-775': ['YGR090W', 'YCL031C', 'YOR039W', 'YLR223C', 'YGL019W', 'YIL035C'],
#  'CPX-776': ['YGR090W', 'YCL031C', 'YOR039W', 'YLR223C', 'YGL019W', 'YOR061W'],
#  'CPX-777': ['YOR213C', 'YMR127C', 'YDR181C'],
#  'CPX-778': ['YNR046W', 'YOL124C'],
#  'CPX-779': ['YGR200C', 'YPL086C', 'YLR384C', 'YHR187W', 'YMR312W', 'YPL101W'],
#  'CPX-780': ['YKL154W', 'YDR292C'],
#  'CPX-781': ['YPR051W', 'YEL053C', 'YCR020C-A'],
#  'CPX-782': ['YOL076W', 'YPR131C'],
#  'CPX-783': ['YHR013C', 'YDL040C', 'YOR253W'],
#  'CPX-784': ['YPL019C', 'YER072W', 'YFL004W', 'YJL012C'],
#  'CPX-824': ['YAR002W',
#   'YMR129W',
#   'YKR095W',
#   'YIL149C',
#   'YGL172W',
#   'YER107C',
#   'YIL115C',
#   'YLR208W',
#   'YJR042W',
#   'YDR424C',
#   'YGL100W',
#   'YLR018C',
#   'YJL041W',
#   'YKR082W',
#   'YFR002W',
#   'YGR119C',
#   'YDL116W',
#   'YML031W',
#   'YBL079W',
#   'YER105C',
#   'YLR335W',
#   'YKL068W',
#   'YOR098C',
#   'YMR047C',
#   'YJL061W',
#   'YJL039C',
#   'YMR153W',
#   'YML103C',
#   'YKL057C'],
#  'CPX-828': ['YBL103C', 'YOL067C'],
#  'CPX-863': ['YPL129W',
#   'YNL059C',
#   'YJL081C',
#   'YDR190C',
#   'YFL039C',
#   'YEL044W',
#   'YOR189W',
#   'YNL215W',
#   'YOR141C',
#   'YGL150C',
#   'YLR052W',
#   'YER092W',
#   'YFL013C',
#   'YDL002C',
#   'YPL235W'],
#  'CPX-867': ['YDL017W', 'YDR052C'],
#  'CPX-868': ['YMR058W'],
#  'CPX-869': ['YBR207W', 'YFL041W'],
#  'CPX-940': ['YGR206W', 'YCL008C', 'YPL065W'],
#  'CPX-946': ['YER111C', 'YLR182W'],
#  'CPX-950': ['YDL056W', 'YLR182W'],
#  'CPX-956': ['YDL100C', 'YER083C', 'YGL020C'],
#  'CPX-961': ['YGL086W', 'YJL030W'],
#  'CPX-962': ['YJL030W'],
#  'CPX-963': ['YOR026W', 'YJL030W'],
#  'CPX-964': ['YJR053W'],
#  'CPX-977': ['YAL041W', 'YJR086W', 'YOR212W'],
#  'CPX-995': ['YKR095W-A', 'YGR262C', 'YJL184W', 'YKR038C', 'YML036W'],
#  'CPX-999': ['YNL103W'],
#  'None': ['YER136W',
#   'YHR087W',
#   'YDR035W',
#   'YDR304C',
#   'YBR035C',
#   'YBR149W',
#   'YBL036C',
#   'YBL033C',
#   'YPR172W',
#   'YBL031W',
#   'YPL211W',
#   'YPR169W',
#   'YPL093W',
#   'YPL146C',
#   'YOR252W',
#   'YOL077C',
#   'YNR053C',
#   'YNL061W',
#   'YNL110C',
#   'YNL002C',
#   'YNL022C',
#   'YLR397C',
#   'YLR449W',
#   'YLR074C',
#   'YLR106C',
#   'YKL172W',
#   'YLR009W',
#   'YIL096C',
#   'YHR052W',
#   'YER126C',
#   'YFL002C',
#   'YER002W',
#   'YER006W',
#   'YDR412W',
#   'YBL028C',
#   'YAL025C',
#   'YPL127C',
#   'YNL091W',
#   'YML081W',
#   'YKR024C',
#   'YJL122W',
#   'YHR170W',
#   'YHR051W',
#   'YHR003C',
#   'YGL187C',
#   'YER176W',
#   'YDR101C',
#   'YBR267W',
#   'YBL030C',
#   'YMR098C',
#   'YGL122C',
#   'YGL173C',
#   'YER077C',
#   'YDL160C',
#   'YOR006C',
#   'YHR135C',
#   'YER032W',
#   'YDL122W',
#   'YBR150C',
#   'YBR260C',
#   'YIL150C',
#   'YBL022C',
#   'YBL017C',
#   'YKR035W-A',
#   'YBL016W',
#   'YBL015W',
#   'YBL011W',
#   'YBL013W',
#   'YBL010C',
#   'YJR024C',
#   'YBL098W',
#   'YNL243W',
#   'YLR206W',
#   'YLR337C',
#   'YDL161W',
#   'YCR024C',
#   'YPL012W',
#   'YOR076C',
#   'YNR024W',
#   'YLR051C',
#   'YIL127C',
#   'YIL019W',
#   'YHR081W',
#   'YGR145W',
#   'YDR457W',
#   'YDR299W',
#   'YGR116W',
#   'YPR049C',
#   'YOR294W',
#   'YOR386W',
#   'YNL088W',
#   'YNL186W',
#   'YML074C',
#   'YLR455W',
#   'YLL008W',
#   'YKR081C',
#   'YJR144W',
#   'YIL070C',
#   'YHR088W',
#   'YGR245C',
#   'YGR270W',
#   'YGL111W',
#   'YFR001W',
#   'YDR496C',
#   'YDR194C',
#   'YDL156W',
#   'YDR091C',
#   'YDL031W',
#   'YCL054W',
#   'YAR028W',
#   'YIR002C',
#   'YCR028C-A',
#   'YAL060W',
#   'YLR090W',
#   'YGL099W',
#   'YAL056W',
#   'YAL054C',
#   'YJR049C',
#   'YLL029W',
#   'YDR051C',
#   'YAL049C',
#   'YOR196C',
#   'YAL047C',
#   'YLR239C',
#   'YGL140C',
#   'YLR064W',
#   'YOR375C',
#   'YLR354C',
#   'YOL109W',
#   'YLR044C',
#   'YKL060C',
#   'YLL050C',
#   'YKL056C',
#   'YHR174W',
#   'YFR053C',
#   'YGR254W',
#   'YDR226W',
#   'YER023W',
#   'YDR050C',
#   'YBR196C',
#   'YCR012W',
#   'YPR074C',
#   'YOR374W',
#   'YKR014C',
#   'YML004C',
#   'YJL217W',
#   'YJR009C',
#   'YIL053W',
#   'YIR012W',
#   'YHR113W',
#   'YFL045C',
#   'YGR234W',
#   'YER031C',
#   'YDR071C',
#   'YDR502C',
#   'YCR088W',
#   'YDL171C',
#   'YBL039C',
#   'YBR218C',
#   'YNL112W',
#   'YMR012W',
#   'YLR249W',
#   'YLR150W',
#   'YIL161W',
#   'YHR146W',
#   'YGR054W',
#   'YGL013C',
#   'YDR423C',
#   'YDR174W',
#   'YAL059W',
#   'YAL036C',
#   'YOL127W',
#   'YMR260C',
#   'YBR263W',
#   'YBR084W',
#   'YAL035W',
#   'YBR130C',
#   'YMR071C',
#   'YKL039W',
#   'YJL198W',
#   'YHL017W',
#   'YGL203C',
#   'YBR023C',
#   'YAL053W',
#   'YPR113W',
#   'YPL207W',
#   'YOR320C',
#   'YNL219C',
#   'YMR161W',
#   'YML075C',
#   'YLR450W',
#   'YLR372W',
#   'YKL165C',
#   'YKL065C',
#   'YJL117W',
#   'YHR133C',
#   'YIL016W',
#   'YGL065C',
#   'YGL055W',
#   'YGL012W',
#   'YEL031W',
#   'YDL121C',
#   'YCR017C',
#   'YDL072C',
#   'YBR106W',
#   'YBR159W',
#   'YDL223C',
#   'YJR011C',
#   'YAL017W',
#   'YNR032W',
#   'YML109W',
#   'YAL012W',
#   'YBR061C',
#   'YIL009W',
#   'YPR037C',
#   'YKL063C',
#   'YGL038C',
#   'YGR284C',
#   'YBR187W',
#   'YOR016C',
#   'YGL054C',
#   'YGL167C',
#   'YDR182W',
#   'YBR205W',
#   'YCL001W',
#   'YBL040C',
#   'YOR133W',
#   'YPR035W',
#   'YNL209W',
#   'YOR027W',
#   'YKL152C',
#   'YLR180W',
#   'YDR385W',
#   'YHR111W',
#   'YCL030C',
#   'YDL229W',
#   'YAL038W',
#   'YPL106C',
#   'YOR020C',
#   'YOR187W',
#   'YNL241C',
#   'YNL007C',
#   'YMR246W',
#   'YLR304C',
#   'YLR259C',
#   'YLR079W',
#   'YLR216C',
#   'YHL021C',
#   'YER103W',
#   'YGL073W',
#   'YDR171W',
#   'YDL226C',
#   'YDR068W',
#   'YBR169C',
#   'YCL050C',
#   'YBR101C',
#   'YBR072W',
#   'YER099C',
#   'YNL192W',
#   'YML123C',
#   'YPR186C',
#   'YPR155C',
#   'YPR141C',
#   'YPR148C',
#   'YPR140W',
#   'YPR122W',
#   'YPR129W',
#   'YPR097W',
#   'YPR057W',
#   'YPR047W',
#   'YPR016C',
#   'YPR022C',
#   'YPR006C',
#   'YPR013C',
#   'YPR002W',
#   'YPR003C',
#   'YPL269W',
#   'YPL273W',
#   'YPL246C',
#   'YPL247C',
#   'YPL222W',
#   'YPL191C',
#   'YPL163C',
#   'YPL168W',
#   'YPL161C',
#   'YPL133C',
#   'YPL144W',
#   'YPL112C',
#   'YPL115C',
#   'YPL107W',
#   'YPL109C',
#   'YPL097W',
#   'YPL084W',
#   'YPL087W',
#   'YPL072W',
#   'YPL074W',
#   'YPL068C',
#   'YPL069C',
#   'YPL060W',
#   'YPL026C',
#   'YPL030W',
#   'YOR372C',
#   'YOR360C',
#   'YOR355W',
#   'YOR354C',
#   'YOR342C',
#   'YOR317W',
#   'YOR305W',
#   'YOR273C',
#   'YOR274W',
#   'YOR267C',
#   'YOR243C',
#   'YOR246C',
#   'YOR231W',
#   'YOR221C',
#   'YOR193W',
#   'YOR199W',
#   'YOR185C',
#   'YOR176W',
#   'YOR147W',
#   'YOR156C',
#   'YOR130C',
#   'YOR124C',
#   'YOR138C',
#   'YOR113W',
#   'YOR120W',
#   'YOR104W',
#   'YOR107W',
#   'YOR094W',
#   'YER019W',
#   'YOL103W-B',
#   'YOR077W',
#   'YOR070C',
#   'YOR074C',
#   'YOR035C',
#   'YOR040W',
#   'YOR034C',
#   'YOL140W',
#   'YOL141W',
#   'YOL136C',
#   'YOL126C',
#   'YOL125W',
#   'YOL100W',
#   'YOL089C',
#   'YOL092W',
#   'YOL087C',
#   'YOL060C',
#   'YOL064C',
#   'YOL055C',
#   'YOL047C',
#   'YOL049W',
#   'YOL028C',
#   'YOL033W',
#   'YOL023W',
#   'YOL027C',
#   'YNR067C',
#   'YOL007C',
#   'YNR056C',
#   'YNR043W',
#   'YNR007C',
#   'YPL157W',
#   'YOR171C',
#   'YNR001C',
#   'YNL326C',
#   'YNL327W',
#   'YNL322C',
#   'YNL310C',
#   'YNL315C',
#   'YNL309W',
#   'YNL280C',
#   'YNL278W',
#   'YNL257C',
#   'YNL238W',
#   'YNL217W',
#   'YNL218W',
#   'YNL198C',
#   'YNL167C',
#   'YNL130C',
#   'YNL125C',
#   'YPL263C',
#   'YNL311C',
#   'YNL108C',
#   'YNL115C',
#   'YNL099C',
#   'YNL068C',
#   'YNL063W',
#   'YNL066W',
#   'YNL053W',
#   'YNL058C',
#   'YNL044W',
#   'YNL003C',
#   'YMR302C',
#   'YMR295C',
#   'YOR128C',
#   'YMR283C',
#   'YMR285C',
#   'YMR277W',
#   'YMR280C',
#   'YPR124W',
#   'YMR251W-A',
#   'YMR253C',
#   'YMR243C',
#   'YPL206C',
#   'YMR232W',
#   'YMR207C',
#   'YMR200W',
#   'YMR195W',
#   'YMR196W',
#   'YMR192W',
#   'YMR174C',
#   'YMR175W',
#   'YMR173W',
#   'YMR169C',
#   'YMR164C',
#   'YMR160W',
#   'YMR139W',
#   'YNL148C',
#   'YOR349W',
#   'YMR138W',
#   'YMR079W',
#   'YMR076C',
#   'YMR066W',
#   'YMR069W',
#   'YMR064W',
#   'YMR036C',
#   'YMR027W',
#   'YMR021C',
#   'YMR002W',
#   'YMR010W',
#   'YML116W',
#   'YMR300C',
#   'YMR178W',
#   'YML079W',
#   'YML080W',
#   'YML070W',
#   'YMR148W',
#   'YML060W',
#   'YNL004W',
#   'YML052W',
#   'YML037C',
#   'YML038C',
#   'YML021C',
#   'YML018C',
#   'YML020W',
#   'YML005W',
#   'YML007W',
#   'YMR099C',
#   'YLR438W',
#   'YLR436C',
#   'YMR304W',
#   'YLR414C',
#   'YLR405W',
#   'YLR395C',
#   'YLR392C',
#   'YNR021W',
#   'YLR363W-A',
#   'YLR351C',
#   'YOR081C',
#   'YLR299W',
#   'YLR285W',
#   'YLR283W',
#   'YLR266C',
#   'YLR253W',
#   'YLR262C',
#   'YLR228C',
#   'YLR215C',
#   'YLR190W',
#   'YLR193C',
#   'YLR168C',
#   'YLR143W',
#   'YLR146C',
#   'YLR136C',
#   'YLR120C',
#   'YLR091W',
#   'YLR084C',
#   'YLR050C',
#   'YLR035C-A',
#   'YNL163C',
#   'YLR032W',
#   'YLR017W',
#   'YNR031C',
#   'YLR006C',
#   'YLR001C',
#   'YLL043W',
#   'YLL054C',
#   'YLL032C',
#   'YPR160W',
#   'YMR226C',
#   'YLL007C',
#   'YLR422W',
#   'YKR096W',
#   'YNR004W',
#   'YKR088C',
#   'YKR086W',
#   'YKR079C',
#   'YKR064W',
#   'YKR052C',
#   'YNL078W',
#   'YKR036C',
#   'YKR039W',
#   'YKR013W',
#   'YNL316C',
#   'YKR003W',
#   'YPL265W',
#   'YKL205W',
#   'YKL194C',
#   'YKL189W',
#   'YKL176C',
#   'YKL160W',
#   'YKL162C',
#   'YKL151C',
#   'YPL028W',
#   'YKL125W',
#   'YKL127W',
#   'YKL113C',
#   'YKL094W',
#   'YKL096W-A',
#   'YKL091C',
#   'YKL092C',
#   'YML016C',
#   'YKL071W',
#   'YKL072W',
#   'YKL055C',
#   'YKL049C',
#   'YKL047W',
#   'YKL048C',
#   'YKL038W',
#   'YKL026C',
#   'YKL020C',
#   'YKL017C',
#   'YPR017C',
#   'YKL157W',
#   'YJR149W',
#   'YJR161C',
#   'YJR147W',
#   'YJR134C',
#   'YJR133W',
#   'YJR119C',
#   'YJR116W',
#   'YJR118C',
#   'YJR111C',
#   'YJR096W',
#   'YPR045C',
#   'YJR074W',
#   'YJR067C',
#   'YJR055W',
#   'YPL193W',
#   'YJR048W',
#   'YJL204C',
#   'YJL208C',
#   'YJL200C',
#   'YKL040C',
#   'YJL197W',
#   'YJL196C',
#   'YJL153C',
#   'YJL155C',
#   'YJL147C',
#   'YNR029C',
#   'YNR016C',
#   'YLR153C',
#   'YJL130C',
#   'YJL123C',
#   'YJL078C',
#   'YJL070C',
#   'YJL048C',
#   'YJL057C',
#   'YJL043W',
#   'YJL044C',
#   'YMR214W',
#   'YLR110C',
#   'YIR034C',
#   'YIR018W',
#   'YIR007W',
#   'YNL135C',
#   'YIR004W',
#   'YIL156W',
#   'YIL151C',
#   'YIL138C',
#   'YIL128W',
#   'YIL123W',
#   'YIL105C',
#   'YJL180C',
#   'YIL101C',
#   'YIL098C',
#   'YIL063C',
#   'YKR042W',
#   'YIL040W',
#   'YIL042C',
#   'YIL037C',
#   'YIL039W',
#   'YIL129C',
#   'YKL179C',
#   'YHR216W',
#   'YHR205W',
#   'YHR206W',
#   'YML106W',
#   'YHR181W',
#   'YHR178W',
#   'YHR159W',
#   'YHR161C',
#   'YIL057C',
#   'YHR142W',
#   'YHR137W',
#   'YHR132C',
#   'YHR136C',
#   'YNL116W',
#   'YHR114W',
#   'YHR115C',
#   'YIL008W',
#   'YHR104W',
#   'YHR108W',
#   'YHR102W',
#   'YHR074W',
#   'YHR072W',
#   'YHR067W',
#   'YHR068W',
#   'YHR063C',
#   'YHR061C',
#   'YHR055C',
#   'YHR060W',
#   'YHR053C',
#   'YHR045W',
#   'YPL110C',
#   'YKL146W',
#   'YHR038W',
#   'YOL097C',
#   'YHR036W',
#   'YHR018C',
#   'YHR011W',
#   'YHR006W',
#   'YHL027W',
#   'YHL036W',
#   'YGR286C',
#   'YGR295C',
#   'YLR390W-A',
#   'YGR282C',
#   'YGR267C',
#   'YGR269W',
#   'YGR263C',
#   'YGR256W',
#   'YGR257C',
#   'YGR250C',
#   'YGR248W',
#   'YGR229C',
#   'YGR233C',
#   'YOR350C',
#   'YGR222W',
#   'YGR211W',
#   'YMR212C',
#   'YGR198W',
#   'YML058W-A',
#   'YML117W',
#   'YJR077C',
#   'YGR171C',
#   'YML120C',
#   'YGR157W',
#   'YGR151C',
#   'YOR197W',
#   'YPR154W',
#   'YNL208W',
#   'YGR126W',
#   'YGR136W',
#   'YGR124W',
#   'YGR122W',
#   'YGR105W',
#   'YGR093W',
#   'YGR087C',
#   'YMR031C',
#   'YGR150C',
#   'YGR071C',
#   'YGR055W',
#   'YGR046W',
#   'YGR052W',
#   'YGR043C',
#   'YGR042W',
#   'YNL087W',
#   'YOR086C',
#   'YGR026W',
#   'YML072C',
#   'YGR007W',
#   'YGR008C',
#   'YIL001W',
#   'YGL254W',
#   'YGL225W',
#   'YGL232W',
#   'YOL006C',
#   'YGL185C',
#   'YGL186C',
#   'YGL178W',
#   'YGL161C',
#   'YGL166W',
#   'YGL157W',
#   'YJR057W',
#   'YGL139W',
#   'YIL010W',
#   'YGR080W',
#   'YMR282C',
#   'YGL126W',
#   'YGL082W',
#   'YKL075C',
#   'YGR271C-A',
#   'YGL060W',
#   'YNL111C',
#   'YGL040C',
#   'YGL029W',
#   'YGL141W',
#   'YGL028C',
#   'YGL026C',
#   'YGL014W',
#   'YHR131C',
#   'YGL001C',
#   'YFR046C',
#   'YFR039C',
#   'YFR034C',
#   'YLR094C',
#   'YFR017C',
#   'YJL137C',
#   'YFR015C',
#   'YFL062W',
#   'YFL046W',
#   'YOR056C',
#   'YMR318C',
#   'YFL034W',
#   'YFL026W',
#   'YFL017C',
#   'YER183C',
#   'YNL168C',
#   'YOR022C',
#   'YKL134C',
#   'YHR008C',
#   'YPL070W',
#   'YGL071W',
#   'YER161C',
#   'YER163C',
#   'YJL172W',
#   'YER154W',
#   'YER150W',
#   'YER141W',
#   'YER140W',
#   'YJR059W',
#   'YML001W',
#   'YOR227W',
#   'YJL042W',
#   'YKL035W',
#   'YGR004W',
#   'YER155C',
#   'YER124C',
#   'YER120W',
#   'YMR209C',
#   'YMR015C',
#   'YJL178C',
#   'YER182W',
#   'YER104W',
#   'YER095W',
#   'YKL120W',
#   'YER081W',
#   'YIL074C',
#   'YOR230W',
#   'YLR109W',
#   'YOR229W',
#   'YER062C',
#   'YER061C',
#   'YER052C',
#   'YER053C',
#   'YER037W',
#   'YLR373C',
#   'YER035W',
#   'YER024W',
#   'YMR311C',
#   'YIL077C',
#   'YER014W',
#   'YJR014W',
#   'YER007C-A',
#   'YEL073C',
#   'YIL155C',
#   'YEL060C',
#   'YKL210W',
#   'YEL058W',
#   'YEL052W',
#   'YIL031W',
#   'YGR094W',
#   'YKL150W',
#   'YEL043W',
#   'YLR083C',
#   'YML048W',
#   'YJL186W',
#   'YEL029C',
#   'YNR027W',
#   'YFL005W',
#   'YEL025C',
#   'YEL017C-A',
#   'YEL017W',
#   'YEL014C',
#   'YGL211W',
#   'YEL011W',
#   'YLR258W',
#   'YEL009C',
#   'YHR163W',
#   'YKL064W',
#   'YDR539W',
#   'YDR530C',
#   'YDR520C',
#   'YDR527W',
#   'YDR513W',
#   'YDR497C',
#   'YDR486C',
#   'YLR181C',
#   'YKL175W',
#   'YDR479C',
#   'YML006C',
#   'YDR465C',
#   'YDR456W',
#   'YDR453C',
#   'YML028W',
#   'YDR441C',
#   'YDR436W',
#   'YDR421W',
#   'YDR419W',
#   'YDR400W',
#   'YDR411C',
#   'YHR007C',
#   'YKL027W',
#   'YIL002C',
#   'YLR432W',
#   'YMR039C',
#   'YGL064C',
#   'YDR373W',
#   'YDR370C',
#   'YDR353W',
#   'YHR106W',
#   'YDR352W',
#   'YDR350C',
#   'YDR349C',
#   'YLR096W',
#   'YIR001C',
#   'YER088C',
#   'YDR346C',
#   'YPR174C',
#   'YDR343C',
#   'YDR345C',
#   'YDR332W',
#   'YDR335W',
#   'YGL095C',
#   'YMR258C',
#   'YDR323C',
#   'YDR316W',
#   'YDR307W',
#   'YDR300C',
#   'YOR276W',
#   'YDR294C',
#   'YDR293C',
#   'YER033C',
#   'YDR291W',
#   'YDR283C',
#   'YDR275W',
#   'YMR313C',
#   'YDR270W',
#   'YDR266C',
#   'YDR267C',
#   'YDR508C',
#   'YJL080C',
#   'YJL145W',
#   'YDR257C',
#   'YDR244W',
#   'YNL042W',
#   'YOR093C',
#   'YOR112W',
#   'YPR091C',
#   'YPR183W',
#   'YLR056W',
#   'YPR028W',
#   'YDR232W',
#   'YHR039C',
#   'YDR222W',
#   'YDR217C',
#   'YDR213W',
#   'YDR210W',
#   'YDR348C',
#   'YMR070W',
#   'YDR205W',
#   'YDR197W',
#   'YDR189W',
#   'YJR080C',
#   'YDR177W',
#   'YDR170W-A',
#   'YJR083C',
#   'YDR168W',
#   'YDR169C',
#   'YML039W',
#   'YOR140W',
#   'YJR029W',
#   'YIL056W',
#   'YHR149C',
#   'YBL005W-B',
#   'YDR152W',
#   'YGR097W',
#   'YDR150W',
#   'YDR147W',
#   'YHR103W',
#   'YDR132C',
#   'YPR184W',
#   'YHR073W',
#   'YDR127W',
#   'YDR120C',
#   'YDR105C',
#   'YDR110W',
#   'YOR018W',
#   'YNL076W',
#   'YMR291W',
#   'YKR090W',
#   'YLR149C',
#   'YKL140W',
#   'YKL168C',
#   'YJR091C',
#   'YIL036W',
#   'YIL045W',
#   'YGL252C',
#   'YHR082C',
#   'YGL021W',
#   'YER114C',
#   'YDR379W',
#   'YDR090C',
#   'YDR096W',
#   'YMR131C',
#   'YDR312W',
#   'YPL085W',
#   'YDR077W',
#   'YDR070C',
#   'YPR116W',
#   'YDR059C',
#   'YDR065W',
#   'YER057C',
#   'YLR058C',
#   'YLL040C',
#   'YDR044W',
#   'YDR046C',
#   'YDR040C',
#   'YDR034C',
#   'YDR026C',
#   'YGL017W',
#   'YDR020C',
#   'YGR281W',
#   'YHR094C',
#   'YGR086C',
#   'YJL146W',
#   'YER003C',
#   'YDR006C',
#   'YPR042C',
#   'YNL267W',
#   'YDR505C',
#   'YNL074C',
#   'YER177W',
#   'YDR017C',
#   'YDR001C',
#   'YDR099W',
#   'YDL238C',
#   'YDL240W',
#   'YDL236W',
#   'YDL233W',
#   'YDL234C',
#   'YMR092C',
#   'YDL224C',
#   'YKL204W',
#   'YBR157C',
#   'YDL215C',
#   'YMR310C',
#   'YNL124W',
#   'YDR233C',
#   'YDL205C',
#   'YDL204W',
#   'YHR030C',
#   'YKR001C',
#   'YEL022W',
#   'YGL234W',
#   'YLR022C',
#   'YDL189W',
#   'YDL178W',
#   'YEL046C',
#   'YDL173W',
#   'YDL164C',
#   'YDL168W',
#   'YNL183C',
#   'YKR018C',
#   'YDL152W',
#   'YDR005C',
#   'YDL146W',
#   'YEL061C',
#   'YNR012W',
#   'YER067W',
#   'YKL181W',
#   'YDL141W',
#   'YDL139C',
#   'YDL137W',
#   'YDL135C',
#   'YML082W',
#   'YDL131W',
#   'YMR067C',
#   'YDL123W',
#   'YDL119C',
#   'YOR220W',
#   ...]}

# %% [markdown]
# ## Sort GI ORFs into clusters/modules

# %%
# Add ORF from correlation network
GI_ORF_list = []
GI_ORF_list.extend(GI_Epsi_network_DF['ORF_query'])
GI_ORF_list.extend(GI_Epsi_network_DF['ORF_array'])

# Make list unique
GI_ORF_list = list(np.unique(GI_ORF_list))


# Get list for only EpsiGI
all_EpsiGI_ORFs = []
all_EpsiGI_ORFs.extend(GI_Epsi_network_DF['ORF_query'])
all_EpsiGI_ORFs.extend(GI_Epsi_network_DF['ORF_array'])

all_EpsiGI_ORFs = list(np.unique(all_EpsiGI_ORFs))

GI_ORF_list
# Out:
# ['YAL001C',
#  'YAL002W',
#  'YAL004W',
#  'YAL005C',
#  'YAL007C',
#  'YAL008W',
#  'YAL009W',
#  'YAL010C',
#  'YAL011W',
#  'YAL012W',
#  'YAL013W',
#  'YAL014C',
#  'YAL015C',
#  'YAL016C-B',
#  'YAL017W',
#  'YAL018C',
#  'YAL019W',
#  'YAL020C',
#  'YAL021C',
#  'YAL022C',
#  'YAL023C',
#  'YAL024C',
#  'YAL025C',
#  'YAL027W',
#  'YAL028W',
#  'YAL029C',
#  'YAL030W',
#  'YAL031C',
#  'YAL032C',
#  'YAL033W',
#  'YAL034C',
#  'YAL034W-A',
#  'YAL036C',
#  'YAL037C-A',
#  'YAL037W',
#  'YAL038W',
#  'YAL039C',
#  'YAL040C',
#  'YAL041W',
#  'YAL042C-A',
#  'YAL042W',
#  'YAL043C',
#  'YAL044C',
#  'YAL044W-A',
#  'YAL045C',
#  'YAL046C',
#  'YAL048C',
#  'YAL049C',
#  'YAL051W',
#  'YAL053W',
#  'YAL054C',
#  'YAL055W',
#  'YAL056C-A',
#  'YAL056W',
#  'YAL058W',
#  'YAL059W',
#  'YAL060W',
#  'YAL061W',
#  'YAL062W',
#  'YAL063C',
#  'YAL063C-A',
#  'YAL064C-A',
#  'YAL064W',
#  'YAL065C',
#  'YAL066W',
#  'YAL067C',
#  'YAL067W-A',
#  'YAL068C',
#  'YAR002C-A',
#  'YAR002W',
#  'YAR003W',
#  'YAR007C',
#  'YAR014C',
#  'YAR015W',
#  'YAR018C',
#  'YAR019C',
#  'YAR020C',
#  'YAR023C',
#  'YAR027W',
#  'YAR028W',
#  'YAR029W',
#  'YAR030C',
#  'YAR031W',
#  'YAR033W',
#  'YAR035C-A',
#  'YAR035W',
#  'YAR037W',
#  'YAR040C',
#  'YAR042W',
#  'YAR043C',
#  'YAR044W',
#  'YAR047C',
#  'YAR050W',
#  'YAR066W',
#  'YAR068W',
#  'YAR071W',
#  'YAR073W',
#  'YAR075W',
#  'YBL001C',
#  'YBL002W',
#  'YBL003C',
#  'YBL005W',
#  'YBL006C',
#  'YBL007C',
#  'YBL008W',
#  'YBL008W-A',
#  'YBL009W',
#  'YBL010C',
#  'YBL011W',
#  'YBL013W',
#  'YBL015W',
#  'YBL017C',
#  'YBL019W',
#  'YBL020W',
#  'YBL021C',
#  'YBL022C',
#  'YBL023C',
#  'YBL024W',
#  'YBL026W',
#  'YBL027W',
#  'YBL028C',
#  'YBL029C-A',
#  'YBL029W',
#  'YBL031W',
#  'YBL032W',
#  'YBL034C',
#  'YBL035C',
#  'YBL036C',
#  'YBL037W',
#  'YBL039C',
#  'YBL039W-B',
#  'YBL040C',
#  'YBL041W',
#  'YBL042C',
#  'YBL043W',
#  'YBL044W',
#  'YBL046W',
#  'YBL047C',
#  'YBL048W',
#  'YBL049W',
#  'YBL050W',
#  'YBL051C',
#  'YBL052C',
#  'YBL053W',
#  'YBL054W',
#  'YBL055C',
#  'YBL056W',
#  'YBL057C',
#  'YBL058W',
#  'YBL059C-A',
#  'YBL059W',
#  'YBL060W',
#  'YBL061C',
#  'YBL062W',
#  'YBL063W',
#  'YBL064C',
#  'YBL065W',
#  'YBL066C',
#  'YBL067C',
#  'YBL068W',
#  'YBL069W',
#  'YBL070C',
#  'YBL071C',
#  'YBL071C-B',
#  'YBL071W-A',
#  'YBL072C',
#  'YBL074C',
#  'YBL075C',
#  'YBL076C',
#  'YBL078C',
#  'YBL079W',
#  'YBL080C',
#  'YBL081W',
#  'YBL082C',
#  'YBL083C',
#  'YBL084C',
#  'YBL085W',
#  'YBL086C',
#  'YBL087C',
#  'YBL088C',
#  'YBL089W',
#  'YBL090W',
#  'YBL091C',
#  'YBL091C-A',
#  'YBL095W',
#  'YBL096C',
#  'YBL097W',
#  'YBL098W',
#  'YBL100C',
#  'YBL100W-C',
#  'YBL101C',
#  'YBL102W',
#  'YBL103C',
#  'YBL104C',
#  'YBL105C',
#  'YBL106C',
#  'YBL107C',
#  'YBL108C-A',
#  'YBL111C',
#  'YBL112C',
#  'YBL113C',
#  'YBR001C',
#  'YBR002C',
#  'YBR003W',
#  'YBR004C',
#  'YBR005W',
#  'YBR006W',
#  'YBR007C',
#  'YBR008C',
#  'YBR009C',
#  'YBR010W',
#  'YBR011C',
#  'YBR012C',
#  'YBR013C',
#  'YBR014C',
#  'YBR015C',
#  'YBR016W',
#  'YBR017C',
#  'YBR018C',
#  'YBR019C',
#  'YBR020W',
#  'YBR022W',
#  'YBR023C',
#  'YBR024W',
#  'YBR025C',
#  'YBR026C',
#  'YBR027C',
#  'YBR028C',
#  'YBR029C',
#  'YBR030W',
#  'YBR031W',
#  'YBR032W',
#  'YBR033W',
#  'YBR034C',
#  'YBR035C',
#  'YBR036C',
#  'YBR037C',
#  'YBR038W',
#  'YBR039W',
#  'YBR040W',
#  'YBR041W',
#  'YBR042C',
#  'YBR043C',
#  'YBR044C',
#  'YBR045C',
#  'YBR046C',
#  'YBR047W',
#  'YBR048W',
#  'YBR049C',
#  'YBR050C',
#  'YBR051W',
#  'YBR052C',
#  'YBR053C',
#  'YBR054W',
#  'YBR055C',
#  'YBR056W',
#  'YBR056W-A',
#  'YBR057C',
#  'YBR058C',
#  'YBR058C-A',
#  'YBR059C',
#  'YBR060C',
#  'YBR061C',
#  'YBR062C',
#  'YBR063C',
#  'YBR064W',
#  'YBR065C',
#  'YBR066C',
#  'YBR067C',
#  'YBR068C',
#  'YBR069C',
#  'YBR070C',
#  'YBR071W',
#  'YBR072C-A',
#  'YBR072W',
#  'YBR073W',
#  'YBR074W',
#  'YBR075W',
#  'YBR076W',
#  'YBR077C',
#  'YBR078W',
#  'YBR079C',
#  'YBR080C',
#  'YBR082C',
#  'YBR083W',
#  'YBR084C-A',
#  'YBR084W',
#  'YBR085C-A',
#  'YBR085W',
#  'YBR086C',
#  'YBR087W',
#  'YBR088C',
#  'YBR089C-A',
#  'YBR090C',
#  'YBR092C',
#  'YBR093C',
#  'YBR094W',
#  'YBR095C',
#  'YBR096W',
#  'YBR097W',
#  'YBR098W',
#  'YBR099C',
#  'YBR100W',
#  'YBR101C',
#  'YBR102C',
#  'YBR103W',
#  'YBR104W',
#  'YBR105C',
#  'YBR107C',
#  'YBR108W',
#  'YBR109C',
#  'YBR110W',
#  'YBR111C',
#  'YBR111W-A',
#  'YBR112C',
#  'YBR114W',
#  'YBR116C',
#  'YBR117C',
#  'YBR118W',
#  'YBR119W',
#  'YBR120C',
#  'YBR121C',
#  'YBR122C',
#  'YBR123C',
#  'YBR125C',
#  'YBR126C',
#  'YBR128C',
#  'YBR129C',
#  'YBR130C',
#  'YBR131W',
#  'YBR132C',
#  'YBR133C',
#  'YBR134W',
#  'YBR135W',
#  'YBR136W',
#  'YBR137W',
#  'YBR138C',
#  'YBR139W',
#  'YBR141C',
#  'YBR142W',
#  'YBR143C',
#  'YBR145W',
#  'YBR146W',
#  'YBR147W',
#  'YBR148W',
#  'YBR149W',
#  'YBR150C',
#  'YBR151W',
#  'YBR152W',
#  'YBR153W',
#  'YBR154C',
#  'YBR156C',
#  'YBR157C',
#  'YBR158W',
#  'YBR160W',
#  'YBR161W',
#  'YBR162C',
#  'YBR162W-A',
#  'YBR163W',
#  'YBR164C',
#  'YBR165W',
#  'YBR166C',
#  'YBR167C',
#  'YBR168W',
#  'YBR169C',
#  'YBR170C',
#  'YBR171W',
#  'YBR172C',
#  'YBR173C',
#  'YBR175W',
#  'YBR176W',
#  'YBR177C',
#  'YBR178W',
#  'YBR179C',
#  'YBR180W',
#  'YBR181C',
#  'YBR182C',
#  'YBR182C-A',
#  'YBR183W',
#  'YBR184W',
#  'YBR185C',
#  'YBR186W',
#  'YBR187W',
#  'YBR188C',
#  'YBR189W',
#  'YBR191W',
#  'YBR193C',
#  'YBR194W',
#  'YBR195C',
#  'YBR196C',
#  'YBR196C-A',
#  'YBR196C-B',
#  'YBR197C',
#  'YBR198C',
#  'YBR199W',
#  'YBR200W',
#  'YBR200W-A',
#  'YBR201W',
#  'YBR202W',
#  'YBR203W',
#  'YBR204C',
#  'YBR205W',
#  'YBR206W',
#  'YBR207W',
#  'YBR208C',
#  'YBR210W',
#  'YBR211C',
#  'YBR212W',
#  'YBR213W',
#  'YBR214W',
#  'YBR215W',
#  'YBR216C',
#  'YBR217W',
#  'YBR218C',
#  'YBR219C',
#  'YBR220C',
#  'YBR221C',
#  'YBR221W-A',
#  'YBR222C',
#  'YBR223C',
#  'YBR224W',
#  'YBR225W',
#  'YBR226C',
#  'YBR227C',
#  'YBR228W',
#  'YBR229C',
#  'YBR230C',
#  'YBR230W-A',
#  'YBR231C',
#  'YBR232C',
#  'YBR233W',
#  'YBR234C',
#  'YBR235W',
#  'YBR236C',
#  'YBR237W',
#  'YBR238C',
#  'YBR239C',
#  'YBR240C',
#  'YBR241C',
#  'YBR242W',
#  'YBR244W',
#  'YBR245C',
#  'YBR246W',
#  'YBR247C',
#  'YBR249C',
#  'YBR250W',
#  'YBR252W',
#  'YBR253W',
#  'YBR254C',
#  'YBR255C-A',
#  'YBR255W',
#  'YBR256C',
#  'YBR257W',
#  'YBR258C',
#  'YBR259W',
#  'YBR260C',
#  'YBR261C',
#  'YBR262C',
#  'YBR263W',
#  'YBR264C',
#  'YBR265W',
#  'YBR267W',
#  'YBR268W',
#  'YBR269C',
#  'YBR270C',
#  'YBR271W',
#  'YBR272C',
#  'YBR273C',
#  'YBR274W',
#  'YBR275C',
#  'YBR276C',
#  'YBR277C',
#  'YBR278W',
#  'YBR279W',
#  'YBR280C',
#  'YBR281C',
#  'YBR283C',
#  'YBR284W',
#  'YBR285W',
#  'YBR286W',
#  'YBR287W',
#  'YBR288C',
#  'YBR289W',
#  'YBR290W',
#  'YBR291C',
#  'YBR292C',
#  'YBR293W',
#  'YBR294W',
#  'YBR295W',
#  'YBR296C',
#  'YBR296C-A',
#  'YBR297W',
#  'YBR298C',
#  'YBR298C-A',
#  'YBR299W',
#  'YBR300C',
#  'YBR301W',
#  'YCL001W',
#  'YCL001W-A',
#  'YCL001W-B',
#  'YCL002C',
#  'YCL005W',
#  'YCL005W-A',
#  'YCL006C',
#  'YCL008C',
#  'YCL009C',
#  'YCL010C',
#  'YCL011C',
#  'YCL012W',
#  'YCL013W',
#  'YCL014W',
#  'YCL016C',
#  'YCL017C',
#  'YCL022C',
#  'YCL023C',
#  'YCL024W',
#  'YCL025C',
#  'YCL026C',
#  'YCL026C-A',
#  'YCL026C-B',
#  'YCL027W',
#  'YCL028W',
#  'YCL029C',
#  'YCL031C',
#  'YCL032W',
#  'YCL033C',
#  'YCL034W',
#  'YCL035C',
#  'YCL036W',
#  'YCL038C',
#  'YCL039W',
#  'YCL040W',
#  'YCL042W',
#  'YCL043C',
#  'YCL044C',
#  'YCL045C',
#  'YCL046W',
#  'YCL047C',
#  'YCL048W',
#  'YCL049C',
#  'YCL050C',
#  'YCL051W',
#  'YCL052C',
#  'YCL055W',
#  'YCL056C',
#  'YCL057C-A',
#  'YCL057W',
#  'YCL058W-A',
#  'YCL059C',
#  'YCL060C',
#  'YCL061C',
#  'YCL062W',
#  'YCL063W',
#  'YCL064C',
#  'YCL068C',
#  'YCL069W',
#  'YCL074W',
#  'YCL075W',
#  'YCL076W',
#  'YCR001W',
#  'YCR002C',
#  'YCR004C',
#  'YCR005C',
#  'YCR006C',
#  'YCR007C',
#  'YCR008W',
#  'YCR009C',
#  'YCR010C',
#  'YCR011C',
#  'YCR014C',
#  'YCR015C',
#  'YCR016W',
#  'YCR017C',
#  'YCR019W',
#  'YCR020C',
#  'YCR020C-A',
#  'YCR020W-B',
#  'YCR021C',
#  'YCR022C',
#  'YCR023C',
#  'YCR024C',
#  'YCR024C-A',
#  'YCR024C-B',
#  'YCR025C',
#  'YCR026C',
#  'YCR027C',
#  'YCR028C-A',
#  'YCR030C',
#  'YCR031C',
#  'YCR032W',
#  'YCR033W',
#  'YCR034W',
#  'YCR035C',
#  'YCR036W',
#  'YCR037C',
#  'YCR039C',
#  'YCR045C',
#  'YCR046C',
#  'YCR048W',
#  'YCR049C',
#  'YCR050C',
#  'YCR051W',
#  'YCR052W',
#  'YCR053W',
#  'YCR054C',
#  'YCR057C',
#  'YCR059C',
#  'YCR060W',
#  'YCR061W',
#  'YCR062W',
#  'YCR063W',
#  'YCR065W',
#  'YCR066W',
#  'YCR067C',
#  'YCR068W',
#  'YCR069W',
#  'YCR071C',
#  'YCR072C',
#  'YCR073C',
#  'YCR073W-A',
#  'YCR075C',
#  'YCR075W-A',
#  'YCR076C',
#  'YCR077C',
#  'YCR079W',
#  'YCR082W',
#  'YCR083W',
#  'YCR085W',
#  'YCR086W',
#  'YCR087C-A',
#  'YCR087W',
#  'YCR088W',
#  'YCR089W',
#  'YCR090C',
#  'YCR091W',
#  'YCR092C',
#  'YCR093W',
#  'YCR094W',
#  'YCR095C',
#  'YCR095W-A',
#  'YCR097W',
#  'YCR098C',
#  'YCR099C',
#  'YCR100C',
#  'YCR101C',
#  'YCR102C',
#  'YCR102W-A',
#  'YCR104W',
#  'YCR105W',
#  'YCR106W',
#  'YCR107W',
#  'YDL001W',
#  'YDL002C',
#  'YDL003W',
#  'YDL005C',
#  'YDL006W',
#  'YDL007W',
#  'YDL008W',
#  'YDL010W',
#  'YDL011C',
#  'YDL012C',
#  'YDL013W',
#  'YDL014W',
#  'YDL015C',
#  'YDL017W',
#  'YDL018C',
#  'YDL019C',
#  'YDL020C',
#  'YDL021W',
#  'YDL022W',
#  'YDL023C',
#  'YDL024C',
#  'YDL025C',
#  'YDL026W',
#  'YDL027C',
#  'YDL028C',
#  'YDL029W',
#  'YDL030W',
#  'YDL031W',
#  'YDL033C',
#  'YDL035C',
#  'YDL036C',
#  'YDL037C',
#  'YDL038C',
#  'YDL039C',
#  'YDL040C',
#  'YDL043C',
#  'YDL044C',
#  'YDL045C',
#  'YDL048C',
#  'YDL049C',
#  'YDL050C',
#  'YDL051W',
#  'YDL052C',
#  'YDL053C',
#  'YDL054C',
#  'YDL056W',
#  'YDL057W',
#  'YDL058W',
#  'YDL059C',
#  'YDL060W',
#  'YDL061C',
#  'YDL062W',
#  'YDL063C',
#  'YDL064W',
#  'YDL065C',
#  'YDL066W',
#  'YDL067C',
#  'YDL069C',
#  'YDL070W',
#  'YDL071C',
#  'YDL073W',
#  'YDL074C',
#  'YDL076C',
#  'YDL077C',
#  'YDL078C',
#  'YDL079C',
#  'YDL080C',
#  'YDL082W',
#  'YDL083C',
#  'YDL084W',
#  'YDL085C-A',
#  'YDL085W',
#  'YDL086W',
#  'YDL087C',
#  'YDL088C',
#  'YDL089W',
#  'YDL090C',
#  'YDL091C',
#  'YDL093W',
#  'YDL094C',
#  'YDL095W',
#  'YDL096C',
#  'YDL097C',
#  'YDL098C',
#  'YDL099W',
#  'YDL100C',
#  'YDL101C',
#  'YDL102W',
#  'YDL103C',
#  'YDL104C',
#  'YDL105W',
#  'YDL106C',
#  'YDL107W',
#  'YDL108W',
#  'YDL109C',
#  'YDL110C',
#  'YDL111C',
#  'YDL112W',
#  'YDL113C',
#  'YDL114W',
#  'YDL115C',
#  'YDL116W',
#  'YDL117W',
#  'YDL118W',
#  'YDL119C',
#  'YDL121C',
#  'YDL122W',
#  'YDL123W',
#  'YDL124W',
#  'YDL125C',
#  'YDL126C',
#  'YDL127W',
#  'YDL128W',
#  'YDL129W',
#  'YDL130W',
#  'YDL130W-A',
#  'YDL131W',
#  'YDL132W',
#  'YDL133C-A',
#  'YDL133W',
#  'YDL134C',
#  'YDL135C',
#  'YDL136W',
#  'YDL137W',
#  'YDL138W',
#  'YDL139C',
#  'YDL140C',
#  'YDL142C',
#  'YDL143W',
#  'YDL144C',
#  'YDL145C',
#  'YDL146W',
#  'YDL147W',
#  'YDL148C',
#  'YDL149W',
#  'YDL150W',
#  'YDL153C',
#  'YDL154W',
#  'YDL155W',
#  'YDL156W',
#  'YDL157C',
#  'YDL159W-A',
#  'YDL160C-A',
#  'YDL161W',
#  'YDL162C',
#  'YDL164C',
#  'YDL165W',
#  'YDL167C',
#  'YDL168W',
#  'YDL169C',
#  'YDL170W',
#  'YDL171C',
#  'YDL172C',
#  'YDL173W',
#  'YDL174C',
#  'YDL175C',
#  'YDL176W',
#  'YDL177C',
#  'YDL178W',
#  'YDL179W',
#  'YDL180W',
#  'YDL181W',
#  'YDL182W',
#  'YDL183C',
#  'YDL184C',
#  'YDL185W',
#  'YDL186W',
#  'YDL187C',
#  'YDL188C',
#  'YDL189W',
#  'YDL190C',
#  'YDL191W',
#  'YDL192W',
#  'YDL193W',
#  'YDL194W',
#  'YDL195W',
#  'YDL197C',
#  'YDL199C',
#  'YDL200C',
#  'YDL201W',
#  'YDL203C',
#  'YDL204W',
#  'YDL206W',
#  'YDL207W',
#  'YDL208W',
#  'YDL209C',
#  'YDL210W',
#  'YDL211C',
#  'YDL213C',
#  'YDL214C',
#  'YDL215C',
#  'YDL216C',
#  'YDL217C',
#  'YDL218W',
#  'YDL219W',
#  'YDL220C',
#  'YDL222C',
#  'YDL223C',
#  'YDL224C',
#  'YDL225W',
#  'YDL226C',
#  'YDL229W',
#  'YDL230W',
#  'YDL231C',
#  'YDL233W',
#  'YDL234C',
#  'YDL236W',
#  'YDL237W',
#  'YDL238C',
#  'YDL239C',
#  'YDL240W',
#  'YDL241W',
#  'YDL242W',
#  'YDL243C',
#  'YDL244W',
#  'YDL245C',
#  'YDL246C',
#  'YDL248W',
#  'YDR001C',
#  'YDR002W',
#  'YDR003W',
#  'YDR003W-A',
#  'YDR004W',
#  'YDR005C',
#  'YDR006C',
#  'YDR007W',
#  'YDR009W',
#  'YDR010C',
#  'YDR011W',
#  'YDR012W',
#  'YDR013W',
#  'YDR014W',
#  'YDR015C',
#  'YDR016C',
#  'YDR018C',
#  'YDR019C',
#  'YDR020C',
#  'YDR021W',
#  'YDR022C',
#  'YDR024W',
#  'YDR025W',
#  'YDR026C',
#  'YDR029W',
#  'YDR030C',
#  'YDR031W',
#  'YDR032C',
#  'YDR033W',
#  'YDR034C-A',
#  'YDR034W-B',
#  'YDR035W',
#  'YDR036C',
#  'YDR037W',
#  'YDR038C',
#  'YDR040C',
#  'YDR042C',
#  'YDR043C',
#  'YDR044W',
#  'YDR045C',
#  'YDR046C',
#  'YDR047W',
#  'YDR049W',
#  'YDR050C',
#  'YDR051C',
#  'YDR052C',
#  'YDR054C',
#  'YDR055W',
#  'YDR056C',
#  'YDR057W',
#  'YDR058C',
#  'YDR059C',
#  'YDR060W',
#  'YDR061W',
#  'YDR062W',
#  'YDR063W',
#  'YDR064W',
#  'YDR065W',
#  'YDR066C',
#  'YDR067C',
#  'YDR068W',
#  'YDR069C',
#  'YDR070C',
#  'YDR071C',
#  'YDR072C',
#  'YDR073W',
#  'YDR074W',
#  'YDR075W',
#  'YDR076W',
#  'YDR077W',
#  'YDR078C',
#  'YDR079W',
#  'YDR080W',
#  'YDR081C',
#  'YDR082W',
#  'YDR083W',
#  'YDR084C',
#  'YDR085C',
#  'YDR086C',
#  'YDR087C',
#  'YDR088C',
#  'YDR089W',
#  'YDR090C',
#  'YDR091C',
#  'YDR092W',
#  'YDR093W',
#  'YDR094W',
#  'YDR095C',
#  'YDR096W',
#  'YDR097C',
#  'YDR098C',
#  'YDR099W',
#  'YDR100W',
#  'YDR101C',
#  'YDR102C',
#  'YDR104C',
#  'YDR105C',
#  'YDR106W',
#  'YDR107C',
#  'YDR108W',
#  'YDR109C',
#  'YDR110W',
#  'YDR111C',
#  'YDR112W',
#  'YDR113C',
#  'YDR116C',
#  'YDR117C',
#  'YDR118W',
#  'YDR119W',
#  'YDR120C',
#  'YDR121W',
#  'YDR122W',
#  'YDR123C',
#  'YDR124W',
#  'YDR125C',
#  'YDR126W',
#  'YDR127W',
#  'YDR128W',
#  'YDR129C',
#  'YDR130C',
#  'YDR131C',
#  'YDR132C',
#  'YDR133C',
#  'YDR134C',
#  'YDR135C',
#  'YDR137W',
#  'YDR139C',
#  'YDR141C',
#  'YDR142C',
#  'YDR143C',
#  'YDR144C',
#  ...]

# %%
## Get list of GI clusters/modules

# Get modules from module dataframe. Make list unique
GI_Modules_list = list(np.unique(GI_Modules['Pathway/complex level (PCC > 0.4)']))

# Make empty dictionary with keys as cluster number
GI_module_dict = {key: [] for key in GI_Modules_list}

# Make 'None' cluster to store connector ORFs
GI_module_dict['None'] = []


# Sort ORFs into dictionnary of GI modules
for ORF in GI_ORF_list:
    if ORF in list(GI_Modules['Systematic array ORF  name']): # If the ORF is a module
        
        # Find cluster to which the ORF belongs:
        cluster = GI_Modules[GI_Modules['Systematic array ORF  name'] == ORF]['Pathway/complex level (PCC > 0.4)'].values
        
        # Make sure ORF belongs to only one cluster
        assert(len(cluster) == 1)
        cluster = cluster[0] # Get value from array containing 1 item
        
        
        # If the ORF has not yet been sorted into this cluster:
        if ORF not in GI_module_dict[cluster]:
            GI_module_dict[cluster].append(ORF) # Add ORF to cluster in dict
        
        else:
            continue
        
    # If ORF is not in a cluster (not in a module):
    elif ORF not in list(GI_Modules['Systematic array ORF  name']):
        GI_module_dict['None'].append(ORF) # Add to non-module list in dict

GI_module_dict
# Out:
# {1: ['YDL077C', 'YML001W'],
#  2: ['YBR288C',
#   'YGR261C',
#   'YHR012W',
#   'YJL024C',
#   'YJL053W',
#   'YJL154C',
#   'YLL040C',
#   'YLR360W',
#   'YMR004W',
#   'YOR068C',
#   'YOR132W',
#   'YPL120W',
#   'YPL195W'],
#  3: ['YBR198C',
#   'YDR145W',
#   'YGL112C',
#   'YML015C',
#   'YML098W',
#   'YMR005W',
#   'YMR236W',
#   'YOR194C'],
#  4: ['YBR244W', 'YBR280C'],
#  5: ['YNR017W', 'YPL063W'],
#  6: ['YDL087C', 'YGR013W', 'YLR298C'],
#  7: ['YGL031C', 'YKR027W', 'YOR167C'],
#  8: ['YFL003C', 'YOL116W'],
#  9: ['YDL020C', 'YDL126C', 'YDL190C'],
#  10: ['YBR139W', 'YGR271W', 'YLL048C', 'YOL056W', 'YOR248W'],
#  11: ['YBR215W', 'YJR140C', 'YMR028W', 'YMR073C', 'YNL091W', 'YOR014W'],
#  12: ['YLR398C', 'YOR076C', 'YPR189W'],
#  13: ['YFR028C', 'YKL022C'],
#  14: ['YML126C', 'YNR043W'],
#  15: ['YBR247C', 'YDL208W', 'YDR064W', 'YDR339C', 'YMR229C', 'YPL266W'],
#  16: ['YBL087C',
#   'YBR048W',
#   'YBR181C',
#   'YDL062W',
#   'YDL083C',
#   'YDL130W',
#   'YDL136W',
#   'YDR496C',
#   'YFR031C-A',
#   'YFR032C-A',
#   'YGR034W',
#   'YGR085C',
#   'YGR118W',
#   'YGR148C',
#   'YGR214W',
#   'YHR203C',
#   'YIL133C',
#   'YJL177W',
#   'YJR094W-A',
#   'YKR057W',
#   'YKR081C',
#   'YLR264W',
#   'YMR143W',
#   'YMR230W',
#   'YNL067W',
#   'YNL096C',
#   'YOR294W'],
#  17: ['YAL041W', 'YBR109C', 'YLR229C', 'YLR319C', 'YOR122C', 'YOR326W'],
#  18: ['YAL025C',
#   'YBR142W',
#   'YGL078C',
#   'YGR103W',
#   'YHR066W',
#   'YHR088W',
#   'YKL021C',
#   'YLR002C',
#   'YLR276C',
#   'YMR049C',
#   'YMR269W',
#   'YNL061W',
#   'YNR038W',
#   'YOR309C',
#   'YPL211W'],
#  19: ['YDR208W', 'YER093C', 'YKL203C'],
#  20: ['YBR103W',
#   'YCR033W',
#   'YGL194C',
#   'YKR028W',
#   'YKR029C',
#   'YLR418C',
#   'YOR123C',
#   'YPR161C'],
#  21: ['YDL105W'],
#  22: ['YDR092W', 'YGL087C'],
#  23: ['YGL151W', 'YPR070W'],
#  24: ['YLR373C', 'YLR374C', 'YLR430W', 'YPL128C'],
#  25: ['YCR077C', 'YJL124C'],
#  26: ['YMR223W', 'YPL047W'],
#  27: ['YDR076W',
#   'YDR369C',
#   'YER095W',
#   'YJL047C',
#   'YJL115W',
#   'YLR320W',
#   'YML032C'],
#  28: ['YBR255W', 'YHR151C'],
#  29: ['YDR126W',
#   'YER136W',
#   'YFL005W',
#   'YGL233W',
#   'YIL118W',
#   'YLR166C',
#   'YPR055W'],
#  30: ['YCL029C',
#   'YDR150W',
#   'YDR424C',
#   'YDR488C',
#   'YHR129C',
#   'YKR054C',
#   'YLL049W',
#   'YLR200W',
#   'YMR294W',
#   'YMR299C',
#   'YNL153C',
#   'YOR269W',
#   'YPL155C',
#   'YPL174C'],
#  31: ['YBR195C', 'YML102W', 'YPR018W'],
#  32: ['YBR079C', 'YOR361C'],
#  33: ['YDR086C', 'YLR378C'],
#  34: ['YMR239C'],
#  35: ['YGL227W', 'YMR135C'],
#  36: ['YHL025W', 'YJL175W'],
#  37: ['YAR002W',
#   'YDL088C',
#   'YDR002W',
#   'YGL092W',
#   'YGL247W',
#   'YHR036W',
#   'YIL040W',
#   'YIL115C',
#   'YJL039C',
#   'YJR042W',
#   'YKL069W',
#   'YKR082W',
#   'YLR018C',
#   'YLR293C',
#   'YLR335W',
#   'YLR347C',
#   'YML103C',
#   'YMR153C-A',
#   'YMR153W',
#   'YMR235C'],
#  38: ['YDL074C', 'YDR469W', 'YPL055C'],
#  39: ['YDL002C', 'YER092W', 'YFL013C', 'YNL021W', 'YPR179C'],
#  40: ['YMR186W', 'YOR027W'],
#  41: ['YJL155C', 'YKR058W', 'YLL058W', 'YPR001W'],
#  42: ['YAR029W',
#   'YDR080W',
#   'YER162C',
#   'YGL212W',
#   'YHL033C',
#   'YJR084W',
#   'YMR201C',
#   'YOL108C',
#   'YPL022W'],
#  43: ['YGL257C', 'YIL067C', 'YKL216W', 'YLR346C'],
#  44: ['YDL111C', 'YGR195W', 'YJL050W'],
#  45: ['YCR002C', 'YHR107C', 'YJR076C', 'YLR314C'],
#  46: ['YGL217C', 'YPL269W'],
#  47: ['YDR060W', 'YDR236C', 'YGL207W', 'YGR113W', 'YKL052C', 'YMR227C'],
#  48: ['YBR026C',
#   'YDL149W',
#   'YER061C',
#   'YFR021W',
#   'YGL180W',
#   'YHR049W',
#   'YHR067W',
#   'YJL046W',
#   'YKL055C',
#   'YLR239C',
#   'YNR007C',
#   'YOR196C',
#   'YOR221C'],
#  49: ['YDR392W', 'YDR512C', 'YGR182C', 'YPL181W', 'YPL182C'],
#  50: ['YCR031C', 'YDR156W', 'YJL148W', 'YOR341W'],
#  51: ['YBL050W',
#   'YBL102W',
#   'YBR029C',
#   'YBR080C',
#   'YBR164C',
#   'YBR254C',
#   'YDL058W',
#   'YDL100C',
#   'YDL145C',
#   'YDR108W',
#   'YDR189W',
#   'YDR203W',
#   'YDR238C',
#   'YDR246W',
#   'YER083C',
#   'YER084W',
#   'YER157W',
#   'YFL038C',
#   'YFR051C',
#   'YGL005C',
#   'YGL020C',
#   'YGL054C',
#   'YGL137W',
#   'YGR089W',
#   'YGR120C',
#   'YGR172C',
#   'YIL004C',
#   'YJL004C',
#   'YJL123C',
#   'YJR033C',
#   'YJR060W',
#   'YKL196C',
#   'YKR019C',
#   'YKR020W',
#   'YKR068C',
#   'YLR026C',
#   'YLR039C',
#   'YLR078C',
#   'YLR261C',
#   'YLR262C',
#   'YLR267W',
#   'YLR268W',
#   'YLR269C',
#   'YLR309C',
#   'YML071C',
#   'YML077W',
#   'YMR197C',
#   'YMR274C',
#   'YMR292W',
#   'YNL041C',
#   'YNL049C',
#   'YNL051W',
#   'YOL018C',
#   'YOL111C',
#   'YOR007C',
#   'YOR070C',
#   'YOR109W',
#   'YOR164C',
#   'YOR216C',
#   'YOR370C',
#   'YPL010W',
#   'YPL051W'],
#  52: ['YAL023C',
#   'YAL058W',
#   'YBL040C',
#   'YBL082C',
#   'YBL083C',
#   'YBR004C',
#   'YBR015C',
#   'YBR070C',
#   'YBR229C',
#   'YBR260C',
#   'YBR276C',
#   'YCR017C',
#   'YDL095W',
#   'YDL096C',
#   'YDR302W',
#   'YDR331W',
#   'YDR372C',
#   'YDR389W',
#   'YDR414C',
#   'YDR434W',
#   'YDR437W',
#   'YDR525W',
#   'YFL025C',
#   'YGL022W',
#   'YGL027C',
#   'YGL065C',
#   'YGL084C',
#   'YGL142C',
#   'YGL226C-A',
#   'YGR166W',
#   'YGR227W',
#   'YHR188C',
#   'YJL002C',
#   'YJL034W',
#   'YJL062W',
#   'YJL091C',
#   'YJL174W',
#   'YJR075W',
#   'YJR117W',
#   'YLR087C',
#   'YLR088W',
#   'YLR459W',
#   'YML019W',
#   'YMR200W',
#   'YMR214W',
#   'YMR238W',
#   'YMR307W',
#   'YNL038W',
#   'YOR002W',
#   'YOR067C',
#   'YOR085W',
#   'YOR103C',
#   'YOR149C',
#   'YOR254C',
#   'YOR336W',
#   'YPL076W',
#   'YPL094C',
#   'YPL227C'],
#  53: ['YKL089W', 'YKL112W'],
#  54: ['YNR056C', 'YPR003C'],
#  55: ['YCL024W',
#   'YDR305C',
#   'YDR522C',
#   'YER150W',
#   'YGR045C',
#   'YHR171W',
#   'YIR016W',
#   'YJL212C',
#   'YJL213W',
#   'YJL215C',
#   'YJR115W',
#   'YKR040C',
#   'YKR064W',
#   'YKR093W',
#   'YLR093C',
#   'YLR214W',
#   'YLR380W',
#   'YML057W',
#   'YML060W',
#   'YMR155W',
#   'YNR059W',
#   'YNR075W',
#   'YOR271C',
#   'YPL054W',
#   'YPL166W',
#   'YPR054W',
#   'YPR185W'],
#  56: ['YGL028C', 'YGR201C'],
#  57: ['YDR122W', 'YLR096W'],
#  58: ['YAL011W',
#   'YBR231C',
#   'YDR334W',
#   'YDR485C',
#   'YFR037C',
#   'YJL168C',
#   'YJL169W',
#   'YLR033W',
#   'YLR085C',
#   'YML041C',
#   'YMR075C-A',
#   'YMR075W',
#   'YPR023C'],
#  59: ['YAR007C',
#   'YBL023C',
#   'YBL035C',
#   'YBR060C',
#   'YBR087W',
#   'YCL060C',
#   'YCL061C',
#   'YDL102W',
#   'YDR013W',
#   'YDR217C',
#   'YDR489W',
#   'YER173W',
#   'YGL113W',
#   'YHR118C',
#   'YIR008C',
#   'YJL072C',
#   'YJL194W',
#   'YJR043C',
#   'YJR046W',
#   'YJR068W',
#   'YKL045W',
#   'YKL113C',
#   'YLL004W',
#   'YLR103C',
#   'YLR274W',
#   'YML065W',
#   'YMR048W',
#   'YNL102W',
#   'YOR024W',
#   'YOR025W',
#   'YOR368W',
#   'YPL194W',
#   'YPR162C'],
#  60: ['YBR193C',
#   'YDL108W',
#   'YGL130W',
#   'YHR058C',
#   'YJL128C',
#   'YLR006C',
#   'YLR113W',
#   'YMR039C',
#   'YNR045W',
#   'YOL050C',
#   'YOL135C',
#   'YOR174W',
#   'YPL228W',
#   'YPR086W'],
#  61: ['YBR094W',
#   'YBR098W',
#   'YBR099C',
#   'YBR100W',
#   'YBR228W',
#   'YDL064W',
#   'YDR288W',
#   'YDR363W',
#   'YDR386W',
#   'YDR510W',
#   'YLR007W',
#   'YLR135W',
#   'YMR190C',
#   'YPL020C'],
#  62: ['YDR020C', 'YKR102W', 'YLR177W', 'YOR005C'],
#  63: ['YBL074C',
#   'YBR064W',
#   'YBR119W',
#   'YBR188C',
#   'YBR237W',
#   'YDL030W',
#   'YDL043C',
#   'YDR243C',
#   'YDR416W',
#   'YDR482C',
#   'YFR005C',
#   'YGL120C',
#   'YGL174W',
#   'YGR129W',
#   'YHR086W',
#   'YIR005W',
#   'YJL203W',
#   'YJR050W',
#   'YKL074C',
#   'YKL173W',
#   'YLR016C',
#   'YLR117C',
#   'YML049C',
#   'YMR213W',
#   'YNR004W',
#   'YOR308C',
#   'YPR057W',
#   'YPR094W'],
#  64: ['YHL002W', 'YNR005C'],
#  65: ['YDR179W-A', 'YKL171W'],
#  66: ['YBL041W',
#   'YDL097C',
#   'YDL147W',
#   'YER094C',
#   'YFR004W',
#   'YFR050C',
#   'YGL011C',
#   'YGL048C',
#   'YGR135W',
#   'YHR027C',
#   'YKL145W',
#   'YLR021W',
#   'YLR199C',
#   'YMR067C',
#   'YOL038W',
#   'YOR157C',
#   'YOR242C',
#   'YOR246C',
#   'YOR259C',
#   'YOR362C',
#   'YPL144W',
#   'YPR103W',
#   'YPR108W'],
#  67: ['YDL132W', 'YJL005W'],
#  68: ['YGL014W', 'YHR167W', 'YNL140C'],
#  69: ['YAL034W-A',
#   'YBL034C',
#   'YBR107C',
#   'YBR156C',
#   'YBR211C',
#   'YCL016C',
#   'YCR065W',
#   'YDL003W',
#   'YDL028C',
#   'YDR014W',
#   'YDR113C',
#   'YDR180W',
#   'YDR201W',
#   'YDR254W',
#   'YDR318W',
#   'YER147C',
#   'YFL008W',
#   'YGL086W',
#   'YGL093W',
#   'YGL216W',
#   'YGR179C',
#   'YHR191C',
#   'YIR010W',
#   'YJL013C',
#   'YJL030W',
#   'YJL074C',
#   'YJR135C',
#   'YKR083C',
#   'YLR045C',
#   'YLR381W',
#   'YML124C',
#   'YMR076C',
#   'YMR078C',
#   'YMR117C',
#   'YMR138W',
#   'YMR198W',
#   'YOR026W',
#   'YOR195W',
#   'YOR349W',
#   'YPL008W',
#   'YPL017C',
#   'YPL018W',
#   'YPL209C',
#   'YPL233W',
#   'YPL241C',
#   'YPL253C',
#   'YPR046W',
#   'YPR135W',
#   'YPR141C'],
#  70: ['YIL146C', 'YJL116C'],
#  71: ['YDR349C', 'YGL203C', 'YLR110C', 'YLR111W'],
#  72: ['YBR082C'],
#  73: ['YBL084C',
#   'YBR134W',
#   'YDR260C',
#   'YDR394W',
#   'YFR052W',
#   'YGL116W',
#   'YHR166C',
#   'YHR200W',
#   'YIR011C',
#   'YKL101W',
#   'YLR102C',
#   'YOR249C',
#   'YPR119W'],
#  74: ['YBL061C',
#   'YBL062W',
#   'YBL105C',
#   'YBR023C',
#   'YBR078W',
#   'YDL103C',
#   'YDL203C',
#   'YER149C',
#   'YER155C',
#   'YGR196C',
#   'YGR217W',
#   'YGR228W',
#   'YGR229C',
#   'YHR030C',
#   'YHR142W',
#   'YJL095W',
#   'YJL099W',
#   'YJL159W',
#   'YKL079W',
#   'YKL190W',
#   'YLL021W',
#   'YLR330W',
#   'YLR332W',
#   'YMR124W',
#   'YOL003C',
#   'YPL089C'],
#  75: ['YLR306W', 'YOR277C', 'YPL003W'],
#  76: ['YBR095C', 'YIL084C', 'YMR263W', 'YNL097C', 'YOL004W'],
#  77: ['YDR398W', 'YHR196W'],
#  78: ['YBL026W', 'YDR378C', 'YDR473C', 'YNL147W', 'YPR178W'],
#  79: ['YKR092C', 'YLR397C', 'YNR053C', 'YPR016C'],
#  80: ['YDL140C', 'YDR527W', 'YMR281W', 'YOR262W'],
#  81: ['YBL007C',
#   'YCR009C',
#   'YDL029W',
#   'YDL143W',
#   'YDR188W',
#   'YDR212W',
#   'YDR276C',
#   'YIL034C',
#   'YIL062C',
#   'YIL095W',
#   'YIR006C',
#   'YJR064W',
#   'YJR065C',
#   'YKL007W',
#   'YMR109W',
#   'YNL138W',
#   'YNR035C',
#   'YOR181W'],
#  82: ['YCL045C', 'YCL046W'],
#  83: ['YAL055W',
#   'YBR238C',
#   'YCL044C',
#   'YDL065C',
#   'YDR244W',
#   'YDR265W',
#   'YDR316W',
#   'YDR329C',
#   'YGL152C',
#   'YGL153W',
#   'YGR077C',
#   'YGR133W',
#   'YJL210W',
#   'YJL211C',
#   'YKL137W',
#   'YKL197C',
#   'YKR065C',
#   'YLR191W',
#   'YMR026C',
#   'YMR035W',
#   'YMR115W',
#   'YMR163C',
#   'YMR204C',
#   'YNR018W',
#   'YOL044W',
#   'YPR024W'],
#  84: ['YDR228C', 'YDR289C', 'YDR290W', 'YGL044C', 'YMR061W'],
#  85: ['YGL045W', 'YGL046W', 'YMR063W', 'YMR154C', 'YOR275C'],
#  86: ['YDL014W',
#   'YDL209C',
#   'YDR050C',
#   'YDR196C',
#   'YHR083W',
#   'YLR457C',
#   'YML046W',
#   'YML125C',
#   'YMR268C',
#   'YNR026C',
#   'YOR074C'],
#  87: ['YER151C', 'YNR051C'],
#  88: ['YGL145W', 'YLR440C'],
#  89: ['YLR066W', 'YML130C'],
#  90: ['YPR075C', 'YPR076W'],
#  91: ['YAL001C', 'YDR362C'],
#  92: ['YKL148C', 'YLL041C'],
#  93: ['YDL229W', 'YMR070W'],
#  94: ['YBL097W', 'YDR325W'],
#  95: ['YGR140W', 'YMR168C'],
#  96: ['YLR395C', 'YOR037W'],
#  97: ['YGL019W', 'YOR039W'],
#  98: ['YBR160W', 'YFL009W'],
#  99: ['YDR435C', 'YIL153W', 'YIL154C', 'YPL152W', 'YPR040W'],
#  100: ['YDR062W', 'YMR296C'],
#  101: ['YOR204W'],
#  102: ['YFR008W',
#   'YIL158W',
#   'YLR238W',
#   'YMR029C',
#   'YMR052W',
#   'YNL127W',
#   'YNR032W'],
#  103: ['YGL211W',
#   'YGR200C',
#   'YHR111W',
#   'YIL008W',
#   'YKL110C',
#   'YLR384C',
#   'YMR312W',
#   'YNL119W',
#   'YNL120C',
#   'YOR251C',
#   'YPL086C',
#   'YPL101W',
#   'YPL102C'],
#  105: ['YHR050W', 'YNL142W'],
#  106: ['YML033W', 'YML034W'],
#  107: ['YFL039C', 'YIL048W'],
#  108: ['YNL006W'],
#  109: ['YGR072W', 'YHR077C', 'YMR080C'],
#  110: ['YMR022W', 'YMR264W'],
#  111: ['YKR084C', 'YNL001W'],
#  112: ['YDL017W', 'YDR052C'],
#  'None': ['YAL002W',
#   'YAL004W',
#   'YAL005C',
#   'YAL007C',
#   'YAL008W',
#   'YAL009W',
#   'YAL010C',
#   'YAL012W',
#   'YAL013W',
#   'YAL014C',
#   'YAL015C',
#   'YAL016C-B',
#   'YAL017W',
#   'YAL018C',
#   'YAL019W',
#   'YAL020C',
#   'YAL021C',
#   'YAL022C',
#   'YAL024C',
#   'YAL027W',
#   'YAL028W',
#   'YAL029C',
#   'YAL030W',
#   'YAL031C',
#   'YAL032C',
#   'YAL033W',
#   'YAL034C',
#   'YAL036C',
#   'YAL037C-A',
#   'YAL037W',
#   'YAL038W',
#   'YAL039C',
#   'YAL040C',
#   'YAL042C-A',
#   'YAL042W',
#   'YAL043C',
#   'YAL044C',
#   'YAL044W-A',
#   'YAL045C',
#   'YAL046C',
#   'YAL048C',
#   'YAL049C',
#   'YAL051W',
#   'YAL053W',
#   'YAL054C',
#   'YAL056C-A',
#   'YAL056W',
#   'YAL059W',
#   'YAL060W',
#   'YAL061W',
#   'YAL062W',
#   'YAL063C',
#   'YAL063C-A',
#   'YAL064C-A',
#   'YAL064W',
#   'YAL065C',
#   'YAL066W',
#   'YAL067C',
#   'YAL067W-A',
#   'YAL068C',
#   'YAR002C-A',
#   'YAR003W',
#   'YAR014C',
#   'YAR015W',
#   'YAR018C',
#   'YAR019C',
#   'YAR020C',
#   'YAR023C',
#   'YAR027W',
#   'YAR028W',
#   'YAR030C',
#   'YAR031W',
#   'YAR033W',
#   'YAR035C-A',
#   'YAR035W',
#   'YAR037W',
#   'YAR040C',
#   'YAR042W',
#   'YAR043C',
#   'YAR044W',
#   'YAR047C',
#   'YAR050W',
#   'YAR066W',
#   'YAR068W',
#   'YAR071W',
#   'YAR073W',
#   'YAR075W',
#   'YBL001C',
#   'YBL002W',
#   'YBL003C',
#   'YBL005W',
#   'YBL006C',
#   'YBL008W',
#   'YBL008W-A',
#   'YBL009W',
#   'YBL010C',
#   'YBL011W',
#   'YBL013W',
#   'YBL015W',
#   'YBL017C',
#   'YBL019W',
#   'YBL020W',
#   'YBL021C',
#   'YBL022C',
#   'YBL024W',
#   'YBL027W',
#   'YBL028C',
#   'YBL029C-A',
#   'YBL029W',
#   'YBL031W',
#   'YBL032W',
#   'YBL036C',
#   'YBL037W',
#   'YBL039C',
#   'YBL039W-B',
#   'YBL042C',
#   'YBL043W',
#   'YBL044W',
#   'YBL046W',
#   'YBL047C',
#   'YBL048W',
#   'YBL049W',
#   'YBL051C',
#   'YBL052C',
#   'YBL053W',
#   'YBL054W',
#   'YBL055C',
#   'YBL056W',
#   'YBL057C',
#   'YBL058W',
#   'YBL059C-A',
#   'YBL059W',
#   'YBL060W',
#   'YBL063W',
#   'YBL064C',
#   'YBL065W',
#   'YBL066C',
#   'YBL067C',
#   'YBL068W',
#   'YBL069W',
#   'YBL070C',
#   'YBL071C',
#   'YBL071C-B',
#   'YBL071W-A',
#   'YBL072C',
#   'YBL075C',
#   'YBL076C',
#   'YBL078C',
#   'YBL079W',
#   'YBL080C',
#   'YBL081W',
#   'YBL085W',
#   'YBL086C',
#   'YBL088C',
#   'YBL089W',
#   'YBL090W',
#   'YBL091C',
#   'YBL091C-A',
#   'YBL095W',
#   'YBL096C',
#   'YBL098W',
#   'YBL100C',
#   'YBL100W-C',
#   'YBL101C',
#   'YBL103C',
#   'YBL104C',
#   'YBL106C',
#   'YBL107C',
#   'YBL108C-A',
#   'YBL111C',
#   'YBL112C',
#   'YBL113C',
#   'YBR001C',
#   'YBR002C',
#   'YBR003W',
#   'YBR005W',
#   'YBR006W',
#   'YBR007C',
#   'YBR008C',
#   'YBR009C',
#   'YBR010W',
#   'YBR011C',
#   'YBR012C',
#   'YBR013C',
#   'YBR014C',
#   'YBR016W',
#   'YBR017C',
#   'YBR018C',
#   'YBR019C',
#   'YBR020W',
#   'YBR022W',
#   'YBR024W',
#   'YBR025C',
#   'YBR027C',
#   'YBR028C',
#   'YBR030W',
#   'YBR031W',
#   'YBR032W',
#   'YBR033W',
#   'YBR034C',
#   'YBR035C',
#   'YBR036C',
#   'YBR037C',
#   'YBR038W',
#   'YBR039W',
#   'YBR040W',
#   'YBR041W',
#   'YBR042C',
#   'YBR043C',
#   'YBR044C',
#   'YBR045C',
#   'YBR046C',
#   'YBR047W',
#   'YBR049C',
#   'YBR050C',
#   'YBR051W',
#   'YBR052C',
#   'YBR053C',
#   'YBR054W',
#   'YBR055C',
#   'YBR056W',
#   'YBR056W-A',
#   'YBR057C',
#   'YBR058C',
#   'YBR058C-A',
#   'YBR059C',
#   'YBR061C',
#   'YBR062C',
#   'YBR063C',
#   'YBR065C',
#   'YBR066C',
#   'YBR067C',
#   'YBR068C',
#   'YBR069C',
#   'YBR071W',
#   'YBR072C-A',
#   'YBR072W',
#   'YBR073W',
#   'YBR074W',
#   'YBR075W',
#   'YBR076W',
#   'YBR077C',
#   'YBR083W',
#   'YBR084C-A',
#   'YBR084W',
#   'YBR085C-A',
#   'YBR085W',
#   'YBR086C',
#   'YBR088C',
#   'YBR089C-A',
#   'YBR090C',
#   'YBR092C',
#   'YBR093C',
#   'YBR096W',
#   'YBR097W',
#   'YBR101C',
#   'YBR102C',
#   'YBR104W',
#   'YBR105C',
#   'YBR108W',
#   'YBR110W',
#   'YBR111C',
#   'YBR111W-A',
#   'YBR112C',
#   'YBR114W',
#   'YBR116C',
#   'YBR117C',
#   'YBR118W',
#   'YBR120C',
#   'YBR121C',
#   'YBR122C',
#   'YBR123C',
#   'YBR125C',
#   'YBR126C',
#   'YBR128C',
#   'YBR129C',
#   'YBR130C',
#   'YBR131W',
#   'YBR132C',
#   'YBR133C',
#   'YBR135W',
#   'YBR136W',
#   'YBR137W',
#   'YBR138C',
#   'YBR141C',
#   'YBR143C',
#   'YBR145W',
#   'YBR146W',
#   'YBR147W',
#   'YBR148W',
#   'YBR149W',
#   'YBR150C',
#   'YBR151W',
#   'YBR152W',
#   'YBR153W',
#   'YBR154C',
#   'YBR157C',
#   'YBR158W',
#   'YBR161W',
#   'YBR162C',
#   'YBR162W-A',
#   'YBR163W',
#   'YBR165W',
#   'YBR166C',
#   'YBR167C',
#   'YBR168W',
#   'YBR169C',
#   'YBR170C',
#   'YBR171W',
#   'YBR172C',
#   'YBR173C',
#   'YBR175W',
#   'YBR176W',
#   'YBR177C',
#   'YBR178W',
#   'YBR179C',
#   'YBR180W',
#   'YBR182C',
#   'YBR182C-A',
#   'YBR183W',
#   'YBR184W',
#   'YBR185C',
#   'YBR186W',
#   'YBR187W',
#   'YBR189W',
#   'YBR191W',
#   'YBR194W',
#   'YBR196C',
#   'YBR196C-A',
#   'YBR196C-B',
#   'YBR197C',
#   'YBR199W',
#   'YBR200W',
#   'YBR200W-A',
#   'YBR201W',
#   'YBR202W',
#   'YBR203W',
#   'YBR204C',
#   'YBR205W',
#   'YBR206W',
#   'YBR207W',
#   'YBR208C',
#   'YBR210W',
#   'YBR212W',
#   'YBR213W',
#   'YBR214W',
#   'YBR216C',
#   'YBR217W',
#   'YBR218C',
#   'YBR219C',
#   'YBR220C',
#   'YBR221C',
#   'YBR221W-A',
#   'YBR222C',
#   'YBR223C',
#   'YBR224W',
#   'YBR225W',
#   'YBR226C',
#   'YBR227C',
#   'YBR230C',
#   'YBR230W-A',
#   'YBR232C',
#   'YBR233W',
#   'YBR234C',
#   'YBR235W',
#   'YBR236C',
#   'YBR239C',
#   'YBR240C',
#   'YBR241C',
#   'YBR242W',
#   'YBR245C',
#   'YBR246W',
#   'YBR249C',
#   'YBR250W',
#   'YBR252W',
#   'YBR253W',
#   'YBR255C-A',
#   'YBR256C',
#   'YBR257W',
#   'YBR258C',
#   'YBR259W',
#   'YBR261C',
#   'YBR262C',
#   'YBR263W',
#   'YBR264C',
#   'YBR265W',
#   'YBR267W',
#   'YBR268W',
#   'YBR269C',
#   'YBR270C',
#   'YBR271W',
#   'YBR272C',
#   'YBR273C',
#   'YBR274W',
#   'YBR275C',
#   'YBR277C',
#   'YBR278W',
#   'YBR279W',
#   'YBR281C',
#   'YBR283C',
#   'YBR284W',
#   'YBR285W',
#   'YBR286W',
#   'YBR287W',
#   'YBR289W',
#   'YBR290W',
#   'YBR291C',
#   'YBR292C',
#   'YBR293W',
#   'YBR294W',
#   'YBR295W',
#   'YBR296C',
#   'YBR296C-A',
#   'YBR297W',
#   'YBR298C',
#   'YBR298C-A',
#   'YBR299W',
#   'YBR300C',
#   'YBR301W',
#   'YCL001W',
#   'YCL001W-A',
#   'YCL001W-B',
#   'YCL002C',
#   'YCL005W',
#   'YCL005W-A',
#   'YCL006C',
#   'YCL008C',
#   'YCL009C',
#   'YCL010C',
#   'YCL011C',
#   'YCL012W',
#   'YCL013W',
#   'YCL014W',
#   'YCL017C',
#   'YCL022C',
#   'YCL023C',
#   'YCL025C',
#   'YCL026C',
#   'YCL026C-A',
#   'YCL026C-B',
#   'YCL027W',
#   'YCL028W',
#   'YCL031C',
#   'YCL032W',
#   'YCL033C',
#   'YCL034W',
#   'YCL035C',
#   'YCL036W',
#   'YCL038C',
#   'YCL039W',
#   'YCL040W',
#   'YCL042W',
#   'YCL043C',
#   'YCL047C',
#   'YCL048W',
#   'YCL049C',
#   'YCL050C',
#   'YCL051W',
#   'YCL052C',
#   'YCL055W',
#   'YCL056C',
#   'YCL057C-A',
#   'YCL057W',
#   'YCL058W-A',
#   'YCL059C',
#   'YCL062W',
#   'YCL063W',
#   'YCL064C',
#   'YCL068C',
#   'YCL069W',
#   'YCL074W',
#   'YCL075W',
#   'YCL076W',
#   'YCR001W',
#   'YCR004C',
#   'YCR005C',
#   'YCR006C',
#   'YCR007C',
#   'YCR008W',
#   'YCR010C',
#   'YCR011C',
#   'YCR014C',
#   'YCR015C',
#   'YCR016W',
#   'YCR019W',
#   'YCR020C',
#   'YCR020C-A',
#   'YCR020W-B',
#   'YCR021C',
#   'YCR022C',
#   'YCR023C',
#   'YCR024C',
#   'YCR024C-A',
#   'YCR024C-B',
#   'YCR025C',
#   'YCR026C',
#   'YCR027C',
#   'YCR028C-A',
#   'YCR030C',
#   'YCR032W',
#   'YCR034W',
#   'YCR035C',
#   'YCR036W',
#   'YCR037C',
#   'YCR039C',
#   'YCR045C',
#   'YCR046C',
#   'YCR048W',
#   'YCR049C',
#   'YCR050C',
#   'YCR051W',
#   'YCR052W',
#   'YCR053W',
#   'YCR054C',
#   'YCR057C',
#   'YCR059C',
#   'YCR060W',
#   'YCR061W',
#   'YCR062W',
#   'YCR063W',
#   'YCR066W',
#   'YCR067C',
#   'YCR068W',
#   'YCR069W',
#   'YCR071C',
#   'YCR072C',
#   'YCR073C',
#   'YCR073W-A',
#   'YCR075C',
#   'YCR075W-A',
#   'YCR076C',
#   'YCR079W',
#   'YCR082W',
#   'YCR083W',
#   'YCR085W',
#   'YCR086W',
#   'YCR087C-A',
#   'YCR087W',
#   'YCR088W',
#   'YCR089W',
#   'YCR090C',
#   'YCR091W',
#   'YCR092C',
#   'YCR093W',
#   'YCR094W',
#   'YCR095C',
#   'YCR095W-A',
#   'YCR097W',
#   'YCR098C',
#   'YCR099C',
#   'YCR100C',
#   'YCR101C',
#   'YCR102C',
#   'YCR102W-A',
#   'YCR104W',
#   'YCR105W',
#   'YCR106W',
#   'YCR107W',
#   'YDL001W',
#   'YDL005C',
#   'YDL006W',
#   'YDL007W',
#   'YDL008W',
#   'YDL010W',
#   'YDL011C',
#   'YDL012C',
#   'YDL013W',
#   'YDL015C',
#   'YDL018C',
#   'YDL019C',
#   'YDL021W',
#   'YDL022W',
#   'YDL023C',
#   'YDL024C',
#   'YDL025C',
#   'YDL026W',
#   'YDL027C',
#   'YDL031W',
#   'YDL033C',
#   'YDL035C',
#   'YDL036C',
#   'YDL037C',
#   'YDL038C',
#   'YDL039C',
#   'YDL040C',
#   'YDL044C',
#   'YDL045C',
#   'YDL048C',
#   'YDL049C',
#   'YDL050C',
#   'YDL051W',
#   'YDL052C',
#   'YDL053C',
#   'YDL054C',
#   'YDL056W',
#   'YDL057W',
#   'YDL059C',
#   'YDL060W',
#   'YDL061C',
#   'YDL063C',
#   'YDL066W',
#   'YDL067C',
#   'YDL069C',
#   'YDL070W',
#   'YDL071C',
#   'YDL073W',
#   'YDL076C',
#   'YDL078C',
#   'YDL079C',
#   'YDL080C',
#   'YDL082W',
#   'YDL084W',
#   'YDL085C-A',
#   'YDL085W',
#   'YDL086W',
#   'YDL089W',
#   'YDL090C',
#   'YDL091C',
#   'YDL093W',
#   'YDL094C',
#   'YDL098C',
#   'YDL099W',
#   'YDL101C',
#   'YDL104C',
#   'YDL106C',
#   'YDL107W',
#   'YDL109C',
#   'YDL110C',
#   'YDL112W',
#   'YDL113C',
#   'YDL114W',
#   'YDL115C',
#   'YDL116W',
#   'YDL117W',
#   'YDL118W',
#   'YDL119C',
#   'YDL121C',
#   'YDL122W',
#   'YDL123W',
#   'YDL124W',
#   'YDL125C',
#   'YDL127W',
#   'YDL128W',
#   'YDL129W',
#   'YDL130W-A',
#   'YDL131W',
#   'YDL133C-A',
#   'YDL133W',
#   'YDL134C',
#   'YDL135C',
#   'YDL137W',
#   'YDL138W',
#   'YDL139C',
#   'YDL142C',
#   'YDL144C',
#   'YDL146W',
#   'YDL148C',
#   'YDL150W',
#   'YDL153C',
#   'YDL154W',
#   'YDL155W',
#   'YDL156W',
#   'YDL157C',
#   'YDL159W-A',
#   'YDL160C-A',
#   'YDL161W',
#   'YDL162C',
#   'YDL164C',
#   'YDL165W',
#   'YDL167C',
#   'YDL168W',
#   'YDL169C',
#   'YDL170W',
#   'YDL171C',
#   'YDL172C',
#   'YDL173W',
#   'YDL174C',
#   'YDL175C',
#   'YDL176W',
#   'YDL177C',
#   'YDL178W',
#   'YDL179W',
#   'YDL180W',
#   'YDL181W',
#   'YDL182W',
#   'YDL183C',
#   'YDL184C',
#   'YDL185W',
#   'YDL186W',
#   'YDL187C',
#   'YDL188C',
#   'YDL189W',
#   'YDL191W',
#   'YDL192W',
#   'YDL193W',
#   'YDL194W',
#   'YDL195W',
#   'YDL197C',
#   'YDL199C',
#   'YDL200C',
#   'YDL201W',
#   'YDL204W',
#   'YDL206W',
#   'YDL207W',
#   'YDL210W',
#   'YDL211C',
#   'YDL213C',
#   'YDL214C',
#   'YDL215C',
#   'YDL216C',
#   'YDL217C',
#   'YDL218W',
#   'YDL219W',
#   'YDL220C',
#   'YDL222C',
#   'YDL223C',
#   'YDL224C',
#   'YDL225W',
#   'YDL226C',
#   'YDL230W',
#   'YDL231C',
#   'YDL233W',
#   'YDL234C',
#   'YDL236W',
#   'YDL237W',
#   'YDL238C',
#   'YDL239C',
#   'YDL240W',
#   'YDL241W',
#   'YDL242W',
#   'YDL243C',
#   'YDL244W',
#   'YDL245C',
#   'YDL246C',
#   'YDL248W',
#   'YDR001C',
#   'YDR003W',
#   'YDR003W-A',
#   'YDR004W',
#   'YDR005C',
#   'YDR006C',
#   'YDR007W',
#   'YDR009W',
#   'YDR010C',
#   'YDR011W',
#   'YDR012W',
#   'YDR015C',
#   'YDR016C',
#   'YDR018C',
#   'YDR019C',
#   'YDR021W',
#   'YDR022C',
#   'YDR024W',
#   'YDR025W',
#   'YDR026C',
#   'YDR029W',
#   'YDR030C',
#   'YDR031W',
#   'YDR032C',
#   'YDR033W',
#   'YDR034C-A',
#   'YDR034W-B',
#   'YDR035W',
#   'YDR036C',
#   'YDR037W',
#   'YDR038C',
#   'YDR040C',
#   'YDR042C',
#   'YDR043C',
#   'YDR044W',
#   'YDR045C',
#   'YDR046C',
#   'YDR047W',
#   'YDR049W',
#   'YDR051C',
#   'YDR054C',
#   'YDR055W',
#   'YDR056C',
#   'YDR057W',
#   'YDR058C',
#   'YDR059C',
#   'YDR061W',
#   'YDR063W',
#   'YDR065W',
#   'YDR066C',
#   'YDR067C',
#   'YDR068W',
#   'YDR069C',
#   'YDR070C',
#   'YDR071C',
#   'YDR072C',
#   'YDR073W',
#   'YDR074W',
#   'YDR075W',
#   'YDR077W',
#   'YDR078C',
#   'YDR079W',
#   'YDR081C',
#   'YDR082W',
#   'YDR083W',
#   'YDR084C',
#   'YDR085C',
#   'YDR087C',
#   'YDR088C',
#   'YDR089W',
#   'YDR090C',
#   'YDR091C',
#   'YDR093W',
#   'YDR094W',
#   'YDR095C',
#   'YDR096W',
#   'YDR097C',
#   'YDR098C',
#   'YDR099W',
#   'YDR100W',
#   'YDR101C',
#   'YDR102C',
#   'YDR104C',
#   'YDR105C',
#   'YDR106W',
#   'YDR107C',
#   'YDR109C',
#   'YDR110W',
#   'YDR111C',
#   'YDR112W',
#   'YDR116C',
#   'YDR117C',
#   'YDR118W',
#   'YDR119W',
#   'YDR120C',
#   'YDR121W',
#   'YDR123C',
#   'YDR124W',
#   'YDR125C',
#   'YDR127W',
#   'YDR128W',
#   'YDR129C',
#   'YDR130C',
#   'YDR131C',
#   'YDR132C',
#   'YDR133C',
#   'YDR134C',
#   'YDR135C',
#   'YDR137W',
#   'YDR139C',
#   'YDR141C',
#   'YDR142C',
#   'YDR143C',
#   'YDR144C',
#   'YDR146C',
#   'YDR147W',
#   'YDR148C',
#   'YDR149C',
#   'YDR151C',
#   'YDR152W',
#   'YDR153C',
#   'YDR154C',
#   'YDR155C',
#   'YDR157W',
#   'YDR158W',
#   'YDR159W',
#   'YDR161W',
#   'YDR162C',
#   'YDR163W',
#   'YDR164C',
#   'YDR165W',
#   'YDR166C',
#   'YDR167W',
#   'YDR168W',
#   'YDR169C',
#   'YDR169C-A',
#   'YDR170C',
#   'YDR171W',
#   'YDR172W',
#   'YDR174W',
#   'YDR176W',
#   'YDR177W',
#   'YDR178W',
#   'YDR179C',
#   'YDR181C',
#   'YDR182W',
#   'YDR182W-A',
#   'YDR183W',
#   'YDR184C',
#   'YDR185C',
#   'YDR186C',
#   'YDR190C',
#   'YDR191W',
#   'YDR192C',
#   'YDR193W',
#   'YDR194C',
#   'YDR194W-A',
#   'YDR195W',
#   'YDR197W',
#   'YDR198C',
#   'YDR199W',
#   'YDR200C',
#   'YDR202C',
#   'YDR204W',
#   'YDR205W',
#   'YDR206W',
#   'YDR207C',
#   'YDR209C',
#   'YDR210W',
#   'YDR211W',
#   'YDR213W',
#   'YDR214W',
#   'YDR215C',
#   'YDR216W',
#   'YDR218C',
#   'YDR219C',
#   'YDR220C',
#   'YDR221W',
#   'YDR222W',
#   'YDR223W',
#   'YDR225W',
#   'YDR226W',
#   'YDR229W',
#   'YDR231C',
#   'YDR232W',
#   'YDR233C',
#   'YDR235W',
#   'YDR239C',
#   'YDR240C',
#   'YDR242W',
#   'YDR245W',
#   'YDR247W',
#   'YDR248C',
#   'YDR249C',
#   'YDR250C',
#   'YDR251W',
#   'YDR252W',
#   'YDR253C',
#   'YDR255C',
#   'YDR256C',
#   'YDR257C',
#   'YDR258C',
#   'YDR259C',
#   'YDR261C',
#   'YDR262W',
#   'YDR263C',
#   'YDR264C',
#   'YDR266C',
#   'YDR267C',
#   'YDR268W',
#   'YDR269C',
#   'YDR270W',
#   'YDR271C',
#   'YDR272W',
#   'YDR273W',
#   'YDR274C',
#   'YDR275W',
#   'YDR277C',
#   'YDR278C',
#   'YDR279W',
#   'YDR280W',
#   'YDR281C',
#   'YDR282C',
#   'YDR283C',
#   'YDR284C',
#   'YDR285W',
#   'YDR286C',
#   'YDR287W',
#   'YDR291W',
#   'YDR292C',
#   'YDR293C',
#   'YDR294C',
#   'YDR295C',
#   'YDR296W',
#   'YDR297W',
#   'YDR298C',
#   'YDR299W',
#   'YDR301W',
#   'YDR303C',
#   'YDR304C',
#   'YDR306C',
#   'YDR307W',
#   'YDR308C',
#   'YDR309C',
#   'YDR310C',
#   'YDR311W',
#   'YDR312W',
#   'YDR313C',
#   'YDR314C',
#   'YDR315C',
#   'YDR317W',
#   'YDR319C',
#   'YDR320C',
#   'YDR321W',
#   'YDR322C-A',
#   'YDR322W',
#   'YDR323C',
#   'YDR324C',
#   'YDR326C',
#   'YDR330W',
#   'YDR332W',
#   'YDR333C',
#   'YDR335W',
#   'YDR336W',
#   'YDR337W',
#   ...]}

# %% [markdown]
# # Map GI modules to PPI modules

# %%
### Find Overlap between individual GI modules and PPI modules
GI_PPI_module_Overlap_matrix = pd.DataFrame(columns = list(PPI_module_dict.keys()), index = list(GI_module_dict.keys()))

# For every cell in matrix, calculate jaccard index between GI module (index) and PPI module (column)
for i in list(GI_module_dict.keys()):
    for j in list(PPI_module_dict.keys()):
        GI_PPI_module_Overlap_matrix.loc[i,j] = Jaccard(PPI_module_dict[j], GI_module_dict[i])

# Convert all values to numeric
for col_name in GI_PPI_module_Overlap_matrix.columns:
    GI_PPI_module_Overlap_matrix[col_name] = pd.to_numeric(GI_PPI_module_Overlap_matrix[col_name])
        
GI_PPI_module_Overlap_matrix
# Out:
#       CPX-1015  CPX-1016  CPX-1018  CPX-1021  CPX-1022  CPX-1026  CPX-1028  \
# 1          0.0       0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2          0.0       0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 3          0.0       0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 4          0.0       0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 5          0.0       0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 109        0.0       0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 110        0.0       0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 111        0.0       0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 112        0.0       0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# None       0.0       0.0  0.000207  0.000414  0.000414  0.000414  0.000414
#
#       CPX-1036  CPX-1037  CPX-1039  ...   CPX-950  CPX-956  CPX-961  CPX-962  \
# 1     0.000000  0.000000  0.000000  ...  0.000000      0.0      0.0      0.0
# 2     0.000000  0.000000  0.000000  ...  0.000000      0.0      0.0      0.0
# 3     0.000000  0.000000  0.000000  ...  0.000000      0.0      0.0      0.0
# 4     0.000000  0.000000  0.000000  ...  0.000000      0.0      0.0      0.0
# 5     0.000000  0.000000  0.000000  ...  0.000000      0.0      0.0      0.0
# ...        ...       ...       ...  ...       ...      ...      ...      ...
# 109   0.000000  0.000000  0.000000  ...  0.000000      0.0      0.0      0.0
# 110   0.000000  0.000000  0.000000  ...  0.000000      0.0      0.0      0.0
# 111   0.000000  0.000000  0.000000  ...  0.000000      0.0      0.0      0.0
# 112   0.000000  0.000000  0.000000  ...  0.000000      0.0      0.0      0.0
# None  0.000414  0.000414  0.001449  ...  0.000414      0.0      0.0      0.0
#
#       CPX-963   CPX-964  CPX-977   CPX-995  CPX-999      None
# 1         0.0  0.000000      0.0  0.000000      0.0  0.000456
# 2         0.0  0.000000      0.0  0.000000      0.0  0.000453
# 3         0.0  0.000000      0.0  0.000000      0.0  0.000000
# 4         0.0  0.000000      0.0  0.000000      0.0  0.000000
# 5         0.0  0.000000      0.0  0.000000      0.0  0.000000
# ...       ...       ...      ...       ...      ...       ...
# 109       0.0  0.000000      0.0  0.000000      0.0  0.000000
# 110       0.0  0.000000      0.0  0.000000      0.0  0.000000
# 111       0.0  0.000000      0.0  0.000000      0.0  0.000000
# 112       0.0  0.000000      0.0  0.000000      0.0  0.000000
# None      0.0  0.000207      0.0  0.000828      0.0  0.344240
#
# [112 rows x 584 columns]

# %%
### Make heatmap of GI to PPI module overlap matrix

#fig, ax = plt.subplots(figsize=(48,24))         # Sample figsize in inches
#sns.heatmap(GI_PPI_module_Overlap_matrix, annot=False, ax = ax, linewidths=.5, vmin = 0, vmax = 1, cmap = "viridis")
#sns.heatmap(GI_PPI_module_Overlap_matrix, annot=False, ax = ax, linewidths=0, vmin = 0, vmax = 1, cmap = "viridis")
#plt.savefig("../graphs/GIvsPPI_module_overlap_matrix.eps", format = "eps")
#plt.show()
#plt.close()

# %%
## Alternative visualization
# Note: Remove rows or columns with no overlap.

# Make a matrix that will only be used for visualization
#GI_PPI_module_Overlap_matrix_ForViz = GI_PPI_module_Overlap_matrix.copy()

#GI_PPI_module_Overlap_matrix_ForViz = GI_PPI_module_Overlap_matrix_ForViz.drop('None', axis = 0)
#GI_PPI_module_Overlap_matrix_ForViz = GI_PPI_module_Overlap_matrix_ForViz.drop('None', axis = 1)

#GI_PPI_module_Overlap_matrix_ForViz = GI_PPI_module_Overlap_matrix_ForViz[GI_PPI_module_Overlap_matrix_ForViz.sum(axis=1, numeric_only=True) != 0]
#GI_PPI_module_Overlap_matrix_ForViz_T = GI_PPI_module_Overlap_matrix_ForViz.T

#GI_PPI_module_Overlap_matrix_ForViz_T = GI_PPI_module_Overlap_matrix_ForViz_T[GI_PPI_module_Overlap_matrix_ForViz_T.sum(axis=1, numeric_only=True) != 0]

#GI_PPI_module_Overlap_matrix_ForViz = GI_PPI_module_Overlap_matrix_ForViz_T.T

#GI_PPI_module_Overlap_matrix_ForViz

# %%
#fig, ax = plt.subplots(figsize=(34,20))         # Sample figsize in inches
#sns.heatmap(GI_PPI_module_Overlap_matrix, annot=False, ax = ax, linewidths=.5, vmin = 0, vmax = 1, cmap = "viridis")
#sns.heatmap(GI_PPI_module_Overlap_matrix_ForViz, annot=False, ax = ax, linewidths=0, vmin = 0, vmax = 1, cmap = "viridis")
#plt.savefig("../graphs/GIvsPPI_module_overlap_matrix.eps", format = "eps")
#plt.show()
#plt.close()

# %%
### Find best PPI complex for each GI cluster

# Get list of complexes, in the same order as columns of matrix
PPI_modules_matrix_list = GI_PPI_module_Overlap_matrix.columns.tolist()

# For every GI cluster, get the column index for which overlap is maximal
GI_PPI_optimal_overlap_DF = pd.DataFrame(GI_PPI_module_Overlap_matrix.apply(lambda x: x.tolist().index(max(x)), axis = 1), columns = ["CPX_index"])

# Get complex ID from index
GI_PPI_optimal_overlap_DF['CPX_ID'] = [PPI_modules_matrix_list[index] for index in GI_PPI_optimal_overlap_DF['CPX_index']]

# Make column for Jaccard index
GI_PPI_optimal_overlap_DF['Jaccard_index'] = GI_PPI_optimal_overlap_DF.apply(lambda x: GI_PPI_module_Overlap_matrix.loc[x.name, x['CPX_ID']], axis = 1)

# Make list of common ORF between GI and PPI modules for each pair
GI_PPI_optimal_overlap_DF['Common_Module_ORFs'] = [set(PPI_module_dict[CPX_ID]).intersection(set(GI_module_dict[cluster])) for CPX_ID, cluster in zip(GI_PPI_optimal_overlap_DF['CPX_ID'].tolist(), list(GI_PPI_optimal_overlap_DF.index))]

GI_PPI_optimal_overlap_DF
# Out:
#       CPX_index    CPX_ID  Jaccard_index  \
# 1           153  CPX-1625       0.142857
# 2           480   CPX-535       0.307692
# 3           170  CPX-1642       0.437500
# 4           427  CPX-3254       0.200000
# 5           524  CPX-6127       1.000000
# ...         ...       ...            ...
# 109          82  CPX-1315       1.000000
# 110         376  CPX-2948       1.000000
# 111         470   CPX-465       1.000000
# 112         569   CPX-867       1.000000
# None        583      None       0.344240
#
#                                      Common_Module_ORFs
# 1                                             {YDL077C}
# 2                  {YJL024C, YGR261C, YBR288C, YPL195W}
# 3     {YMR005W, YGL112C, YML015C, YML098W, YBR198C, ...
# 4                                             {YBR280C}
# 5                                    {YNR017W, YPL063W}
# ...                                                 ...
# 109                         {YGR072W, YHR077C, YMR080C}
# 110                                  {YMR264W, YMR022W}
# 111                                  {YKR084C, YNL001W}
# 112                                  {YDL017W, YDR052C}
# None  {YPR049C, YFR048W, YGR145W, YMR243C, YGR068C, ...
#
# [112 rows x 4 columns]

# %% [markdown]
# # Add PPI and GI Module ORFs

# %%
GI_PPI_optimal_overlap_DF['Cluster_ID'] = GI_PPI_optimal_overlap_DF.index
GI_PPI_optimal_overlap_DF = GI_PPI_optimal_overlap_DF.reset_index(drop = True)

# Add list of ORFs for GI modules
GI_PPI_optimal_overlap_DF['GI_Module_ORFs'] = [GI_module_dict[key_] for key_ in GI_PPI_optimal_overlap_DF['Cluster_ID']]

# Add list of ORFs for PPI modules
GI_PPI_optimal_overlap_DF['PPI_Module_ORFs'] = [PPI_module_dict[key_] for key_ in GI_PPI_optimal_overlap_DF['CPX_ID']]

# %%
## Export
GI_PPI_optimal_overlap_DF.to_csv('../results/GI_PPI_optimal_module_overlap.csv')

# %%
GI_PPI_optimal_overlap_DF = GI_PPI_optimal_overlap_DF[GI_PPI_optimal_overlap_DF['Common_Module_ORFs'].apply(lambda x: len(x) > 0)]
GI_PPI_optimal_overlap_DF = GI_PPI_optimal_overlap_DF[GI_PPI_optimal_overlap_DF['CPX_ID'] != 'None']
GI_PPI_optimal_overlap_DF
# Out:
#      CPX_index    CPX_ID  Jaccard_index  \
# 0          153  CPX-1625       0.142857
# 1          480   CPX-535       0.307692
# 2          170  CPX-1642       0.437500
# 3          427  CPX-3254       0.200000
# 4          524  CPX-6127       1.000000
# ..         ...       ...            ...
# 106        240  CPX-1717       0.333333
# 107         82  CPX-1315       1.000000
# 108        376  CPX-2948       1.000000
# 109        470   CPX-465       1.000000
# 110        569   CPX-867       1.000000
#
#                                     Common_Module_ORFs Cluster_ID  \
# 0                                            {YDL077C}          1
# 1                 {YJL024C, YGR261C, YBR288C, YPL195W}          2
# 2    {YMR005W, YGL112C, YML015C, YML098W, YBR198C, ...          3
# 3                                            {YBR280C}          4
# 4                                   {YNR017W, YPL063W}          5
# ..                                                 ...        ...
# 106                                          {YNL006W}        108
# 107                        {YGR072W, YHR077C, YMR080C}        109
# 108                                 {YMR264W, YMR022W}        110
# 109                                 {YKR084C, YNL001W}        111
# 110                                 {YDL017W, YDR052C}        112
#
#                                         GI_Module_ORFs  \
# 0                                   [YDL077C, YML001W]
# 1    [YBR288C, YGR261C, YHR012W, YJL024C, YJL053W, ...
# 2    [YBR198C, YDR145W, YGL112C, YML015C, YML098W, ...
# 3                                   [YBR244W, YBR280C]
# 4                                   [YNR017W, YPL063W]
# ..                                                 ...
# 106                                          [YNL006W]
# 107                        [YGR072W, YHR077C, YMR080C]
# 108                                 [YMR022W, YMR264W]
# 109                                 [YKR084C, YNL001W]
# 110                                 [YDL017W, YDR052C]
#
#                                        PPI_Module_ORFs
# 0    [YDR080W, YDL077C, YLR396C, YMR231W, YLR148W, ...
# 1                 [YGR261C, YJL024C, YBR288C, YPL195W]
# 2    [YPL129W, YER148W, YPL011C, YMR227C, YML015C, ...
# 3                 [YDR054C, YDR328C, YDL132W, YBR280C]
# 4                                   [YPL063W, YNR017W]
# ..                                                 ...
# 106                        [YNL006W, YOL078W, YKL203C]
# 107                        [YGR072W, YMR080C, YHR077C]
# 108                                 [YMR022W, YMR264W]
# 109                                 [YNL001W, YKR084C]
# 110                                 [YDL017W, YDR052C]
#
# [88 rows x 7 columns]

# %%
## Export
GI_PPI_optimal_overlap_DF.to_csv('../results/GI_PPI_optimal_module_overlap_clean.csv')

# %% [markdown]
# # Randomization to get p-values for individual module pairings

# %%
Cluster_ID_iter_ls = []
Jaccard_index_iter_ls = []
pool_of_PPI_Module_ORFs_stable = [x for list_ in PPI_module_dict.values() for x in list_]

# %%
for i in tqdm(range(0,1000)):
    
    pool_of_PPI_Module_ORFs_random = pool_of_PPI_Module_ORFs_stable.copy()
    
    random.shuffle(pool_of_PPI_Module_ORFs_random)
    
    ## Map GI modules to PPI modules 
    ### Find Overlap between individual GI modules and PPI modules
    GI_PPI_module_Overlap_matrix_iter = pd.DataFrame(columns = list(PPI_module_dict.keys()), index = list(GI_module_dict.keys()))
    
    
    k = 0
    # For every cell in matrix, calculate jaccard index between GI module (index) and PPI module (column)
    for j in list(PPI_module_dict.keys()):
        #print(j)
        size = len(PPI_module_dict[j])
        random_PPI_module = pool_of_PPI_Module_ORFs_random[k:k+size]
        k = k+size
        for i in list(GI_module_dict.keys()):
            #print(i)
            GI_PPI_module_Overlap_matrix_iter.loc[i,j] = Jaccard(random_PPI_module, GI_module_dict[i])
            #print(k, size, random_PPI_module, Jaccard(random_PPI_module, GI_module_dict[i]))
        #time.sleep(60)
    
    # Convert all values to numeric
    for col_name in GI_PPI_module_Overlap_matrix_iter.columns:
        GI_PPI_module_Overlap_matrix_iter[col_name] = pd.to_numeric(GI_PPI_module_Overlap_matrix_iter[col_name])
        
    ### Find best PPI complex for each GI cluster
    
    # Get list of complexes, in the same order as columns of matrix
    PPI_modules_matrix_list_iter = GI_PPI_module_Overlap_matrix_iter.columns.tolist()
    
    # For every GI cluster, get the column index for which overlap is maximal
    GI_PPI_optimal_overlap_DF_iter = pd.DataFrame(GI_PPI_module_Overlap_matrix_iter.apply(lambda x: x.tolist().index(max(x)), axis = 1), columns = ["CPX_index"])
    
    # Get complex ID from index
    GI_PPI_optimal_overlap_DF_iter['CPX_ID'] = [PPI_modules_matrix_list_iter[index] for index in GI_PPI_optimal_overlap_DF_iter['CPX_index']]
    
    # Make column for Jaccard index
    GI_PPI_optimal_overlap_DF_iter['Jaccard_index'] = GI_PPI_optimal_overlap_DF_iter.apply(lambda x: GI_PPI_module_Overlap_matrix_iter.loc[x.name, x['CPX_ID']], axis = 1)
    
    # Make list of common ORF between GI and PPI modules for each pair
    #GI_PPI_optimal_overlap_DF_iter['Common_Module_ORFs'] = [set(PPI_module_dict[CPX_ID]).intersection(set(GI_module_dict[cluster])) for CPX_ID, cluster in zip(GI_PPI_optimal_overlap_DF_iter['CPX_ID'].tolist(), list(GI_PPI_optimal_overlap_DF_iter.index))]
    
    Cluster_ID_iter_ls.extend(GI_PPI_optimal_overlap_DF_iter.index.copy().tolist())
    Jaccard_index_iter_ls.extend(GI_PPI_optimal_overlap_DF_iter['Jaccard_index'].copy().tolist())
# Out:
# 100%|███████████████████████████████████████████████████████████| 1000/1000 [1:19:10<00:00,  4.75s/it]

# %%
randomized_module_overlap_DF = pd.DataFrame({"Cluster_ID":Cluster_ID_iter_ls, "Jaccard_index":Jaccard_index_iter_ls})
randomized_module_overlap_DF
# Out:
#        Cluster_ID  Jaccard_index
# 0               1       0.000977
# 1               2       0.066667
# 2               3       0.111111
# 3               4       0.333333
# 4               5       0.333333
# ...           ...            ...
# 111995        109       0.090909
# 111996        110       0.000989
# 111997        111       0.083333
# 111998        112       0.000989
# 111999       None       0.266026
#
# [112000 rows x 2 columns]

# %%
randomized_module_overlap_DF.to_csv("../results/GI_PPI_randomized_ModuleOverlap.csv")

# %% [markdown]
# ### Calculate a z-score for every overlapping module

# %%
# Make a dictionary holding random overlaps for each GI Cluster
random_overlap_dict = dict.fromkeys(list(GI_module_dict.keys()))

for key in list(random_overlap_dict.keys()):
    random_overlap_dict[key] = randomized_module_overlap_DF['Jaccard_index'][randomized_module_overlap_DF['Cluster_ID'] == key].tolist()

# %%
zscores_ls = []
for i in GI_PPI_optimal_overlap_DF.index:
    zscores_ls.append((GI_PPI_optimal_overlap_DF['Jaccard_index'][i] - np.mean(random_overlap_dict[i]))/statistics.stdev(random_overlap_dict[i]))
# Out:
# /tmp/ipykernel_101771/838944227.py:3: RuntimeWarning: invalid value encountered in scalar divide
#   zscores_ls.append((GI_PPI_optimal_overlap_DF['Jaccard_index'][i] - np.mean(random_overlap_dict[i]))/statistics.stdev(random_overlap_dict[i]))

# %%
GI_PPI_optimal_overlap_DF['zscore'] = zscores_ls
GI_PPI_optimal_overlap_DF['pvalue'] = GI_PPI_optimal_overlap_DF['zscore'].apply(lambda x: scipy.stats.norm.sf(abs(x))) 

significant_ls = 

GI_PPI_optimal_overlap_DF['Significant'] = GI_PPI_optimal_overlap_DF['pvalue'].apply(lambda x: True if x < 0.05 else False)
GI_PPI_optimal_overlap_DF
# Out:
#       CPX_index    CPX_ID  Jaccard_index  \
# 1           153  CPX-1625       0.142857
# 2           480   CPX-535       0.307692
# 3           170  CPX-1642       0.437500
# 4           427  CPX-3254       0.200000
# 5           524  CPX-6127       1.000000
# ...         ...       ...            ...
# 109          82  CPX-1315       1.000000
# 110         376  CPX-2948       1.000000
# 111         470   CPX-465       1.000000
# 112         569   CPX-867       1.000000
# None        583      None       0.357727
#
#                                      Common_Module_ORFs     zscore  \
# 1                                             {YDL077C}  -0.034911
# 2                  {YBR288C, YPL195W, YGR261C, YJL024C}  24.814872
# 3     {YML015C, YMR236W, YBR198C, YGL112C, YDR145W, ...  21.043517
# 4                                             {YBR280C}   0.841149
# 5                                    {YNR017W, YPL063W}   6.312815
# ...                                                 ...        ...
# 109                         {YGR072W, YMR080C, YHR077C}   9.279429
# 110                                  {YMR022W, YMR264W}   6.190406
# 111                                  {YKR084C, YNL001W}   6.472446
# 112                                  {YDR052C, YDL017W}   6.546603
# None  {YPL109C, YGR270W, YGR044C, YML020W, YLR108C, ...  24.871830
#
#              pvalue  Significant
# 1      4.860752e-01        False
# 2     3.097648e-136         True
# 3      1.310953e-98         True
# 4      2.001321e-01        False
# 5      1.370022e-10         True
# ...             ...          ...
# 109    8.519473e-21         True
# 110    3.000477e-10         True
# 111    4.821459e-11         True
# 112    2.943022e-11         True
# None  7.507623e-137         True
#
# [112 rows x 7 columns]

# %%
#GI_PPI_optimal_overlap_DF.to_csv('../results/GI_PPI_optimal_module_overlap.csv')
# Out:
# [{'YDL077C'}, {'YBR288C', 'YPL195W', 'YGR261C', 'YJL024C'}, {'YML015C', 'YMR236W', 'YBR198C', 'YGL112C', 'YDR145W', 'YML098W', 'YMR005W'}, {'YBR280C'}, {'YNR017W', 'YPL063W'}, {'YLR298C', 'YDL087C', 'YGR013W'}, {'YKR027W'}, set(), {'YDL190C', 'YDL126C'}, {'YGR271W'}, {'YJR140C', 'YBR215W'}, {'YPR189W', 'YLR398C'}, {'YFR028C'}, {'YNR043W'}, {'YDL208W'}, {'YFR032C-A'}, {'YOR326W', 'YBR109C'}, {'YMR049C', 'YGR103W'}, {'YKL203C'}, {'YBR103W', 'YCR033W', 'YGL194C', 'YKR029C'}, {'YDL105W'}, {'YGL087C'}, {'YPR070W', 'YGL151W'}, {'YLR430W'}, {'YJL124C', 'YCR077C'}, {'YPL047W', 'YMR223W'}, {'YJL047C'}, {'YBR255W'}, {'YPR055W', 'YLR166C', 'YGL233W'}, {'YMR299C', 'YKR054C', 'YDR424C'}, {'YBR195C', 'YML102W', 'YPR018W'}, {'YBR079C', 'YOR361C'}, {'YLR378C'}, set(), {'YMR135C', 'YGL227W'}, {'YHL025W'}, {'YMR153W', 'YAR002W', 'YML103C', 'YLR335W', 'YJL039C', 'YJR042W', 'YKR082W', 'YLR018C', 'YIL115C'}, {'YDL074C'}, {'YPR179C', 'YNL021W'}, {'YMR186W'}, {'YKR058W', 'YJL155C'}, {'YER162C'}, {'YKL216W'}, {'YJL050W'}, {'YLR314C', 'YCR002C', 'YHR107C', 'YJR076C'}, {'YPL269W'}, {'YGR113W', 'YKL052C'}, {'YGL180W'}, {'YPL181W'}, {'YJL148W', 'YDR156W', 'YOR341W'}, {'YER157W', 'YGL005C', 'YNL041C', 'YNL051W', 'YGR120C', 'YML071C'}, {'YGL022W', 'YGL226C-A', 'YJL002C', 'YML019W', 'YOR103C'}, {'YKL112W'}, {'YNR056C', 'YPR003C'}, {'YPR185W'}, {'YGL028C'}, {'YDR122W', 'YLR096W'}, {'YAL011W', 'YDR334W', 'YBR231C', 'YLR085C', 'YDR485C', 'YML041C'}, {'YDR013W', 'YDR489W', 'YLR274W', 'YBL023C', 'YJL072C', 'YLR103C'}, {'YPL228W', 'YGL130W'}, {'YDR288W', 'YLR007W'}, {'YLR177W', 'YDR020C'}, {'YDL043C', 'YGL174W', 'YLR117C', 'YJL203W', 'YMR213W', 'YJR050W', 'YKL173W', 'YDR482C', 'YBR188C', 'YML049C', 'YIR005W', 'YGR129W', 'YDL030W', 'YDR416W'}, {'YHL002W'}, {'YKL171W'}, {'YPR103W', 'YOR157C', 'YDL097C', 'YBL041W', 'YHR027C', 'YOR259C', 'YFR050C', 'YGL048C', 'YFR004W', 'YDL147W', 'YPR108W', 'YGR135W', 'YOR362C', 'YER094C', 'YGL011C', 'YOL038W', 'YKL145W'}, {'YJL005W'}, {'YHR167W'}, {'YGR179C', 'YAL034W-A', 'YDR254W', 'YPR046W', 'YBR107C', 'YLR381W', 'YDR318W', 'YJR135C', 'YBR211C', 'YPL018W'}, set(), {'YLR110C', 'YGL203C', 'YDR349C'}, {'YBR082C'}, {'YHR166C', 'YOR249C', 'YDR260C', 'YLR102C', 'YBL084C'}, {'YER149C', 'YLL021W'}, set(), {'YBR095C', 'YOL004W', 'YMR263W', 'YIL084C', 'YNL097C'}, {'YHR196W', 'YDR398W'}, {'YBL026W', 'YNL147W', 'YDR378C'}, {'YPR016C', 'YLR397C', 'YNR053C', 'YKR092C'}, {'YDL140C'}, {'YJR065C', 'YIL062C', 'YDL029W', 'YNR035C'}, {'YCL045C'}, {'YPR024W', 'YMR115W', 'YCL044C'}, {'YMR061W', 'YGL044C', 'YDR228C'}, set(), {'YHR083W'}, {'YNR051C', 'YER151C'}, {'YLR440C', 'YGL145W'}, {'YLR066W'}, {'YPR075C'}, {'YAL001C', 'YDR362C'}, {'YLL041C', 'YKL148C'}, {'YDL229W', 'YMR070W'}, {'YBL097W', 'YDR325W'}, {'YGR140W', 'YMR168C'}, {'YLR395C'}, {'YGL019W', 'YOR039W'}, {'YBR160W'}, {'YIL153W'}, {'YDR062W', 'YMR296C'}, {'YOR204W'}, {'YMR052W', 'YNL127W', 'YMR029C', 'YFR008W', 'YLR238W'}, {'YPL101W', 'YMR312W', 'YGR200C', 'YPL086C', 'YLR384C'}, set(), {'YML034W'}, {'YFL039C'}, {'YNL006W'}, {'YGR072W', 'YMR080C', 'YHR077C'}, {'YMR022W', 'YMR264W'}, {'YKR084C', 'YNL001W'}, {'YDR052C', 'YDL017W'}, {'YPL109C', 'YGR270W', 'YGR044C', 'YML020W', 'YLR108C', 'YIL009W', 'YDR330W', 'YDL121C', 'YHR136C', 'YMR031C', 'YER080W', 'YER132C', 'YDR067C', 'YDR483W', 'YLR351C', 'YPR042C', 'YOL066C', 'YGL108C', 'YOR356W', 'YHL038C', 'YLR189C', 'YDL237W', 'YGR125W', 'YER178W', 'YMR207C', 'YNL301C', 'YHR114W', 'YGR124W', 'YGR026W', 'YDR465C', 'YDR011W', 'YML026C', 'YGR126W', 'YLR388W', 'YKL159C', 'YHR003C', 'YNR001C', 'YCL025C', 'YJL112W', 'YLR241W', 'YNL099C', 'YIL096C', 'YNL116W', 'YDR129C', 'YDL019C', 'YKR014C', 'YLR414C', 'YLR136C', 'YJR119C', 'YDL044C', 'YGR061C', 'YGR117C', 'YDR152W', 'YKL198C', 'YNL077W', 'YJR080C', 'YLR422W', 'YER124C', 'YGR269W', 'YOR360C', 'YMR255W', 'YMR098C', 'YMR015C', 'YGR295C', 'YER003C', 'YGR004W', 'YLR168C', 'YPL006W', 'YCL055W', 'YEL040W', 'YGL253W', 'YJL196C', 'YBR138C', 'YMR313C', 'YHR038W', 'YLR371W', 'YOR219C', 'YGR080W', 'YOR089C', 'YDL078C',  ...

# %%
GI_PPI_optimal_overlap_sig_DF = GI_PPI_optimal_overlap_DF[GI_PPI_optimal_overlap_DF['Significant']==True].copy()
GI_PPI_optimal_overlap_sig_DF
# Out:
#       CPX_index    CPX_ID  Jaccard_index  \
# 2           480   CPX-535       0.307692
# 3           170  CPX-1642       0.437500
# 5           524  CPX-6127       1.000000
# 9            89  CPX-1323       0.500000
# 11           59   CPX-124       0.250000
# 12           10  CPX-1040       0.500000
# 17          341  CPX-2225       0.285714
# 18          296  CPX-1862       0.125000
# 20           94  CPX-1342       0.363636
# 22          351  CPX-2541       0.500000
# 29          315  CPX-1890       0.250000
# 30           42  CPX-1178       0.214286
# 31          505   CPX-568       1.000000
# 32          272  CPX-1831       0.400000
# 33          274  CPX-1833       0.500000
# 37          566   CPX-824       0.225000
# 38          368  CPX-2911       0.333333
# 39          309  CPX-1884       0.333333
# 45          201  CPX-1675       0.800000
# 51          281  CPX-1840       0.093750
# 52          166  CPX-1638       0.081967
# 58          336  CPX-2122       0.285714
# 59          377   CPX-297       0.157895
# 60          513   CPX-580       0.142857
# 61           99  CPX-1364       0.100000
# 63          177  CPX-1651       0.245614
# 64          150  CPX-1622       0.333333
# 66          342  CPX-2262       0.435897
# 69           36  CPX-1156       0.196078
# 71          583      None       0.001297
# 73          545   CPX-756       0.238095
# 74          407  CPX-3188       0.071429
# 76          287  CPX-1852       0.500000
# 78          469    CPX-46       0.375000
# 79          583      None       0.001730
# 81          521   CPX-607       0.190476
# 83          181  CPX-1655       0.115385
# 84          319  CPX-1895       0.500000
# 87          116  CPX-1412       1.000000
# 88          259  CPX-1786       0.666667
# 90           77  CPX-1302       0.500000
# 92          503   CPX-565       0.666667
# 94          303  CPX-1869       0.400000
# 95          321  CPX-1898       0.500000
# 97          550   CPX-769       0.666667
# 98          440   CPX-339       0.500000
# 100         399  CPX-3158       0.500000
# 102          53  CPX-1197       0.625000
# 103         560   CPX-779       0.357143
# 109          82  CPX-1315       1.000000
# 110         376  CPX-2948       1.000000
# 111         470   CPX-465       1.000000
# 112         569   CPX-867       1.000000
# None        583      None       0.357727
#
#                                      Common_Module_ORFs     zscore  \
# 2                  {YBR288C, YPL195W, YGR261C, YJL024C}  24.814872
# 3     {YML015C, YMR236W, YBR198C, YGL112C, YDR145W, ...  21.043517
# 5                                    {YNR017W, YPL063W}   6.312815
# 9                                    {YDL190C, YDL126C}   3.980045
# 11                                   {YJR140C, YBR215W}   4.332681
# 12                                   {YPR189W, YLR398C}   3.851019
# 17                                   {YOR326W, YBR109C}   6.690953
# 18                                   {YMR049C, YGR103W}   6.856812
# 20                 {YBR103W, YCR033W, YGL194C, YKR029C}  13.859889
# 22                                            {YGL087C}   3.716913
# 29                          {YPR055W, YLR166C, YGL233W}   4.654586
# 30                          {YMR299C, YKR054C, YDR424C}  21.605835
# 31                          {YBR195C, YML102W, YPR018W}   8.914619
# 32                                   {YBR079C, YOR361C}   1.899722
# 33                                            {YLR378C}   2.669667
# 37    {YMR153W, YAR002W, YML103C, YLR335W, YJL039C, ...  24.770189
# 38                                            {YDL074C}   1.920998
# 39                                   {YPR179C, YNL021W}   4.288247
# 45                 {YLR314C, YCR002C, YHR107C, YJR076C}  13.792296
# 51    {YER157W, YGL005C, YNL041C, YNL051W, YGR120C, ...  10.407547
# 52      {YGL022W, YGL226C-A, YJL002C, YML019W, YOR103C}   8.218954
# 58    {YAL011W, YDR334W, YBR231C, YLR085C, YDR485C, ...  23.442587
# 59    {YDR013W, YDR489W, YLR274W, YBL023C, YJL072C, ...  11.764631
# 60                                   {YPL228W, YGL130W}   8.413392
# 61                                   {YDR288W, YLR007W}   4.508786
# 63    {YDL043C, YGL174W, YLR117C, YJL203W, YMR213W, ...  15.624376
# 64                                            {YHL002W}   1.939479
# 66    {YPR103W, YOR157C, YDL097C, YBL041W, YHR027C, ...  48.589143
# 69    {YGR179C, YAL034W-A, YDR254W, YPR046W, YBR107C...  20.296045
# 71                          {YLR110C, YGL203C, YDR349C}  -1.681266
# 73        {YHR166C, YOR249C, YDR260C, YLR102C, YBL084C}  11.922478
# 74                                   {YER149C, YLL021W}   4.147790
# 76        {YBR095C, YOL004W, YMR263W, YIL084C, YNL097C}   8.721814
# 78                          {YBL026W, YNL147W, YDR378C}   6.396712
# 79                 {YPR016C, YLR397C, YNR053C, YKR092C}  -2.135442
# 81                 {YJR065C, YIL062C, YDL029W, YNR035C}  15.315124
# 83                          {YPR024W, YMR115W, YCL044C}  11.722081
# 84                          {YMR061W, YGL044C, YDR228C}   9.646030
# 87                                   {YNR051C, YER151C}   6.565112
# 88                                   {YLR440C, YGL145W}   3.846492
# 90                                            {YPR075C}   3.555897
# 92                                   {YLL041C, YKL148C}   3.841376
# 94                                   {YBL097W, YDR325W}   1.945108
# 95                                   {YGR140W, YMR168C}   2.635421
# 97                                   {YGL019W, YOR039W}   3.015523
# 98                                            {YBR160W}   1.843683
# 100                                  {YDR062W, YMR296C}   2.759335
# 102       {YMR052W, YNL127W, YMR029C, YFR008W, YLR238W}  18.498141
# 103       {YPL101W, YMR312W, YGR200C, YPL086C, YLR384C}  39.262624
# 109                         {YGR072W, YMR080C, YHR077C}   9.279429
# 110                                  {YMR022W, YMR264W}   6.190406
# 111                                  {YKR084C, YNL001W}   6.472446
# 112                                  {YDR052C, YDL017W}   6.546603
# None  {YPL109C, YGR270W, YGR044C, YML020W, YLR108C, ...  24.871830
#
#              pvalue  Significant
# 2     3.097648e-136         True
# 3      1.310953e-98         True
# 5      1.370022e-10         True
# 9      3.445105e-05         True
# 11     7.365224e-06         True
# 12     5.881370e-05         True
# 17     1.108612e-11         True
# 18     3.520702e-12         True
# 20     5.542313e-44         True
# 22     1.008359e-04         True
# 29     1.623165e-06         True
# 30    7.914965e-104         True
# 31     2.447488e-19         True
# 32     2.873483e-02         True
# 33     3.796322e-03         True
# 37    9.395687e-136         True
# 38     2.736595e-02         True
# 39     9.004447e-06         True
# 45     1.417946e-43         True
# 51     1.145236e-25         True
# 52     1.026426e-16         True
# 58    7.866622e-122         True
# 59     2.969254e-32         True
# 60     1.991597e-17         True
# 61     3.259984e-06         True
# 63     2.483795e-55         True
# 64     2.622153e-02         True
# 66     0.000000e+00         True
# 69     6.968074e-92         True
# 71     4.635567e-02         True
# 73     4.518987e-33         True
# 74     1.678501e-05         True
# 76     1.368894e-18         True
# 78     7.937895e-11         True
# 79     1.636246e-02         True
# 81     3.029820e-53         True
# 83     4.911476e-32         True
# 84     2.554794e-22         True
# 87     2.599688e-11         True
# 88     5.991059e-05         True
# 90     1.883457e-04         True
# 92     6.117326e-05         True
# 94     2.588102e-02         True
# 95     4.201650e-03         True
# 97     1.282684e-03         True
# 98     3.261465e-02         True
# 100    2.895956e-03         True
# 102    1.068606e-76         True
# 103    0.000000e+00         True
# 109    8.519473e-21         True
# 110    3.000477e-10         True
# 111    4.821459e-11         True
# 112    2.943022e-11         True
# None  7.507623e-137         True

# %%
GI_PPI_optimal_overlap_sig_DF.shape[0]
# Out:
# 54
